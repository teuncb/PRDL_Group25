# %%
import re
import random
import os
import numpy as np
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import LabelBinarizer

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import logging
from sklearn.preprocessing import LabelBinarizer


class JustLSTM(keras.Model):
    def __init__(self, input_shape, timeframe, LSTM_units, dense_units, num_classes=4):
        super().__init__()

        # TODO: kijken of we input shape niet uit elkaar trekken in width, height, batch_size en timesteps (nu num_segments)
        self.in_shape = input_shape
        self.num_classes = num_classes
        self.LSTM_units = LSTM_units

        # The number of images / timesteps that we will look at for each training step
        self.timeframe = timeframe

        self.lstm1 = keras.layers.LSTM(self.LSTM_units, return_sequences=True, name="lstm1")
        self.lstm2 = keras.layers.LSTM(self.LSTM_units, name="lstm2")

        self.fc = keras.layers.Dense(dense_units, activation="relu")

        self.out = keras.layers.Dense(self.num_classes, activation="softmax", name="output")

    def call(self, inputs, training=True, mask=None):
        """
        Specifies how the inputs should be passed through the layers of the model and returns the output

        :param inputs: the inputs to be classified by the model, with the same shape as self.in_shape
        :param training: whether the gradients should be tracked
        :param mask: whether a certain mask should be applied on the inputs (such as masking certain timesteps)
        :return: probabilities for each of the classes
        """

        input_layer = keras.layers.InputLayer(self.in_shape, name="input")(inputs)

        # Pass the timesteps through the RNN to find temporal features The amount of units in the layer are equal to
        # the number of timesteps (i.e. segments) according to Zhang et al. (2018)
        lstm1 = self.lstm1(input_layer)
        lstm2 = self.lstm2(lstm1)

        #fc = self.fc(lstm2)

        # Final fully connected layer with softmax to give class probabilities
        output = self.out(lstm2)

        return output

    def build_graph(self):
        """
        Builds the Tensor Graph in order to generate a summary of the model by running dummy input through the model
        :return: a 'dummy' version of the model of which we can generate a summary
        """
        x = keras.Input(self.in_shape)
        return keras.Model(inputs=[x], outputs=self.call(x))

# %%
def create_windows(dataset, model_type, timeframe):
    # Will contain the slices of the dataset that represent the different windows
    windows = []

    if model_type == "cascade":
        num_windows = int(dataset.shape[2] / timeframe)
    else:
        num_windows = int(dataset.shape[1] / timeframe)

    i = timeframe
    j = 0
    count = 0

    # Loop through the dataset until we have the specified number of windows (might cut off some of the last timesteps)
    while count < num_windows:
        # Save the view of the array in the windows list
        if model_type == "cascade":
            view = dataset[:, :, j:i]
        else:
            view = dataset[:, j:i]
        windows.append(view)

        i += timeframe
        j += timeframe
        count += 1
    # Return the list of array views
    return windows


def read_prepro_file(data_path):
    hfive = h5py.File(data_path, 'r')
    matrix = hfive.get('dir')
    matrix = np.array(matrix)
    return matrix

# %%
import tensorflow as tf
from tensorflow import keras
import re
import os
import random
import numpy as np


# tf function zal niet heel veel uitmaken volgens de documentatie, omdat wij veel convolutional operations hebben (waarbij de speedup dus meevalt)
def train_epoch(model, x_train, y_train, optimizer, train_acc):
    # Instantiate an optimizer and loss function
    loss_function = keras.losses.CategoricalCrossentropy()

    total_loss = 0

    # Doet nu nog wel een update per window, wellicht veel? We kunnen ook nog batches gaan gebruiken om het aantal updates te reduceren
    for step in range(len(x_train)):
        # Used to track the gradients during the forward pass
        with tf.GradientTape() as tape:
            logits = model(tf.expand_dims(x_train[step], axis=0), training=True)
            # Calculate the loss value
            loss_value = loss_function(y_train[step], logits)

        total_loss += loss_value

        # Extract the gradients from the gradienttape
        grads = tape.gradient(loss_value, model.trainable_weights)

        # Perform a weight update step using the extracted gradients
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        # Keep track of the training accuracy which is given at the end of the loop
        train_acc.update_state(y_train[step], logits)

        # Report the training loss for monitoring
        if step % 100 == 0:
            print("Training loss value at step {}: {}".format(step, loss_value))

    print("Training accuracy over whole file: {}".format(train_acc.result()))
    print("---------------------------------------------------")
    average_loss = total_loss / len(x_train)
    return average_loss, train_acc


# TODO: kijken of we de input als tensors willen doen (wat wel netter is I guess) of makkelijker als np arrays --> netwerk vindt allebei goed
def fit_eight(model, model_type, dirlist, parent_path, optimizer, timeframe, label_encoder,
              train_acc_obj):  # Fit a network on 8 datafiles at a time.
    fit_list = []
    average_loss = 0
    i = 0
    j = 0
    while i < 8:  # Load the 8 datafiles
        filename = parent_path + "/" + dirlist[i]

        data = read_prepro_file(filename)
        label = extract_label(filename)

        fit_list.append((data, label))
        i += 1

    for counter, (data, label) in enumerate(fit_list):
        print("Fitting on file {} containing task: {}".format((counter + 1), label))
        # Creates windows of length 'timeframe' to fit the model on
        windows = create_windows(data, model_type, timeframe)
        x_train = []
        # Only needed for CascadeNet, not for the LSTM network
        for window in windows:
            if model_type == "cascade":
                x_train.append(tf.convert_to_tensor(window))
            else:
                x_train.append(tf.convert_to_tensor(np.transpose(window)))

        # Encode the textual label to one-hot-encoding
        encoded_label = label_encoder.transform([label])
        # Create a list of tensors, each corresponding to an encoded label
        y_train = [tf.convert_to_tensor(encoded_label)] * len(x_train)

        # Fit the model on the data from this specific file
        average_loss, train_acc_obj = train_epoch(model, x_train, y_train, optimizer, train_acc_obj)

    return average_loss, train_acc_obj


def train_dir(model, model_type, dirpath, epochs, timeframe, optimizer, label_encoder,
              shuffle=True):  # Train a network on a given directory
    dirnames = os.listdir(dirpath)  # get list of all filenames
    random.shuffle(dirnames)
    batches = len(dirnames) // 8  # int divide by eight to avoid float errors

    train_acc_obj = keras.metrics.CategoricalAccuracy()

    average_epoch_accuracy = 0
    average_epoch_loss = 0
    losses = []
    accuracies = []

    # Check if it is divisible by eight
    if not (len(dirnames) % 8) == 0:
        raise TypeError("Not divisible by eight")

    for epoch in range(epochs):
        print("Starting epoch {}".format(epoch + 1))
        print()
        train_acc_obj.reset_states()
        for i in range(batches):  # Fit on 8 batches at a time                HIER IPV 1 WEER 'BATCHES' NEERZETTEN
            print("Fitting on files {}-{}....".format((i * 8), ((i + 1) * 8)))
            # Fits the model on 8 files for the specified amount of epochs
            average_loss, train_acc_obj = fit_eight(model, model_type, dirnames[i * 8:(i + 1) * 8], dirpath, optimizer,
                                                    timeframe, label_encoder, train_acc_obj)
            average_epoch_loss += average_loss
            average_epoch_accuracy += train_acc_obj.result()

            print("--------------------------------------------------------------")

        losses.append(average_epoch_loss)
        accuracies.append(average_epoch_accuracy)

    # SAVE THE MODEL AFTER TRAINING!!!!
    model.save("models/trained_LSTM_e2_5_20_cross")

    return model, losses, accuracies


def extract_label(filename):  # Extract the label out of a filename
    filename = filename.split("/")
    pattern = r'_\d'
    split = re.split(pattern, filename[-1])
    return split[0]

# %%
from sklearn.preprocessing import LabelBinarizer
import tensorflow
from tensorflow import keras

output_classes = 4

# Hyperparameters
timeframe = 5
LSTM_units = 20
# (1e-2, 1e-3, 1e-4)
learning_rate = 1e-2

epochs = 5



textual_labels = ["rest", "task_motor", "task_story_math", "task_working_memory"]
label_encoder = LabelBinarizer()
label_encoder.fit(textual_labels)

model = JustLSTM((timeframe, 248), timeframe, LSTM_units, 16, output_classes)
model_type = "lstm"

optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

model, losses, accuracies = train_dir(model, model_type, "data/Cross/train_prepro", epochs, timeframe, optimizer, label_encoder)
# Out:
# Starting epoch 1
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 1.3539279699325562
# Training loss value at step 100: 0.011571669019758701
# Training loss value at step 200: 0.00010179955279454589
# Training loss value at step 300: 3.683499380713329e-05
# Training loss value at step 400: 6.770858453819528e-05
# Training loss value at step 500: 6.151010165922344e-05
# Training loss value at step 600: 1.2278481335670222e-05
# Training loss value at step 700: 9.059865078597795e-06
# Training accuracy over whole file: 0.9974715709686279
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 13.111363410949707
# Training loss value at step 100: 0.00032729512895457447
# Training loss value at step 200: 0.0002857038634829223
# Training loss value at step 300: 0.00019000156316906214
# Training loss value at step 400: 7.652943895664066e-05
# Training loss value at step 500: 9.178694017464295e-05
# Training loss value at step 600: 0.00021419614495243877
# Training loss value at step 700: 8.725739462533966e-05
# Training accuracy over whole file: 0.993678867816925
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 11.20209789276123
# Training loss value at step 100: 0.00017629499780014157
# Training loss value at step 200: 0.00023958197562023997
# Training loss value at step 300: 4.8040190449682996e-05
# Training loss value at step 400: 5.209310256759636e-05
# Training loss value at step 500: 2.8490614567999728e-05
# Training loss value at step 600: 3.9934315282152966e-05
# Training loss value at step 700: 3.71926071238704e-05
# Training accuracy over whole file: 0.991993248462677
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 13.902295112609863
# Training loss value at step 100: 0.0011980506824329495
# Training loss value at step 200: 0.004237482324242592
# Training loss value at step 300: 0.0011376821203157306
# Training loss value at step 400: 0.000996331567876041
# Training loss value at step 500: 0.0004015354788862169
# Training loss value at step 600: 0.0003607814433053136
# Training loss value at step 700: 0.000592890428379178
# Training accuracy over whole file: 0.991150438785553
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 9.298578262329102
# Training loss value at step 100: 0.00015960850578267127
# Training loss value at step 200: 0.00010644822759786621
# Training loss value at step 300: 9.595887240720913e-05
# Training loss value at step 400: 7.784063927829266e-05
# Training loss value at step 500: 2.7894584491150454e-05
# Training loss value at step 600: 2.8490614567999728e-05
# Training loss value at step 700: 2.9205850296420977e-05
# Training accuracy over whole file: 0.9906447529792786
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 7.142495632171631
# Training loss value at step 100: 0.0007596705690957606
# Training loss value at step 200: 0.0015443552983924747
# Training loss value at step 300: 0.0014396075857803226
# Training loss value at step 400: 0.0003885467885993421
# Training loss value at step 500: 0.0003177614707965404
# Training loss value at step 600: 0.0005839549703523517
# Training loss value at step 700: 0.0002094287920044735
# Training accuracy over whole file: 0.9898862242698669
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 9.62279987335205
# Training loss value at step 100: 4.2199197196168825e-05
# Training loss value at step 200: 1.0013530300057027e-05
# Training loss value at step 300: 8.34461570775602e-06
# Training loss value at step 400: 1.2397689715726301e-05
# Training loss value at step 500: 1.5020257706055418e-05
# Training loss value at step 600: 1.4424220353248529e-05
# Training loss value at step 700: 7.033323527139146e-06
# Training accuracy over whole file: 0.9900668263435364
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 13.152261734008789
# Training loss value at step 100: 5.364403477869928e-06
# Training loss value at step 200: 1.0609570381348021e-05
# Training loss value at step 300: 4.529942543740617e-06
# Training loss value at step 400: 0.00013457823661156
# Training loss value at step 500: 4.887569048150908e-06
# Training loss value at step 600: 9.536697689327411e-06
# Training loss value at step 700: 5.245195097813848e-06
# Training accuracy over whole file: 0.989570140838623
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 4.529942543740617e-06
# Training loss value at step 100: 4.887569048150908e-06
# Training loss value at step 200: 3.814689989667386e-06
# Training loss value at step 300: 5.8412379075889476e-06
# Training loss value at step 400: 5.960446742392378e-06
# Training loss value at step 500: 6.794906312279636e-06
# Training loss value at step 600: 3.933898824470816e-06
# Training loss value at step 700: 5.006777428206988e-06
# Training accuracy over whole file: 0.990729033946991
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 13.70257568359375
# Training loss value at step 100: 9.321732068201527e-05
# Training loss value at step 200: 3.302042750874534e-05
# Training loss value at step 300: 0.00040820849244482815
# Training loss value at step 400: 3.349725011503324e-05
# Training loss value at step 500: 6.282132380874828e-05
# Training loss value at step 600: 4.8636207793606445e-05
# Training loss value at step 700: 3.671578815556131e-05
# Training accuracy over whole file: 0.9898862242698669
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 11.126934051513672
# Training loss value at step 100: 0.0009095107670873404
# Training loss value at step 200: 0.0009660820942372084
# Training loss value at step 300: 0.0008099374244920909
# Training loss value at step 400: 0.00014554394874721766
# Training loss value at step 500: 0.0001597276859683916
# Training loss value at step 600: 0.00018487652414478362
# Training loss value at step 700: 3.6477376852417365e-05
# Training accuracy over whole file: 0.9895414113998413
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 8.272845268249512
# Training loss value at step 100: 0.0010364643530920148
# Training loss value at step 200: 0.00035386974923312664
# Training loss value at step 300: 0.0008573431987315416
# Training loss value at step 400: 0.000161038784426637
# Training loss value at step 500: 0.00015889335190877318
# Training loss value at step 600: 0.0001248043408850208
# Training loss value at step 700: 5.781483559985645e-05
# Training accuracy over whole file: 0.989359438419342
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 10.215871810913086
# Training loss value at step 100: 0.00012027494085486978
# Training loss value at step 200: 9.7508447652217e-05
# Training loss value at step 300: 7.188061863416806e-05
# Training loss value at step 400: 6.294052582234144e-05
# Training loss value at step 500: 0.00010108436981681734
# Training loss value at step 600: 4.756337511935271e-05
# Training loss value at step 700: 3.2543604902457446e-05
# Training accuracy over whole file: 0.9891082644462585
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.00014995403762441128
# Training loss value at step 100: 3.862306402879767e-05
# Training loss value at step 200: 0.0001003691868390888
# Training loss value at step 300: 5.638440416078083e-05
# Training loss value at step 400: 8.761498611420393e-05
# Training loss value at step 500: 5.709961988031864e-05
# Training loss value at step 600: 0.00010251473577227443
# Training loss value at step 700: 1.3589766240329482e-05
# Training accuracy over whole file: 0.9898862242698669
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 11.779998779296875
# Training loss value at step 100: 0.00010084597306558862
# Training loss value at step 200: 6.878139538457617e-05
# Training loss value at step 300: 0.000399033073335886
# Training loss value at step 400: 2.932505594799295e-05
# Training loss value at step 500: 5.709961988031864e-05
# Training loss value at step 600: 2.3483953555114567e-05
# Training loss value at step 700: 7.497983460780233e-05
# Training accuracy over whole file: 0.9897176623344421
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 11.90477180480957
# Training loss value at step 100: 0.0003400462737772614
# Training loss value at step 200: 0.0013166338903829455
# Training loss value at step 300: 0.0009218971827067435
# Training loss value at step 400: 0.0003868784988299012
# Training loss value at step 500: 0.00036030475166626275
# Training loss value at step 600: 0.0007701530121266842
# Training loss value at step 700: 0.0002790300059132278
# Training accuracy over whole file: 0.9894121289253235
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 10.167746543884277
# Training loss value at step 100: 0.00013076403411105275
# Training loss value at step 200: 0.00027211778797209263
# Training loss value at step 300: 0.00014852374442853034
# Training loss value at step 400: 0.00019178935326635838
# Training loss value at step 500: 0.00017689094238448888
# Training loss value at step 600: 0.00020203932945150882
# Training loss value at step 700: 0.00037674958002753556
# Training accuracy over whole file: 0.9890682101249695
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 16.308975219726562
# Training loss value at step 100: 0.00024041623692028224
# Training loss value at step 200: 0.00027771908207796514
# Training loss value at step 300: 0.00014602071314584464
# Training loss value at step 400: 0.0004183370911050588
# Training loss value at step 500: 0.00017212340026162565
# Training loss value at step 600: 6.079655122448457e-06
# Training loss value at step 700: 0.002825199393555522
# Training accuracy over whole file: 0.9886220097541809
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 1.6093124941107817e-05
# Training loss value at step 100: 1.0371154530730564e-05
# Training loss value at step 200: 7.414542778860778e-05
# Training loss value at step 300: 8.821448318485636e-06
# Training loss value at step 400: 2.4914430468925275e-05
# Training loss value at step 500: 3.158996332786046e-05
# Training loss value at step 600: 0.0001161031104857102
# Training loss value at step 700: 9.131014667218551e-05
# Training accuracy over whole file: 0.9892208576202393
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 3.0874729418428615e-05
# Training loss value at step 100: 2.9444261599564925e-05
# Training loss value at step 200: 2.8609820219571702e-05
# Training loss value at step 300: 1.811964830267243e-05
# Training loss value at step 400: 8.260862523457035e-05
# Training loss value at step 500: 2.5033637939486653e-05
# Training loss value at step 600: 2.0146166207268834e-05
# Training loss value at step 700: 5.960462772236497e-07
# Training accuracy over whole file: 0.9897598028182983
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 12.737947463989258
# Training loss value at step 100: 0.00784364715218544
# Training loss value at step 200: 0.0015387610765174031
# Training loss value at step 300: 0.0009885906474664807
# Training loss value at step 400: 0.002515249652788043
# Training loss value at step 500: 0.001705264556221664
# Training loss value at step 600: 0.0002711643755901605
# Training loss value at step 700: 5.280832192511298e-05
# Training accuracy over whole file: 0.9889832139015198
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 10.086130142211914
# Training loss value at step 100: 0.003923933021724224
# Training loss value at step 200: 0.00031716562807559967
# Training loss value at step 300: 0.00038044367101974785
# Training loss value at step 400: 0.00011300401820335537
# Training loss value at step 500: 0.00021252757869660854
# Training loss value at step 600: 0.0002343380037928
# Training loss value at step 700: 1.2755313036905136e-05
# Training accuracy over whole file: 0.9883921146392822
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 11.057294845581055
# Training loss value at step 100: 0.0001941730733960867
# Training loss value at step 200: 0.00011681827891152352
# Training loss value at step 300: 0.00022933237778488547
# Training loss value at step 400: 0.00027938754647038877
# Training loss value at step 500: 2.95634672511369e-05
# Training loss value at step 600: 0.0005180685548111796
# Training loss value at step 700: 8.583032467868179e-06
# Training accuracy over whole file: 0.9877974987030029
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 12.5047025680542
# Training loss value at step 100: 0.003926070407032967
# Training loss value at step 200: 0.0020943391136825085
# Training loss value at step 300: 0.001739775761961937
# Training loss value at step 400: 0.0007294139941222966
# Training loss value at step 500: 0.0018184330547228456
# Training loss value at step 600: 7.855583680793643e-05
# Training loss value at step 700: 0.0003147821989841759
# Training accuracy over whole file: 0.9874104261398315
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 0.003543053288012743
# Training loss value at step 100: 0.0013567537534981966
# Training loss value at step 200: 0.001311752712354064
# Training loss value at step 300: 0.0001820160250645131
# Training loss value at step 400: 0.0010844547068700194
# Training loss value at step 500: 0.0003297977091278881
# Training loss value at step 600: 5.304672595229931e-05
# Training loss value at step 700: 0.00498931622132659
# Training accuracy over whole file: 0.9879140257835388
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 2.3007127310847864e-05
# Training loss value at step 100: 0.00019202772818971425
# Training loss value at step 200: 5.722029527532868e-06
# Training loss value at step 300: 6.615896563744172e-05
# Training loss value at step 400: 0.0001958416833076626
# Training loss value at step 500: 8.618460560683161e-05
# Training loss value at step 600: 4.9470632802695036e-05
# Training loss value at step 700: 0.000759074988309294
# Training accuracy over whole file: 0.9883788824081421
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 8.48570442199707
# Training loss value at step 100: 0.00194110709708184
# Training loss value at step 200: 0.0013048476539552212
# Training loss value at step 300: 0.00205163168720901
# Training loss value at step 400: 6.341733387671411e-05
# Training loss value at step 500: 0.0001012035645544529
# Training loss value at step 600: 0.0001282609737245366
# Training loss value at step 700: 5.8410845667822286e-05
# Training accuracy over whole file: 0.9882006049156189
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 10.896076202392578
# Training loss value at step 100: 0.00158946483861655
# Training loss value at step 200: 0.0011133907828480005
# Training loss value at step 300: 0.0006829552003182471
# Training loss value at step 400: 0.0002543602604418993
# Training loss value at step 500: 0.0012644876260310411
# Training loss value at step 600: 0.0008667526417411864
# Training loss value at step 700: 0.0005810956354252994
# Training accuracy over whole file: 0.9878996014595032
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 9.294110298156738
# Training loss value at step 100: 0.002879285253584385
# Training loss value at step 200: 0.0038769098464399576
# Training loss value at step 300: 0.0004292996891308576
# Training loss value at step 400: 0.0026833738666027784
# Training loss value at step 500: 0.0015079329023137689
# Training loss value at step 600: 0.00012408917245920748
# Training loss value at step 700: 0.00012003655137959868
# Training accuracy over whole file: 0.9876193404197693
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 2.395960569381714
# Training loss value at step 100: 0.0005150898941792548
# Training loss value at step 200: 0.0006744970451109111
# Training loss value at step 300: 2.6225699912174605e-05
# Training loss value at step 400: 0.047067027539014816
# Training loss value at step 500: 0.0009413101943209767
# Training loss value at step 600: 0.0008918836829252541
# Training loss value at step 700: 8.928377064876258e-05
# Training accuracy over whole file: 0.9875263571739197
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 1.0728830375228426e-06
# Training loss value at step 100: 1.4305104514278355e-06
# Training loss value at step 200: 0.0002980979916173965
# Training loss value at step 300: 7.080780778778717e-05
# Training loss value at step 400: 0.0005628670332953334
# Training loss value at step 500: 2.8371408916427754e-05
# Training loss value at step 600: 6.425174069590867e-05
# Training loss value at step 700: 7.581423415103927e-05
# Training accuracy over whole file: 0.9879286885261536
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 10.104887962341309
# Training loss value at step 100: 0.02016671560704708
# Training loss value at step 200: 0.0030017101671546698
# Training loss value at step 300: 0.002502645133063197
# Training loss value at step 400: 0.0018461579456925392
# Training loss value at step 500: 0.0018278334755450487
# Training loss value at step 600: 0.0011711412807926536
# Training loss value at step 700: 0.0008095800876617432
# Training accuracy over whole file: 0.9874762892723083
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 32-40....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 4.081055641174316
# Training loss value at step 100: 0.0006121906917542219
# Training loss value at step 200: 0.010797174647450447
# Training loss value at step 300: 0.03929930552840233
# Training loss value at step 400: 0.0003743662964552641
# Training loss value at step 500: 3.886147169396281e-05
# Training loss value at step 600: 0.00011884459672728553
# Training loss value at step 700: 1.1205610462639015e-05
# Training accuracy over whole file: 0.9871279001235962
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 8.868854522705078
# Training loss value at step 100: 0.00035279724397696555
# Training loss value at step 200: 2.5255799293518066
# Training loss value at step 300: 0.022920558229088783
# Training loss value at step 400: 0.0019839382730424404
# Training loss value at step 500: 0.00010954733443213627
# Training loss value at step 600: 0.0013068715343251824
# Training loss value at step 700: 0.00025245340657420456
# Training accuracy over whole file: 0.9868000149726868
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 14.396319389343262
# Training loss value at step 100: 2.6225699912174605e-05
# Training loss value at step 200: 0.01589086279273033
# Training loss value at step 300: 2.0265558760002023e-06
# Training loss value at step 400: 7.867782187531702e-06
# Training loss value at step 500: 1.311301275563892e-06
# Training loss value at step 600: 1.1920928244535389e-07
# Training loss value at step 700: 5.960462772236497e-07
# Training accuracy over whole file: 0.985804557800293
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.3056790828704834
# Training loss value at step 100: 0.0021130156237632036
# Training loss value at step 200: 0.01623024046421051
# Training loss value at step 300: 0.0003413571394048631
# Training loss value at step 400: 0.0022814455442130566
# Training loss value at step 500: 0.00013517419574782252
# Training loss value at step 600: 0.04339516535401344
# Training loss value at step 700: 0.002385748317465186
# Training accuracy over whole file: 0.985672116279602
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 12.388816833496094
# Training loss value at step 100: 7.152555099310121e-07
# Training loss value at step 200: 1.7881377516459906e-06
# Training loss value at step 300: 8.344646857949556e-07
# Training loss value at step 400: 1.6927575416048057e-05
# Training loss value at step 500: 5.960462772236497e-07
# Training loss value at step 600: 1.823885577323381e-05
# Training loss value at step 700: 5.483612312673358e-06
# Training accuracy over whole file: 0.9855810403823853
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.00019774865359067917
# Training loss value at step 100: 0.0
# Training loss value at step 200: 1.7881377516459906e-06
# Training loss value at step 300: 1.7881377516459906e-06
# Training loss value at step 400: 0.0
# Training loss value at step 500: 2.3841855067985307e-07
# Training loss value at step 600: 8.106198947643861e-06
# Training loss value at step 700: 5.030505417380482e-05
# Training accuracy over whole file: 0.9858606457710266
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 14.380159378051758
# Training loss value at step 100: 0.005122038535773754
# Training loss value at step 200: 0.00038235029205679893
# Training loss value at step 300: 0.0017394188325852156
# Training loss value at step 400: 0.00020919041708111763
# Training loss value at step 500: 0.00024101213784888387
# Training loss value at step 600: 0.016765527427196503
# Training loss value at step 700: 6.0794889577664435e-05
# Training accuracy over whole file: 0.9854128360748291
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 0.08863304555416107
# Training loss value at step 100: 0.0023509026505053043
# Training loss value at step 200: 1.2993727978027891e-05
# Training loss value at step 300: 0.00070296844933182
# Training loss value at step 400: 0.0017028844449669123
# Training loss value at step 500: 7.390948667307384e-06
# Training loss value at step 600: 7.259582343976945e-05
# Training loss value at step 700: 0.0004462200158741325
# Training accuracy over whole file: 0.9857774972915649
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 0.0005980133428238332
# Training loss value at step 100: 0.0006810491322539747
# Training loss value at step 200: 9.226373367710039e-05
# Training loss value at step 300: 0.0004956685588695109
# Training loss value at step 400: 0.00294263893738389
# Training loss value at step 500: 0.0003079893649555743
# Training loss value at step 600: 2.7418097943154862e-06
# Training loss value at step 700: 1.0251946150674485e-05
# Training accuracy over whole file: 0.9861243963241577
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 11.141637802124023
# Training loss value at step 100: 0.00024768622824922204
# Training loss value at step 200: 3.611976353568025e-05
# Training loss value at step 300: 0.00025412190007045865
# Training loss value at step 400: 5.98412734689191e-05
# Training loss value at step 500: 6.210611172718927e-05
# Training loss value at step 600: 9.536288416711614e-05
# Training loss value at step 700: 0.0001821352052502334
# Training accuracy over whole file: 0.9858527779579163
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 7.823850154876709
# Training loss value at step 100: 0.000972036796156317
# Training loss value at step 200: 0.00014506718434859067
# Training loss value at step 300: 0.19011633098125458
# Training loss value at step 400: 0.0034454050473868847
# Training loss value at step 500: 0.0006507901125587523
# Training loss value at step 600: 4.410734163684538e-06
# Training loss value at step 700: 0.0010178867960348725
# Training accuracy over whole file: 0.9855055212974548
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 15.969428062438965
# Training loss value at step 100: 0.0477537102997303
# Training loss value at step 200: 7.319182623177767e-05
# Training loss value at step 300: 0.00013672371278516948
# Training loss value at step 400: 0.0002829628065228462
# Training loss value at step 500: 8.892617915989831e-05
# Training loss value at step 600: 9.810443589231e-05
# Training loss value at step 700: 0.003097737906500697
# Training accuracy over whole file: 0.9851453900337219
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 8.960029602050781
# Training loss value at step 100: 0.0028278145473450422
# Training loss value at step 200: 0.0003232433518860489
# Training loss value at step 300: 0.01095589529722929
# Training loss value at step 400: 0.008556608110666275
# Training loss value at step 500: 0.0020918408408761024
# Training loss value at step 600: 0.001763337990269065
# Training loss value at step 700: 0.0006700892699882388
# Training accuracy over whole file: 0.9847450256347656
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 12.146326065063477
# Training loss value at step 100: 0.022625749930739403
# Training loss value at step 200: 0.004942343104630709
# Training loss value at step 300: 0.0022640805691480637
# Training loss value at step 400: 0.021050255745649338
# Training loss value at step 500: 0.0016550427535548806
# Training loss value at step 600: 0.0021121830213814974
# Training loss value at step 700: 0.0017903504194691777
# Training accuracy over whole file: 0.9844170808792114
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 1.863722801208496
# Training loss value at step 100: 0.00011538793478393927
# Training loss value at step 200: 0.0003002431185450405
# Training loss value at step 300: 0.00010489867418073118
# Training loss value at step 400: 3.766942609217949e-05
# Training loss value at step 500: 0.024293826892971992
# Training loss value at step 600: 0.007239064201712608
# Training loss value at step 700: 0.0007602662080898881
# Training accuracy over whole file: 0.9842913746833801
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 12.671304702758789
# Training loss value at step 100: 0.004477831535041332
# Training loss value at step 200: 0.0021627387031912804
# Training loss value at step 300: 0.004052760079503059
# Training loss value at step 400: 0.002939548809081316
# Training loss value at step 500: 0.0004363300104159862
# Training loss value at step 600: 0.006471747066825628
# Training loss value at step 700: 0.0001811817055568099
# Training accuracy over whole file: 0.9840655326843262
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 10.417263984680176
# Training loss value at step 100: 0.0028556303586810827
# Training loss value at step 200: 0.018719321116805077
# Training loss value at step 300: 0.0011508992174640298
# Training loss value at step 400: 0.0007560970261693001
# Training loss value at step 500: 0.0008026715368032455
# Training loss value at step 600: 0.0007831366965547204
# Training loss value at step 700: 0.0003469580551609397
# Training accuracy over whole file: 0.983565092086792
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 13.17449951171875
# Training loss value at step 100: 0.0038291718810796738
# Training loss value at step 200: 0.001613625674508512
# Training loss value at step 300: 0.0011480414541438222
# Training loss value at step 400: 0.0019508631667122245
# Training loss value at step 500: 0.0004720765573438257
# Training loss value at step 600: 0.00035577642847783864
# Training loss value at step 700: 0.005156906321644783
# Training accuracy over whole file: 0.9833375215530396
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 12.052570343017578
# Training loss value at step 100: 0.009946780279278755
# Training loss value at step 200: 0.004680273588746786
# Training loss value at step 300: 0.013364259153604507
# Training loss value at step 400: 0.0028765511233359575
# Training loss value at step 500: 0.0014972201315686107
# Training loss value at step 600: 0.0009833505610004067
# Training loss value at step 700: 0.0037320267874747515
# Training accuracy over whole file: 0.98314368724823
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 6.155755519866943
# Training loss value at step 100: 0.002134546637535095
# Training loss value at step 200: 0.10699612647294998
# Training loss value at step 300: 0.0012449617497622967
# Training loss value at step 400: 0.0141681507229805
# Training loss value at step 500: 0.00027378625236451626
# Training loss value at step 600: 0.0005421360838226974
# Training loss value at step 700: 0.0007664603181183338
# Training accuracy over whole file: 0.9831274747848511
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 10.815366744995117
# Training loss value at step 100: 0.0009573881980031729
# Training loss value at step 200: 0.01396973617374897
# Training loss value at step 300: 0.008154669776558876
# Training loss value at step 400: 0.008304587565362453
# Training loss value at step 500: 0.003949105739593506
# Training loss value at step 600: 0.00046790618216618896
# Training loss value at step 700: 0.0019254018552601337
# Training accuracy over whole file: 0.9829687476158142
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 9.153168678283691
# Training loss value at step 100: 0.0017202593153342605
# Training loss value at step 200: 0.0005609607324004173
# Training loss value at step 300: 0.008892104029655457
# Training loss value at step 400: 0.021267341449856758
# Training loss value at step 500: 0.003324578981846571
# Training loss value at step 600: 0.0031251898035407066
# Training loss value at step 700: 0.01497808936983347
# Training accuracy over whole file: 0.9822774529457092
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 0.0001174142598756589
# Training loss value at step 100: 0.00013541258522309363
# Training loss value at step 200: 8.904537389753386e-05
# Training loss value at step 300: 0.0008470999309793115
# Training loss value at step 400: 0.00036459474358707666
# Training loss value at step 500: 0.019068969413638115
# Training loss value at step 600: 5.507317473529838e-05
# Training loss value at step 700: 0.00035041390219703317
# Training accuracy over whole file: 0.982599675655365
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 11.452839851379395
# Training loss value at step 100: 7.70062324590981e-05
# Training loss value at step 200: 2.586808113846928e-05
# Training loss value at step 300: 0.0002683041093405336
# Training loss value at step 400: 1.7523612768854946e-05
# Training loss value at step 500: 1.2993727978027891e-05
# Training loss value at step 600: 0.012920472770929337
# Training loss value at step 700: 2.3603161025675945e-05
# Training accuracy over whole file: 0.9825040698051453
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 9.512448741588742e-05
# Training loss value at step 100: 5.304672595229931e-05
# Training loss value at step 200: 3.71926071238704e-05
# Training loss value at step 300: 1.2040065485052764e-05
# Training loss value at step 400: 9.179073458653875e-06
# Training loss value at step 500: 4.827859811484814e-05
# Training loss value at step 600: 3.6954195820726454e-05
# Training loss value at step 700: 3.8265450712060556e-05
# Training accuracy over whole file: 0.9828110337257385
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 13.224292755126953
# Training loss value at step 100: 0.001493054092861712
# Training loss value at step 200: 0.00043525759247131646
# Training loss value at step 300: 0.0007082099909894168
# Training loss value at step 400: 0.001013361383229494
# Training loss value at step 500: 0.0001879753835964948
# Training loss value at step 600: 0.0003864018653985113
# Training loss value at step 700: 0.00047910655848681927
# Training accuracy over whole file: 0.9827368259429932
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 8.590934753417969
# Training loss value at step 100: 0.000388665939681232
# Training loss value at step 200: 1.7881233361549675e-05
# Training loss value at step 300: 0.28495585918426514
# Training loss value at step 400: 0.004401044920086861
# Training loss value at step 500: 0.00018046658078674227
# Training loss value at step 600: 0.0047566830180585384
# Training loss value at step 700: 0.0018764998530969024
# Training accuracy over whole file: 0.9825794696807861
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.00982602871954441
# Training loss value at step 100: 0.0032834685407578945
# Training loss value at step 200: 1.5497195136049413e-06
# Training loss value at step 300: 1.5497195136049413e-06
# Training loss value at step 400: 2.6940935640595853e-05
# Training loss value at step 500: 1.4662635294371285e-05
# Training loss value at step 600: 0.00020668754586949944
# Training loss value at step 700: 0.00012408917245920748
# Training accuracy over whole file: 0.9828487038612366
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 15.696151733398438
# Training loss value at step 100: 0.0001646144810365513
# Training loss value at step 200: 0.00046719127567484975
# Training loss value at step 300: 0.00011646069469861686
# Training loss value at step 400: 0.0004262015863787383
# Training loss value at step 500: 0.00047743841423653066
# Training loss value at step 600: 0.0011716175358742476
# Training loss value at step 700: 0.0035750067327171564
# Training accuracy over whole file: 0.9827361106872559
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 2.138786554336548
# Training loss value at step 100: 0.007809700444340706
# Training loss value at step 200: 0.004015597980469465
# Training loss value at step 300: 0.00037531962152570486
# Training loss value at step 400: 4.31528314948082e-05
# Training loss value at step 500: 0.0020412816666066647
# Training loss value at step 600: 3.58813522325363e-05
# Training loss value at step 700: 0.00022909401741344482
# Training accuracy over whole file: 0.9827902317047119
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 9.72890567779541
# Training loss value at step 100: 0.0010094314347952604
# Training loss value at step 200: 0.01692037284374237
# Training loss value at step 300: 0.0019451522966846824
# Training loss value at step 400: 0.0019195717759430408
# Training loss value at step 500: 0.003346678102388978
# Training loss value at step 600: 0.00020597243565134704
# Training loss value at step 700: 0.00028761065914295614
# Training accuracy over whole file: 0.9826821684837341
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 9.708781242370605
# Training loss value at step 100: 0.00027021096320822835
# Training loss value at step 200: 0.11446117609739304
# Training loss value at step 300: 3.659658250398934e-05
# Training loss value at step 400: 0.00545169273391366
# Training loss value at step 500: 2.3007127310847864e-05
# Training loss value at step 600: 0.003480450250208378
# Training loss value at step 700: 1.1324817933200393e-05
# Training accuracy over whole file: 0.9824588894844055
# ---------------------------------------------------
# --------------------------------------------------------------
# Starting epoch 2
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 10.401633262634277
# Training loss value at step 100: 0.003337054280564189
# Training loss value at step 200: 0.001210552523843944
# Training loss value at step 300: 0.0008657997823320329
# Training loss value at step 400: 0.0017100248951464891
# Training loss value at step 500: 0.00113589596003294
# Training loss value at step 600: 0.0038689535576850176
# Training loss value at step 700: 0.0010720703285187483
# Training accuracy over whole file: 0.9734513163566589
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 11.02069091796875
# Training loss value at step 100: 0.0012200777418911457
# Training loss value at step 200: 0.000498289882671088
# Training loss value at step 300: 3.4689302992774174e-05
# Training loss value at step 400: 9.011816291604191e-05
# Training loss value at step 500: 2.3603161025675945e-05
# Training loss value at step 600: 5.173549288883805e-05
# Training loss value at step 700: 8.4638240878121e-06
# Training accuracy over whole file: 0.9696586728096008
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 11.923605918884277
# Training loss value at step 100: 3.0278701160568744e-05
# Training loss value at step 200: 5.61460001335945e-05
# Training loss value at step 300: 6.925819616299123e-05
# Training loss value at step 400: 4.768360213347478e-06
# Training loss value at step 500: 0.0004412154376041144
# Training loss value at step 600: 2.3841855067985307e-07
# Training loss value at step 700: 2.3841855067985307e-07
# Training accuracy over whole file: 0.974294126033783
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 16.48091697692871
# Training loss value at step 100: 0.0002195594133809209
# Training loss value at step 200: 0.0066881137900054455
# Training loss value at step 300: 0.0012001938885077834
# Training loss value at step 400: 6.079655122448457e-06
# Training loss value at step 500: 0.00044860312482342124
# Training loss value at step 600: 1.966933996300213e-05
# Training loss value at step 700: 1.1920928244535389e-07
# Training accuracy over whole file: 0.9762958288192749
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 13.698904991149902
# Training loss value at step 100: 0.0027462646830826998
# Training loss value at step 200: 0.0032963010016828775
# Training loss value at step 300: 0.0037991267163306475
# Training loss value at step 400: 0.0029068617150187492
# Training loss value at step 500: 0.0009504806366749108
# Training loss value at step 600: 0.0005765683017671108
# Training loss value at step 700: 0.00011324241495458409
# Training accuracy over whole file: 0.977496862411499
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 6.940189361572266
# Training loss value at step 100: 8.344646857949556e-07
# Training loss value at step 200: 2.0265558760002023e-06
# Training loss value at step 300: 0.12243186682462692
# Training loss value at step 400: 0.0008624648326076567
# Training loss value at step 500: 0.00013183678674977273
# Training loss value at step 600: 4.6491513785440475e-06
# Training loss value at step 700: 7.045020902296528e-05
# Training accuracy over whole file: 0.9780868291854858
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 13.752708435058594
# Training loss value at step 100: 0.7136157155036926
# Training loss value at step 200: 2.5033637939486653e-05
# Training loss value at step 300: 0.00043394684325903654
# Training loss value at step 400: 2.706014311115723e-05
# Training loss value at step 500: 0.0006368515896610916
# Training loss value at step 600: 0.00015662873920518905
# Training loss value at step 700: 0.0003003622987307608
# Training accuracy over whole file: 0.9770634174346924
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 9.772321701049805
# Training loss value at step 100: 0.0008472190820612013
# Training loss value at step 200: 0.0009607228566892445
# Training loss value at step 300: 0.004509992431849241
# Training loss value at step 400: 0.00019429226813372225
# Training loss value at step 500: 0.0002649671514518559
# Training loss value at step 600: 0.0005681092734448612
# Training loss value at step 700: 0.0004667146422434598
# Training accuracy over whole file: 0.9774020314216614
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 2.6940935640595853e-05
# Training loss value at step 100: 0.00026973424246534705
# Training loss value at step 200: 2.729855441430118e-05
# Training loss value at step 300: 2.276871418871451e-05
# Training loss value at step 400: 8.40390202938579e-05
# Training loss value at step 500: 0.0001567479339428246
# Training loss value at step 600: 0.000129691296024248
# Training loss value at step 700: 5.125868119648658e-05
# Training accuracy over whole file: 0.9799129366874695
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 9.51840877532959
# Training loss value at step 100: 0.00013505500101018697
# Training loss value at step 200: 0.00016759421851020306
# Training loss value at step 300: 0.0002008474839385599
# Training loss value at step 400: 0.0001387499796692282
# Training loss value at step 500: 7.664863369427621e-05
# Training loss value at step 600: 2.0861407392658293e-05
# Training loss value at step 700: 5.745722592109814e-05
# Training accuracy over whole file: 0.9801517128944397
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 11.097639083862305
# Training loss value at step 100: 0.001427584677003324
# Training loss value at step 200: 0.0023509026505053043
# Training loss value at step 300: 0.0003805628512054682
# Training loss value at step 400: 0.00723764393478632
# Training loss value at step 500: 0.0010838593589141965
# Training loss value at step 600: 0.0005106813623569906
# Training loss value at step 700: 0.001526977401226759
# Training accuracy over whole file: 0.9797724485397339
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 8.40091323852539
# Training loss value at step 100: 0.0017141900025308132
# Training loss value at step 200: 0.0017755947774276137
# Training loss value at step 300: 0.028958382084965706
# Training loss value at step 400: 0.0003500564198475331
# Training loss value at step 500: 0.0007011815905570984
# Training loss value at step 600: 0.0006185048841871321
# Training loss value at step 700: 0.000856747676152736
# Training accuracy over whole file: 0.9801938533782959
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 4.625094413757324
# Training loss value at step 100: 0.0016764646861702204
# Training loss value at step 200: 0.006242064759135246
# Training loss value at step 300: 0.0013005617074668407
# Training loss value at step 400: 0.0011169631034135818
# Training loss value at step 500: 0.00046266341814771295
# Training loss value at step 600: 0.0004592079494614154
# Training loss value at step 700: 0.00043930893298238516
# Training accuracy over whole file: 0.9802587032318115
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.00033825874561443925
# Training loss value at step 100: 0.0033186383079737425
# Training loss value at step 200: 0.0051412517204880714
# Training loss value at step 300: 0.00030524839530698955
# Training loss value at step 400: 0.0004805363714694977
# Training loss value at step 500: 0.0004689785710070282
# Training loss value at step 600: 0.0007378716254606843
# Training loss value at step 700: 0.00013493580627255142
# Training accuracy over whole file: 0.9816687703132629
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 9.422718048095703
# Training loss value at step 100: 0.00020215852418914437
# Training loss value at step 200: 0.00023266946664080024
# Training loss value at step 300: 0.0010007378878071904
# Training loss value at step 400: 0.0004532501916401088
# Training loss value at step 500: 0.0006255338666960597
# Training loss value at step 600: 0.000228140561375767
# Training loss value at step 700: 0.00017867876158561558
# Training accuracy over whole file: 0.9813737869262695
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 6.8971662521362305
# Training loss value at step 100: 0.05084091052412987
# Training loss value at step 200: 0.0017183552263304591
# Training loss value at step 300: 0.031277846544981
# Training loss value at step 400: 0.0001546025014249608
# Training loss value at step 500: 0.0013016331940889359
# Training loss value at step 600: 0.02823108248412609
# Training loss value at step 700: 0.00022349244682118297
# Training accuracy over whole file: 0.9811946749687195
# ---------------------------------------------------
# ...
# Training loss value at step 700: 0.00012957210128661245
# Training accuracy over whole file: 0.97651207447052
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 4.461207866668701
# Training loss value at step 100: 0.009202445857226849
# Training loss value at step 200: 0.015364852733910084
# Training loss value at step 300: 0.011553522199392319
# Training loss value at step 400: 0.009873718023300171
# Training loss value at step 500: 0.0030914393719285727
# Training loss value at step 600: 0.0020945770666003227
# Training loss value at step 700: 0.001581966644152999
# Training accuracy over whole file: 0.9763363599777222
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 0.0006349454633891582
# Training loss value at step 100: 0.0007068996201269329
# Training loss value at step 200: 0.005291859619319439
# Training loss value at step 300: 0.00825505144894123
# Training loss value at step 400: 0.013867340050637722
# Training loss value at step 500: 0.00018034738604910672
# Training loss value at step 600: 7.271740287251305e-06
# Training loss value at step 700: 2.8967437174287625e-05
# Training accuracy over whole file: 0.976896345615387
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 0.0004707658663392067
# Training loss value at step 100: 0.0008976006065495312
# Training loss value at step 200: 6.103329360485077e-05
# Training loss value at step 300: 1.1920858014491387e-05
# Training loss value at step 400: 0.0012537722941488028
# Training loss value at step 500: 0.00018142008048016578
# Training loss value at step 600: 0.00017712931730784476
# Training loss value at step 700: 2.312633478140924e-05
# Training accuracy over whole file: 0.9774290323257446
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 11.144328117370605
# Training loss value at step 100: 0.009782824665307999
# Training loss value at step 200: 0.021299084648489952
# Training loss value at step 300: 0.00895153358578682
# Training loss value at step 400: 0.0012194823939353228
# Training loss value at step 500: 0.0010494445450603962
# Training loss value at step 600: 0.0009544108179397881
# Training loss value at step 700: 0.0010181248653680086
# Training accuracy over whole file: 0.9772440195083618
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 9.525382995605469
# Training loss value at step 100: 0.003775256220251322
# Training loss value at step 200: 0.001085883704945445
# Training loss value at step 300: 0.00031406714697368443
# Training loss value at step 400: 0.00031513971043750644
# Training loss value at step 500: 0.0005525015876628458
# Training loss value at step 600: 0.00010609064338495955
# Training loss value at step 700: 0.00014900050882715732
# Training accuracy over whole file: 0.9768911600112915
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 10.401460647583008
# Training loss value at step 100: 0.03695255517959595
# Training loss value at step 200: 0.013458003289997578
# Training loss value at step 300: 0.013459179550409317
# Training loss value at step 400: 0.012360988184809685
# Training loss value at step 500: 0.012694032862782478
# Training loss value at step 600: 0.003884628415107727
# Training loss value at step 700: 0.002506093354895711
# Training accuracy over whole file: 0.9766406416893005
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 3.805171489715576
# Training loss value at step 100: 0.0010768335778266191
# Training loss value at step 200: 0.00031156453769654036
# Training loss value at step 300: 0.00024828212917782366
# Training loss value at step 400: 0.7227217555046082
# Training loss value at step 500: 0.00025519452174194157
# Training loss value at step 600: 1.1920928244535389e-07
# Training loss value at step 700: 5.125986263010418e-06
# Training accuracy over whole file: 0.976401150226593
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 8.228767395019531
# Training loss value at step 100: 0.012771598063409328
# Training loss value at step 200: 0.02168142795562744
# Training loss value at step 300: 0.001456867903470993
# Training loss value at step 400: 0.00033087024348787963
# Training loss value at step 500: 0.00013147920253686607
# Training loss value at step 600: 0.0002723561483435333
# Training loss value at step 700: 0.00048565989709459245
# Training accuracy over whole file: 0.9761446714401245
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.007509574294090271
# Training loss value at step 100: 0.000666277133859694
# Training loss value at step 200: 0.11790456622838974
# Training loss value at step 300: 0.0009891861118376255
# Training loss value at step 400: 0.06423924118280411
# Training loss value at step 500: 0.0017003853572532535
# Training loss value at step 600: 7.271502545336261e-05
# Training loss value at step 700: 5.602820692729438e-06
# Training accuracy over whole file: 0.9761411547660828
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 6.499282360076904
# Training loss value at step 100: 0.0036786997225135565
# Training loss value at step 200: 0.002797620603814721
# Training loss value at step 300: 0.004232021979987621
# Training loss value at step 400: 0.001029557315632701
# Training loss value at step 500: 0.0008665143977850676
# Training loss value at step 600: 0.0019346822518855333
# Training loss value at step 700: 0.00011288482346571982
# Training accuracy over whole file: 0.9761641621589661
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 10.740275382995605
# Training loss value at step 100: 0.002072450239211321
# Training loss value at step 200: 0.0018388995667919517
# Training loss value at step 300: 0.020377803593873978
# Training loss value at step 400: 0.0033105588518083096
# Training loss value at step 500: 0.009181184694170952
# Training loss value at step 600: 0.007594167720526457
# Training loss value at step 700: 0.005468528252094984
# Training accuracy over whole file: 0.9758249521255493
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 11.991622924804688
# Training loss value at step 100: 0.004107373300939798
# Training loss value at step 200: 0.006130699068307877
# Training loss value at step 300: 0.00281461956910789
# Training loss value at step 400: 0.014509523287415504
# Training loss value at step 500: 0.0016943159280344844
# Training loss value at step 600: 0.0019930992275476456
# Training loss value at step 700: 0.0034862712491303682
# Training accuracy over whole file: 0.9755499362945557
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 8.627334594726562
# Training loss value at step 100: 0.019401073455810547
# Training loss value at step 200: 0.008447510190308094
# Training loss value at step 300: 0.0028676362708210945
# Training loss value at step 400: 0.0022980966605246067
# Training loss value at step 500: 0.000993592431768775
# Training loss value at step 600: 0.0003638797497842461
# Training loss value at step 700: 0.0028707266319543123
# Training accuracy over whole file: 0.9753848314285278
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 5.06707763671875
# Training loss value at step 100: 0.0008811643347144127
# Training loss value at step 200: 0.12934629619121552
# Training loss value at step 300: 0.020457111299037933
# Training loss value at step 400: 0.0014607959892600775
# Training loss value at step 500: 0.0016452836571261287
# Training loss value at step 600: 0.003653401043266058
# Training loss value at step 700: 0.007191604934632778
# Training accuracy over whole file: 0.9753233194351196
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 7.932927131652832
# Training loss value at step 100: 0.03536473959684372
# Training loss value at step 200: 0.0029258797876536846
# Training loss value at step 300: 0.016275161877274513
# Training loss value at step 400: 0.0014002051902934909
# Training loss value at step 500: 0.0010008569806814194
# Training loss value at step 600: 0.002344718435779214
# Training loss value at step 700: 0.00023064337437972426
# Training accuracy over whole file: 0.9750971794128418
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 17.630910873413086
# Training loss value at step 100: 0.0380859412252903
# Training loss value at step 200: 0.0013230626937001944
# Training loss value at step 300: 0.00986427441239357
# Training loss value at step 400: 0.0004889961564913392
# Training loss value at step 500: 0.0009495278936810791
# Training loss value at step 600: 0.000800408364739269
# Training loss value at step 700: 0.0005081792478449643
# Training accuracy over whole file: 0.9748560190200806
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 0.0012311505852267146
# Training loss value at step 100: 0.0015373327769339085
# Training loss value at step 200: 0.0004551566671580076
# Training loss value at step 300: 0.000500196241773665
# Training loss value at step 400: 0.0003864018653985113
# Training loss value at step 500: 0.00422976678237319
# Training loss value at step 600: 0.0007602662080898881
# Training loss value at step 700: 0.0006291079334914684
# Training accuracy over whole file: 0.9752901792526245
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 8.050878524780273
# Training loss value at step 100: 0.01897270791232586
# Training loss value at step 200: 0.020290780812501907
# Training loss value at step 300: 0.0007571690948680043
# Training loss value at step 400: 0.0023778993636369705
# Training loss value at step 500: 0.004629489034414291
# Training loss value at step 600: 0.0022053224965929985
# Training loss value at step 700: 0.0022182876709848642
# Training accuracy over whole file: 0.9751670360565186
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 0.0006042085005901754
# Training loss value at step 100: 0.0002818902430590242
# Training loss value at step 200: 0.0003084660565946251
# Training loss value at step 300: 0.0008931938209570944
# Training loss value at step 400: 0.00046492734691128135
# Training loss value at step 500: 0.0039013714995235205
# Training loss value at step 600: 0.0005287918029353023
# Training loss value at step 700: 0.0005279577453620732
# Training accuracy over whole file: 0.9755805730819702
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 7.656830787658691
# Training loss value at step 100: 0.0230198185890913
# Training loss value at step 200: 0.0072564613074064255
# Training loss value at step 300: 0.04564771056175232
# Training loss value at step 400: 0.002220785478129983
# Training loss value at step 500: 0.0018830440239980817
# Training loss value at step 600: 0.0021878371480852365
# Training loss value at step 700: 0.0014248467050492764
# Training accuracy over whole file: 0.9754348397254944
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.07674427330493927
# Training loss value at step 100: 8.320462075062096e-05
# Training loss value at step 200: 8.821448318485636e-06
# Training loss value at step 300: 0.0004400238685775548
# Training loss value at step 400: 0.03437501937150955
# Training loss value at step 500: 0.0003471963864285499
# Training loss value at step 600: 0.20218192040920258
# Training loss value at step 700: 0.007286402862519026
# Training accuracy over whole file: 0.9753583669662476
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.0
# Training loss value at step 100: 0.0
# Training loss value at step 200: 0.0
# Training loss value at step 300: 0.0
# Training loss value at step 400: 0.0049362932331860065
# Training loss value at step 500: 0.002404776168987155
# Training loss value at step 600: 7.283422019099817e-05
# Training loss value at step 700: 0.00011991735664196312
# Training accuracy over whole file: 0.97576904296875
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 8.574874877929688
# Training loss value at step 100: 0.013561970554292202
# Training loss value at step 200: 0.0023818237241357565
# Training loss value at step 300: 0.00028153270250186324
# Training loss value at step 400: 0.0012894895626232028
# Training loss value at step 500: 0.013744710013270378
# Training loss value at step 600: 0.007484727073460817
# Training loss value at step 700: 0.021319271996617317
# Training accuracy over whole file: 0.9755652546882629
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.00103265349753201
# Training loss value at step 100: 0.00037901371251791716
# Training loss value at step 200: 0.0005639393348246813
# Training loss value at step 300: 2.3841855067985307e-07
# Training loss value at step 400: 8.260862523457035e-05
# Training loss value at step 500: 0.0168532095849514
# Training loss value at step 600: 5.328513361746445e-05
# Training loss value at step 700: 1.5258672647178173e-05
# Training accuracy over whole file: 0.9755923748016357
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 4.317446708679199
# Training loss value at step 100: 0.00444044778123498
# Training loss value at step 200: 0.01094151008874178
# Training loss value at step 300: 0.0008407871937379241
# Training loss value at step 400: 0.004408997017890215
# Training loss value at step 500: 0.0027296210173517466
# Training loss value at step 600: 0.000567275274079293
# Training loss value at step 700: 0.00011359999916749075
# Training accuracy over whole file: 0.9756386280059814
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 7.367872714996338
# Training loss value at step 100: 0.0019133847672492266
# Training loss value at step 200: 0.002007613657042384
# Training loss value at step 300: 0.012810908257961273
# Training loss value at step 400: 0.0005840741214342415
# Training loss value at step 500: 0.013588078320026398
# Training loss value at step 600: 0.001629216712899506
# Training loss value at step 700: 0.0013074668822810054
# Training accuracy over whole file: 0.975347638130188
# ---------------------------------------------------
# --------------------------------------------------------------
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.dense.Dense object at 0x28350fa10>, because it is not built.
# INFO:tensorflow:Assets written to: models/trained_LSTM_e2_5_20_cross/assets
# INFO:tensorflow:Assets written to: models/trained_LSTM_e2_5_20_cross/assets

# %%
new_model = keras.models.load_model("models/trained_LSTM_e2_5_20_cross")
new_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "just_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm1 (LSTM)                multiple                  21520
#
#  lstm2 (LSTM)                multiple                  3280
#
#  dense (Dense)               multiple                  0
#
#  output (Dense)              multiple                  84
#
# =================================================================
# Total params: 24884 (97.20 KB)
# Trainable params: 24884 (97.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_arr = [tensor.numpy() for tensor in losses]

# %%
print(loss_arr)
# Out:
# [0.9465862, 1.7282428, 2.5975618, 3.5831525, 4.6258883]

# %%
acc_arr = [tensor.numpy() for tensor in accuracies]

# %%
print(acc_arr)
# Out:
# [7.8886747, 15.742188, 23.555962, 31.364145, 39.15895]
