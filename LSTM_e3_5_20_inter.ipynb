# %%
import re
import random
import os
import numpy as np
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import LabelBinarizer

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import logging
from sklearn.preprocessing import LabelBinarizer


class JustLSTM(keras.Model):
    def __init__(self, input_shape, timeframe, LSTM_units, dense_units, num_classes=4):
        super().__init__()

        # TODO: kijken of we input shape niet uit elkaar trekken in width, height, batch_size en timesteps (nu num_segments)
        self.in_shape = input_shape
        self.num_classes = num_classes
        self.LSTM_units = LSTM_units

        # The number of images / timesteps that we will look at for each training step
        self.timeframe = timeframe

        self.lstm1 = keras.layers.LSTM(self.LSTM_units, return_sequences=True, name="lstm1")
        self.lstm2 = keras.layers.LSTM(self.LSTM_units, name="lstm2")

        self.fc = keras.layers.Dense(dense_units, activation="relu")

        self.out = keras.layers.Dense(self.num_classes, activation="softmax", name="output")

    def call(self, inputs, training=True, mask=None):
        """
        Specifies how the inputs should be passed through the layers of the model and returns the output

        :param inputs: the inputs to be classified by the model, with the same shape as self.in_shape
        :param training: whether the gradients should be tracked
        :param mask: whether a certain mask should be applied on the inputs (such as masking certain timesteps)
        :return: probabilities for each of the classes
        """

        input_layer = keras.layers.InputLayer(self.in_shape, name="input")(inputs)

        # Pass the timesteps through the RNN to find temporal features The amount of units in the layer are equal to
        # the number of timesteps (i.e. segments) according to Zhang et al. (2018)
        lstm1 = self.lstm1(input_layer)
        lstm2 = self.lstm2(lstm1)

        #fc = self.fc(lstm2)

        # Final fully connected layer with softmax to give class probabilities
        output = self.out(lstm2)

        return output

    def build_graph(self):
        """
        Builds the Tensor Graph in order to generate a summary of the model by running dummy input through the model
        :return: a 'dummy' version of the model of which we can generate a summary
        """
        x = keras.Input(self.in_shape)
        return keras.Model(inputs=[x], outputs=self.call(x))

# %%
def create_windows(dataset, model_type, timeframe):
    # Will contain the slices of the dataset that represent the different windows
    windows = []

    if model_type == "cascade":
        num_windows = int(dataset.shape[2] / timeframe)
    else:
        num_windows = int(dataset.shape[1] / timeframe)

    i = timeframe
    j = 0
    count = 0

    # Loop through the dataset until we have the specified number of windows (might cut off some of the last timesteps)
    while count < num_windows:
        # Save the view of the array in the windows list
        if model_type == "cascade":
            view = dataset[:, :, j:i]
        else:
            view = dataset[:, j:i]
        windows.append(view)

        i += timeframe
        j += timeframe
        count += 1
    # Return the list of array views
    return windows


def read_prepro_file(data_path):
    hfive = h5py.File(data_path, 'r')
    matrix = hfive.get('dir')
    matrix = np.array(matrix)
    return matrix

# %%
import tensorflow as tf
from tensorflow import keras
import re
import os
import random
import numpy as np


# tf function zal niet heel veel uitmaken volgens de documentatie, omdat wij veel convolutional operations hebben (waarbij de speedup dus meevalt)
def train_epoch(model, x_train, y_train, optimizer, train_acc):
    # Instantiate an optimizer and loss function
    loss_function = keras.losses.CategoricalCrossentropy()

    total_loss = 0

    # Doet nu nog wel een update per window, wellicht veel? We kunnen ook nog batches gaan gebruiken om het aantal updates te reduceren
    for step in range(len(x_train)):
        # Used to track the gradients during the forward pass
        with tf.GradientTape() as tape:
            logits = model(tf.expand_dims(x_train[step], axis=0), training=True)
            # Calculate the loss value
            loss_value = loss_function(y_train[step], logits)

        total_loss += loss_value

        # Extract the gradients from the gradienttape
        grads = tape.gradient(loss_value, model.trainable_weights)

        # Perform a weight update step using the extracted gradients
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        # Keep track of the training accuracy which is given at the end of the loop
        train_acc.update_state(y_train[step], logits)

        # Report the training loss for monitoring
        if step % 100 == 0:
            print("Training loss value at step {}: {}".format(step, loss_value))

    print("Training accuracy over whole file: {}".format(train_acc.result()))
    print("---------------------------------------------------")
    average_loss = total_loss / len(x_train)
    return average_loss, train_acc


# TODO: kijken of we de input als tensors willen doen (wat wel netter is I guess) of makkelijker als np arrays --> netwerk vindt allebei goed
def fit_eight(model, model_type, dirlist, parent_path, optimizer, timeframe, label_encoder,
              train_acc_obj):  # Fit a network on 8 datafiles at a time.
    fit_list = []
    average_loss = 0
    i = 0
    j = 0
    while i < 8:  # Load the 8 datafiles
        filename = parent_path + "/" + dirlist[i]

        data = read_prepro_file(filename)
        label = extract_label(filename)

        fit_list.append((data, label))
        i += 1

    for counter, (data, label) in enumerate(fit_list):
        print("Fitting on file {} containing task: {}".format((counter + 1), label))
        # Creates windows of length 'timeframe' to fit the model on
        windows = create_windows(data, model_type, timeframe)
        x_train = []
        # Only needed for CascadeNet, not for the LSTM network
        for window in windows:
            if model_type == "cascade":
                x_train.append(tf.convert_to_tensor(window))
            else:
                x_train.append(tf.convert_to_tensor(np.transpose(window)))

        # Encode the textual label to one-hot-encoding
        encoded_label = label_encoder.transform([label])
        # Create a list of tensors, each corresponding to an encoded label
        y_train = [tf.convert_to_tensor(encoded_label)] * len(x_train)

        # Fit the model on the data from this specific file
        average_loss, train_acc_obj = train_epoch(model, x_train, y_train, optimizer, train_acc_obj)

    return average_loss, train_acc_obj


def train_dir(model, model_type, dirpath, epochs, timeframe, optimizer, label_encoder,
              shuffle=True):  # Train a network on a given directory
    dirnames = os.listdir(dirpath)  # get list of all filenames
    random.shuffle(dirnames)
    batches = len(dirnames) // 8  # int divide by eight to avoid float errors

    train_acc_obj = keras.metrics.CategoricalAccuracy()

    average_epoch_accuracy = 0
    average_epoch_loss = 0
    losses = []
    accuracies = []

    # Check if it is divisible by eight
    if not (len(dirnames) % 8) == 0:
        raise TypeError("Not divisible by eight")

    for epoch in range(epochs):
        print("Starting epoch {}".format(epoch + 1))
        print()
        train_acc_obj.reset_states()
        for i in range(batches):  # Fit on 8 batches at a time                HIER IPV 1 WEER 'BATCHES' NEERZETTEN
            print("Fitting on files {}-{}....".format((i * 8), ((i + 1) * 8)))
            # Fits the model on 8 files for the specified amount of epochs
            average_loss, train_acc_obj = fit_eight(model, model_type, dirnames[i * 8:(i + 1) * 8], dirpath, optimizer,
                                                    timeframe, label_encoder, train_acc_obj)
            average_epoch_loss += average_loss
            average_epoch_accuracy += train_acc_obj.result()

            print("--------------------------------------------------------------")

        losses.append(average_epoch_loss)
        accuracies.append(average_epoch_accuracy)

    # SAVE THE MODEL AFTER TRAINING!!!!
    model.save("models/trained_LSTM_e3_5_20_intra")

    return model, losses, accuracies


def extract_label(filename):  # Extract the label out of a filename
    filename = filename.split("/")
    pattern = r'_\d'
    split = re.split(pattern, filename[-1])
    return split[0]

# %%
from sklearn.preprocessing import LabelBinarizer
import tensorflow
from tensorflow import keras

output_classes = 4

# Hyperparameters
timeframe = 5
LSTM_units = 20
# (1e-2, 1e-3, 1e-4)
learning_rate = 1e-3

epochs = 5



textual_labels = ["rest", "task_motor", "task_story_math", "task_working_memory"]
label_encoder = LabelBinarizer()
label_encoder.fit(textual_labels)

model = JustLSTM((timeframe, 248), timeframe, LSTM_units, 16, output_classes)
model_type = "lstm"

optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

model, losses, accuracies = train_dir(model, model_type, "data/Intra/train_prepro", epochs, timeframe, optimizer, label_encoder)
# Out:
# Starting epoch 1
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 1.5104531049728394
# Training loss value at step 100: 0.007600792683660984
# Training loss value at step 200: 0.004450654145330191
# Training loss value at step 300: 0.001280084135942161
# Training loss value at step 400: 0.014787588268518448
# Training loss value at step 500: 0.0004818470624741167
# Training loss value at step 600: 0.0005974177038297057
# Training loss value at step 700: 0.00029952809563837945
# Training accuracy over whole file: 0.992414653301239
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 9.47115707397461
# Training loss value at step 100: 0.018804024904966354
# Training loss value at step 200: 0.00761215016245842
# Training loss value at step 300: 0.005291859619319439
# Training loss value at step 400: 0.05983579158782959
# Training loss value at step 500: 0.0027336629573255777
# Training loss value at step 600: 0.001973706530407071
# Training loss value at step 700: 0.0009132028790190816
# Training accuracy over whole file: 0.9886220097541809
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.0006212450098246336
# Training loss value at step 100: 0.0005667987279593945
# Training loss value at step 200: 0.0005211663665249944
# Training loss value at step 300: 0.0004412154376041144
# Training loss value at step 400: 0.046445079147815704
# Training loss value at step 500: 0.00054058717796579
# Training loss value at step 600: 0.0007165487040765584
# Training loss value at step 700: 0.00035375059815123677
# Training accuracy over whole file: 0.992414653301239
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 9.460824012756348
# Training loss value at step 100: 0.014014054089784622
# Training loss value at step 200: 0.004922058433294296
# Training loss value at step 300: 0.0032620809506624937
# Training loss value at step 400: 0.005209680180996656
# Training loss value at step 500: 0.003528561210259795
# Training loss value at step 600: 0.0037054228596389294
# Training loss value at step 700: 0.0013368725776672363
# Training accuracy over whole file: 0.9902022480964661
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.011943024583160877
# Training loss value at step 100: 0.001257463125512004
# Training loss value at step 200: 0.0008087463211268187
# Training loss value at step 300: 0.0014182995073497295
# Training loss value at step 400: 0.00096941675292328
# Training loss value at step 500: 0.00031323294388130307
# Training loss value at step 600: 0.0003238391946069896
# Training loss value at step 700: 0.0007370378007180989
# Training accuracy over whole file: 0.9921618103981018
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 9.844508171081543
# Training loss value at step 100: 0.025451751425862312
# Training loss value at step 200: 0.176481693983078
# Training loss value at step 300: 0.003704235190525651
# Training loss value at step 400: 0.0030774159822613
# Training loss value at step 500: 0.002730215433984995
# Training loss value at step 600: 0.0035367575474083424
# Training loss value at step 700: 0.003284894395619631
# Training accuracy over whole file: 0.9869363903999329
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 4.565389156341553
# Training loss value at step 100: 0.005426201969385147
# Training loss value at step 200: 0.0031491946429014206
# Training loss value at step 300: 0.010848944075405598
# Training loss value at step 400: 0.0035697801504284143
# Training loss value at step 500: 0.0006079017766751349
# Training loss value at step 600: 0.007011096924543381
# Training loss value at step 700: 0.0002762889489531517
# Training accuracy over whole file: 0.9866353869438171
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.0018736441852524877
# Training loss value at step 100: 0.00017593742813915014
# Training loss value at step 200: 0.00022301571152638644
# Training loss value at step 300: 0.00021431533969007432
# Training loss value at step 400: 0.0002829628065228462
# Training loss value at step 500: 0.00015937011630740017
# Training loss value at step 600: 0.00013326710904948413
# Training loss value at step 700: 0.000125281119835563
# Training accuracy over whole file: 0.9881479144096375
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 0.00014280252798926085
# Training loss value at step 100: 0.00014065706636756659
# Training loss value at step 200: 0.00016449528629891574
# Training loss value at step 300: 0.00020311199477873743
# Training loss value at step 400: 0.00020680672605521977
# Training loss value at step 500: 0.0001382732152706012
# Training loss value at step 600: 7.319182623177767e-05
# Training loss value at step 700: 9.238292841473594e-05
# Training accuracy over whole file: 0.9894648194313049
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 6.385381698608398
# Training loss value at step 100: 0.004369355272501707
# Training loss value at step 200: 0.0027167813386768103
# Training loss value at step 300: 0.009668665006756783
# Training loss value at step 400: 0.003889378160238266
# Training loss value at step 500: 0.0013306819600984454
# Training loss value at step 600: 0.0015805383445695043
# Training loss value at step 700: 0.0038409284316003323
# Training accuracy over whole file: 0.9891276955604553
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 4.587266445159912
# Training loss value at step 100: 0.009979120455682278
# Training loss value at step 200: 0.001157209975644946
# Training loss value at step 300: 0.0010606384603306651
# Training loss value at step 400: 0.003026312217116356
# Training loss value at step 500: 0.05428033322095871
# Training loss value at step 600: 0.00782070029526949
# Training loss value at step 700: 0.0005315321614034474
# Training accuracy over whole file: 0.9888518452644348
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.00017236177518498152
# Training loss value at step 100: 0.00013517419574782252
# Training loss value at step 200: 0.00015162272029556334
# Training loss value at step 300: 0.00026639728457666934
# Training loss value at step 400: 0.0004153581103309989
# Training loss value at step 500: 0.00030298411729745567
# Training loss value at step 600: 0.0007061848300509155
# Training loss value at step 700: 0.0002946419408544898
# Training accuracy over whole file: 0.989780843257904
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.00010668662434909493
# Training loss value at step 100: 0.00016592556494288146
# Training loss value at step 200: 0.00021431533969007432
# Training loss value at step 300: 0.00023684080224484205
# Training loss value at step 400: 0.0002520958660170436
# Training loss value at step 500: 7.521823135903105e-05
# Training loss value at step 600: 7.164221460698172e-05
# Training loss value at step 700: 6.806619057897478e-05
# Training accuracy over whole file: 0.9905669689178467
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.00011586471373448148
# Training loss value at step 100: 9.369411418447271e-05
# Training loss value at step 200: 7.784063927829266e-05
# Training loss value at step 300: 0.00012146688823122531
# Training loss value at step 400: 0.00015758226800244302
# Training loss value at step 500: 6.878139538457617e-05
# Training loss value at step 600: 0.00010096516780322418
# Training loss value at step 700: 0.00019965562387369573
# Training accuracy over whole file: 0.9912407398223877
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 10.155436515808105
# Training loss value at step 100: 0.0035569514147937298
# Training loss value at step 200: 0.0015256681945174932
# Training loss value at step 300: 0.010606818832457066
# Training loss value at step 400: 0.0010986251290887594
# Training loss value at step 500: 0.0016098171472549438
# Training loss value at step 600: 0.001970613142475486
# Training loss value at step 700: 0.005358973518013954
# Training accuracy over whole file: 0.9897176623344421
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 10.90947437286377
# Training loss value at step 100: 0.010866986587643623
# Training loss value at step 200: 0.001214005402289331
# Training loss value at step 300: 0.003221324644982815
# Training loss value at step 400: 0.001354015665128827
# Training loss value at step 500: 0.0004668337933253497
# Training loss value at step 600: 0.0011843579122796655
# Training loss value at step 700: 0.0009833505610004067
# Training accuracy over whole file: 0.9871207475662231
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 7.048874378204346
# Training loss value at step 100: 0.028283579275012016
# Training loss value at step 200: 0.007884570397436619
# Training loss value at step 300: 0.0064308843575417995
# Training loss value at step 400: 0.04041927307844162
# Training loss value at step 500: 0.004680273588746786
# Training loss value at step 600: 0.0026102541014552116
# Training loss value at step 700: 0.003153829136863351
# Training accuracy over whole file: 0.9852755069732666
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 7.6045823097229
# Training loss value at step 100: 0.06328698992729187
# Training loss value at step 200: 0.10893983393907547
# Training loss value at step 300: 0.0014805557439103723
# Training loss value at step 400: 0.005005803424865007
# Training loss value at step 500: 0.0022846567444503307
# Training loss value at step 600: 0.004064988810569048
# Training loss value at step 700: 0.000426439888542518
# Training accuracy over whole file: 0.984197199344635
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 7.032475471496582
# Training loss value at step 100: 0.07098989188671112
# Training loss value at step 200: 0.03204449638724327
# Training loss value at step 300: 0.01571156643331051
# Training loss value at step 400: 0.01264800876379013
# Training loss value at step 500: 0.008728092536330223
# Training loss value at step 600: 0.005227112676948309
# Training loss value at step 700: 0.0009382136631757021
# Training accuracy over whole file: 0.9824339747428894
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 6.7852888107299805
# Training loss value at step 100: 0.004909484181553125
# Training loss value at step 200: 0.004899994004517794
# Training loss value at step 300: 0.001917668036185205
# Training loss value at step 400: 0.0012491289526224136
# Training loss value at step 500: 0.004796546418219805
# Training loss value at step 600: 0.00027378625236451626
# Training loss value at step 700: 0.00205781776458025
# Training accuracy over whole file: 0.9815423488616943
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 8.361241340637207
# Training loss value at step 100: 0.41764211654663086
# Training loss value at step 200: 0.01560958381742239
# Training loss value at step 300: 0.021695192903280258
# Training loss value at step 400: 0.005353874992579222
# Training loss value at step 500: 0.009166892617940903
# Training loss value at step 600: 0.004488037899136543
# Training loss value at step 700: 0.0024434253573417664
# Training accuracy over whole file: 0.9809162616729736
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 0.0064416625536978245
# Training loss value at step 100: 0.0017575069796293974
# Training loss value at step 200: 0.001976205036044121
# Training loss value at step 300: 0.002797977067530155
# Training loss value at step 400: 0.0025584129616618156
# Training loss value at step 500: 0.0022644372656941414
# Training loss value at step 600: 0.0024831434711813927
# Training loss value at step 700: 0.0023557788226753473
# Training accuracy over whole file: 0.9817836880683899
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 8.492240905761719
# Training loss value at step 100: 0.002568757627159357
# Training loss value at step 200: 0.002097907941788435
# Training loss value at step 300: 0.008235188201069832
# Training loss value at step 400: 0.004077930003404617
# Training loss value at step 500: 0.007210778072476387
# Training loss value at step 600: 0.0030633925925940275
# Training loss value at step 700: 0.0021506056655198336
# Training accuracy over whole file: 0.9807618260383606
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 7.482705593109131
# Training loss value at step 100: 0.06972000747919083
# Training loss value at step 200: 0.2002706080675125
# Training loss value at step 300: 0.007575119845569134
# Training loss value at step 400: 0.03854714706540108
# Training loss value at step 500: 0.008990757167339325
# Training loss value at step 600: 0.0052758511155843735
# Training loss value at step 700: 0.0009114163694903255
# Training accuracy over whole file: 0.9801411628723145
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 7.810062408447266
# Training loss value at step 100: 0.007908224128186703
# Training loss value at step 200: 0.00032145579461939633
# Training loss value at step 300: 9.524368942948058e-05
# Training loss value at step 400: 0.0005800233921036124
# Training loss value at step 500: 0.0017863045213744044
# Training loss value at step 600: 0.0003592322755139321
# Training loss value at step 700: 0.0003411188081372529
# Training accuracy over whole file: 0.9794184565544128
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 14.212532997131348
# Training loss value at step 100: 0.12388359010219574
# Training loss value at step 200: 0.0003847335756290704
# Training loss value at step 300: 0.0003873551613651216
# Training loss value at step 400: 0.000436091679148376
# Training loss value at step 500: 0.002435576869174838
# Training loss value at step 600: 0.0020067808218300343
# Training loss value at step 700: 0.005245019216090441
# Training accuracy over whole file: 0.9787513613700867
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 9.568680763244629
# Training loss value at step 100: 0.04999726265668869
# Training loss value at step 200: 0.03694865107536316
# Training loss value at step 300: 0.004261698108166456
# Training loss value at step 400: 0.03796658664941788
# Training loss value at step 500: 0.026172945275902748
# Training loss value at step 600: 0.0009868042543530464
# Training loss value at step 700: 0.000812915270216763
# Training accuracy over whole file: 0.9784613847732544
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.00011455356434453279
# Training loss value at step 100: 0.0006853376980870962
# Training loss value at step 200: 0.024570930749177933
# Training loss value at step 300: 0.000896052282769233
# Training loss value at step 400: 0.001606365549378097
# Training loss value at step 500: 0.0013069906271994114
# Training loss value at step 600: 0.00038378025055862963
# Training loss value at step 700: 0.0004059444472659379
# Training accuracy over whole file: 0.9791854619979858
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 11.403280258178711
# Training loss value at step 100: 0.009945482015609741
# Training loss value at step 200: 0.0010544460965320468
# Training loss value at step 300: 0.0010159813100472093
# Training loss value at step 400: 0.2985721826553345
# Training loss value at step 500: 0.004368999041616917
# Training loss value at step 600: 0.002420355100184679
# Training loss value at step 700: 7.652943895664066e-05
# Training accuracy over whole file: 0.9783774614334106
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 8.124754905700684
# Training loss value at step 100: 0.011246737092733383
# Training loss value at step 200: 0.17325197160243988
# Training loss value at step 300: 0.006785801146179438
# Training loss value at step 400: 0.003461561631411314
# Training loss value at step 500: 0.0012504386249929667
# Training loss value at step 600: 0.0015697074122726917
# Training loss value at step 700: 0.001470794901251793
# Training accuracy over whole file: 0.9779604077339172
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 7.294920921325684
# Training loss value at step 100: 0.028366317972540855
# Training loss value at step 200: 0.01752440445125103
# Training loss value at step 300: 0.007305219303816557
# Training loss value at step 400: 0.009717186912894249
# Training loss value at step 500: 0.004034119658172131
# Training loss value at step 600: 0.0041139028035104275
# Training loss value at step 700: 0.002707627136260271
# Training accuracy over whole file: 0.9767953753471375
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 4.082424163818359
# Training loss value at step 100: 0.00962982140481472
# Training loss value at step 200: 0.00686856172978878
# Training loss value at step 300: 0.010655649937689304
# Training loss value at step 400: 0.005532785318791866
# Training loss value at step 500: 0.0018284284742549062
# Training loss value at step 600: 0.0025567482225596905
# Training loss value at step 700: 0.002342339837923646
# Training accuracy over whole file: 0.9765723943710327
# ---------------------------------------------------
# --------------------------------------------------------------
# Starting epoch 2
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 6.895834922790527
# Training loss value at step 100: 0.016758259385824203
# Training loss value at step 200: 0.007072532549500465
# Training loss value at step 300: 0.017313532531261444
# Training loss value at step 400: 0.040769312530756
# Training loss value at step 500: 0.0017492959741503
# Training loss value at step 600: 0.00990487914532423
# Training loss value at step 700: 0.0016058895271271467
# Training accuracy over whole file: 0.9620733261108398
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 8.12682056427002
# Training loss value at step 100: 0.03670598194003105
# Training loss value at step 200: 0.010565770789980888
# Training loss value at step 300: 0.006986001040786505
# Training loss value at step 400: 0.018857136368751526
# Training loss value at step 500: 0.002174633787944913
# Training loss value at step 600: 0.0011793570592999458
# Training loss value at step 700: 0.0011139861308038235
# Training accuracy over whole file: 0.9620733261108398
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.0015891077928245068
# Training loss value at step 100: 0.0011212497483938932
# Training loss value at step 200: 0.0010711177019402385
# Training loss value at step 300: 0.00030179237364791334
# Training loss value at step 400: 0.006377227138727903
# Training loss value at step 500: 0.0019014865392819047
# Training loss value at step 600: 0.0003761537664104253
# Training loss value at step 700: 0.000296310376143083
# Training accuracy over whole file: 0.974715530872345
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 4.351430892944336
# Training loss value at step 100: 0.013606659136712551
# Training loss value at step 200: 0.0045014480128884315
# Training loss value at step 300: 0.00915413536131382
# Training loss value at step 400: 0.001754293916746974
# Training loss value at step 500: 0.017273344099521637
# Training loss value at step 600: 0.011769145727157593
# Training loss value at step 700: 0.0020192726515233517
# Training accuracy over whole file: 0.9734513163566589
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.0002946419408544898
# Training loss value at step 100: 0.0012919898144900799
# Training loss value at step 200: 0.000631848000921309
# Training loss value at step 300: 0.0009098681039176881
# Training loss value at step 400: 0.0004520586517173797
# Training loss value at step 500: 7.366862701019272e-05
# Training loss value at step 600: 5.340433563105762e-05
# Training loss value at step 700: 0.0005410637822933495
# Training accuracy over whole file: 0.9785082340240479
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 9.249448776245117
# Training loss value at step 100: 0.05766373872756958
# Training loss value at step 200: 0.5385481119155884
# Training loss value at step 300: 0.006327949929982424
# Training loss value at step 400: 0.0030171608086675406
# Training loss value at step 500: 0.0034905478823930025
# Training loss value at step 600: 0.0028700134716928005
# Training loss value at step 700: 0.004868438933044672
# Training accuracy over whole file: 0.9734513163566589
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.09013441950082779
# Training loss value at step 100: 0.0013173482147976756
# Training loss value at step 200: 0.0014946014853194356
# Training loss value at step 300: 0.2593710720539093
# Training loss value at step 400: 0.0007936188485473394
# Training loss value at step 500: 0.00025602878304198384
# Training loss value at step 600: 0.0001517419150331989
# Training loss value at step 700: 0.00017581824795342982
# Training accuracy over whole file: 0.9754379391670227
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.00044764988706447184
# Training loss value at step 100: 0.00035208225017413497
# Training loss value at step 200: 0.0003545847721397877
# Training loss value at step 300: 0.00020776021119672805
# Training loss value at step 400: 0.00012885693286079913
# Training loss value at step 500: 8.666139910928905e-05
# Training loss value at step 600: 0.0001784403866622597
# Training loss value at step 700: 4.136476854910143e-05
# Training accuracy over whole file: 0.9783501625061035
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 0.00031132620642893016
# Training loss value at step 100: 0.0001392267586197704
# Training loss value at step 200: 0.0006275591440498829
# Training loss value at step 300: 0.0004891153075732291
# Training loss value at step 400: 0.00016544880054425448
# Training loss value at step 500: 0.0001573438785271719
# Training loss value at step 600: 4.768258077092469e-05
# Training loss value at step 700: 5.721882189391181e-05
# Training accuracy over whole file: 0.9807557463645935
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 0.02227967604994774
# Training loss value at step 100: 0.0031382618471980095
# Training loss value at step 200: 0.0011822147062048316
# Training loss value at step 300: 0.06543804705142975
# Training loss value at step 400: 0.002041757572442293
# Training loss value at step 500: 0.03065617009997368
# Training loss value at step 600: 0.0014330603880807757
# Training loss value at step 700: 0.0008465044084005058
# Training accuracy over whole file: 0.9815423488616943
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 8.333580017089844
# Training loss value at step 100: 0.008363342843949795
# Training loss value at step 200: 0.0011981697753071785
# Training loss value at step 300: 0.0005068686441518366
# Training loss value at step 400: 0.006288502831012011
# Training loss value at step 500: 0.0003159739135298878
# Training loss value at step 600: 0.000192504478036426
# Training loss value at step 700: 9.77468371274881e-05
# Training accuracy over whole file: 0.9804620146751404
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.0005286726518534124
# Training loss value at step 100: 0.0002450642641633749
# Training loss value at step 200: 0.00015031162183731794
# Training loss value at step 300: 9.238292841473594e-05
# Training loss value at step 400: 0.0004042761866003275
# Training loss value at step 500: 0.0002299282787134871
# Training loss value at step 600: 0.00013171759201213717
# Training loss value at step 700: 0.004346091765910387
# Training accuracy over whole file: 0.982090175151825
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.0003494605771265924
# Training loss value at step 100: 0.00036590558011084795
# Training loss value at step 200: 7.509902934543788e-05
# Training loss value at step 300: 0.00016127715934999287
# Training loss value at step 400: 0.00015615197480656207
# Training loss value at step 500: 6.794698856538162e-05
# Training loss value at step 600: 0.0002908283786382526
# Training loss value at step 700: 7.545663538621739e-05
# Training accuracy over whole file: 0.9834678769111633
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 8.618460560683161e-05
# Training loss value at step 100: 6.961580220377073e-05
# Training loss value at step 200: 0.00010156115604331717
# Training loss value at step 300: 8.082063141046092e-05
# Training loss value at step 400: 9.119095193454996e-05
# Training loss value at step 500: 0.0001081169830285944
# Training loss value at step 600: 0.00011312322021694854
# Training loss value at step 700: 8.606540359323844e-05
# Training accuracy over whole file: 0.9846487045288086
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 8.518455505371094
# Training loss value at step 100: 0.0008374521275982261
# Training loss value at step 200: 0.0006995138246566057
# Training loss value at step 300: 0.0006119524477981031
# Training loss value at step 400: 0.0006313714548014104
# Training loss value at step 500: 0.0002989322238136083
# Training loss value at step 600: 0.004764394834637642
# Training loss value at step 700: 0.00022599527437705547
# Training accuracy over whole file: 0.9840707778930664
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 10.043362617492676
# Training loss value at step 100: 0.0007457336178049445
# Training loss value at step 200: 0.0007855190197005868
# Training loss value at step 300: 0.0009729895391501486
# Training loss value at step 400: 0.00034791138023138046
# Training loss value at step 500: 0.00036090059438720345
# Training loss value at step 600: 0.0022357723210006952
# Training loss value at step 700: 0.0003951007383875549
# Training accuracy over whole file: 0.9828540086746216
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 11.577729225158691
# Training loss value at step 100: 0.006828543730080128
# Training loss value at step 200: 0.022794373333454132
# Training loss value at step 300: 0.0066489181481301785
# Training loss value at step 400: 0.0026372435968369246
# Training loss value at step 500: 0.0010638536186888814
# Training loss value at step 600: 0.013337675482034683
# Training loss value at step 700: 0.0008819981012493372
# Training accuracy over whole file: 0.9801442623138428
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 8.84716510772705
# Training loss value at step 100: 0.04662691429257393
# Training loss value at step 200: 0.039038293063640594
# Training loss value at step 300: 0.005498760379850864
# Training loss value at step 400: 0.0017347777029499412
# Training loss value at step 500: 0.0078344214707613
# Training loss value at step 600: 0.007276343181729317
# Training loss value at step 700: 0.0012144817737862468
# Training accuracy over whole file: 0.9787189364433289
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 6.923775672912598
# Training loss value at step 100: 0.021824900060892105
# Training loss value at step 200: 0.04012683033943176
# Training loss value at step 300: 0.0041396645829081535
# Training loss value at step 400: 0.0014466306893154979
# Training loss value at step 500: 0.00020180096908006817
# Training loss value at step 600: 0.0005472592893056571
# Training loss value at step 700: 0.00034791138023138046
# Training accuracy over whole file: 0.9776432514190674
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 2.6045196056365967
# Training loss value at step 100: 0.013452005572617054
# Training loss value at step 200: 0.005710359662771225
# Training loss value at step 300: 0.00490450207144022
# Training loss value at step 400: 0.0041558099910616875
# Training loss value at step 500: 0.008943499065935612
# Training loss value at step 600: 0.00453467620536685
# Training loss value at step 700: 0.0030358200892806053
# Training accuracy over whole file: 0.9775600433349609
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 5.7070722579956055
# Training loss value at step 100: 0.4928087592124939
# Training loss value at step 200: 0.005511208903044462
# Training loss value at step 300: 0.004897028673440218
# Training loss value at step 400: 0.0035709680523723364
# Training loss value at step 500: 0.004443770740181208
# Training loss value at step 600: 0.003911108709871769
# Training loss value at step 700: 0.0023820616770535707
# Training accuracy over whole file: 0.9771838188171387
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 0.0018205749802291393
# Training loss value at step 100: 0.0007662221323698759
# Training loss value at step 200: 0.0021111122332513332
# Training loss value at step 300: 0.0005141366855241358
# Training loss value at step 400: 0.0019185009878128767
# Training loss value at step 500: 0.0015587572706863284
# Training loss value at step 600: 0.0012875846587121487
# Training loss value at step 700: 0.0007110689766705036
# Training accuracy over whole file: 0.9782208800315857
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 6.506977081298828
# Training loss value at step 100: 0.004647050518542528
# Training loss value at step 200: 0.00359139870852232
# Training loss value at step 300: 0.011522294022142887
# Training loss value at step 400: 0.0030976191628724337
# Training loss value at step 500: 0.0048146978951990604
# Training loss value at step 600: 0.005395493470132351
# Training loss value at step 700: 0.0009147512027993798
# Training accuracy over whole file: 0.9777936339378357
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 8.640201568603516
# Training loss value at step 100: 0.002753754146397114
# Training loss value at step 200: 0.0022603932302445173
# Training loss value at step 300: 0.00766361178830266
# Training loss value at step 400: 0.001910886145196855
# Training loss value at step 500: 0.025475459173321724
# Training loss value at step 600: 0.0035415091551840305
# Training loss value at step 700: 0.00012766500003635883
# Training accuracy over whole file: 0.9774547219276428
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 9.540152549743652
# Training loss value at step 100: 0.004879827611148357
# Training loss value at step 200: 0.0010456338059157133
# Training loss value at step 300: 0.0006086166249588132
# Training loss value at step 400: 0.0006092122639529407
# Training loss value at step 500: 0.002741033909842372
# Training loss value at step 600: 0.00013565097469836473
# Training loss value at step 700: 0.00011336160969221964
# Training accuracy over whole file: 0.9770417213439941
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 8.891608238220215
# Training loss value at step 100: 0.009914086200296879
# Training loss value at step 200: 0.005322927143424749
# Training loss value at step 300: 0.006986947730183601
# Training loss value at step 400: 0.001527215470559895
# Training loss value at step 500: 0.0011767374817281961
# Training loss value at step 600: 0.0025620989035815
# Training loss value at step 700: 0.0025101364590227604
# Training accuracy over whole file: 0.9768549799919128
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.18147704005241394
# Training loss value at step 100: 0.004105354659259319
# Training loss value at step 200: 0.0020553194917738438
# Training loss value at step 300: 0.0013322297018021345
# Training loss value at step 400: 0.03728922829031944
# Training loss value at step 500: 0.0021490592043846846
# Training loss value at step 600: 0.002435101196169853
# Training loss value at step 700: 0.0012055517872795463
# Training accuracy over whole file: 0.9770566821098328
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.000846147071570158
# Training loss value at step 100: 0.0003620922507252544
# Training loss value at step 200: 0.00015484087634831667
# Training loss value at step 300: 0.0003466005437076092
# Training loss value at step 400: 0.04710569232702255
# Training loss value at step 500: 0.0004855407460127026
# Training loss value at step 600: 0.0001370812824461609
# Training loss value at step 700: 0.00045694399159401655
# Training accuracy over whole file: 0.9778761267662048
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 14.594978332519531
# Training loss value at step 100: 0.0016653967322781682
# Training loss value at step 200: 0.0006482883472926915
# Training loss value at step 300: 0.0010802869219332933
# Training loss value at step 400: 0.025677412748336792
# Training loss value at step 500: 0.01613757759332657
# Training loss value at step 600: 0.003285250859335065
# Training loss value at step 700: 0.001994288759306073
# Training accuracy over whole file: 0.9770260453224182
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 8.626667022705078
# Training loss value at step 100: 0.011215617880225182
# Training loss value at step 200: 0.02459140121936798
# Training loss value at step 300: 0.003932719584554434
# Training loss value at step 400: 0.003262556390836835
# Training loss value at step 500: 0.029474282637238503
# Training loss value at step 600: 0.0008488865569233894
# Training loss value at step 700: 0.0009257083875127137
# Training accuracy over whole file: 0.9769068956375122
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 8.385381698608398
# Training loss value at step 100: 0.014345608651638031
# Training loss value at step 200: 0.04805154353380203
# Training loss value at step 300: 0.005183353088796139
# Training loss value at step 400: 0.011049039661884308
# Training loss value at step 500: 0.0012998473830521107
# Training loss value at step 600: 0.0032743194606155157
# Training loss value at step 700: 0.0020308124367147684
# Training accuracy over whole file: 0.976632297039032
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 5.9044270515441895
# Training loss value at step 100: 0.006874836515635252
# Training loss value at step 200: 0.0017567930044606328
# Training loss value at step 300: 0.0028471907135099173
# Training loss value at step 400: 0.003455859376117587
# Training loss value at step 500: 0.0025977694895118475
# Training loss value at step 600: 0.00392583291977644
# Training loss value at step 700: 0.0031389747746288776
# Training accuracy over whole file: 0.9764933586120605
# ---------------------------------------------------
# --------------------------------------------------------------
# Starting epoch 3
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 4.47709846496582
# Training loss value at step 100: 0.010361449792981148
# Training loss value at step 200: 0.010945282876491547
# Training loss value at step 300: 0.015727410092949867
# Training loss value at step 400: 0.14771825075149536
# Training loss value at step 500: 0.002097788965329528
# Training loss value at step 600: 0.0015766106080263853
# Training loss value at step 700: 0.0028020190075039864
# Training accuracy over whole file: 0.9734513163566589
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 0.02806534431874752
# Training loss value at step 100: 0.0014497257070615888
# Training loss value at step 200: 0.0049233632162213326
# Training loss value at step 300: 0.005312255118042231
# Training loss value at step 400: 0.041732605546712875
# Training loss value at step 500: 0.00010179955279454589
# Training loss value at step 600: 0.0029844765085726976
# Training loss value at step 700: 4.327203714638017e-05
# Training accuracy over whole file: 0.974083423614502
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.0009420248097740114
# Training loss value at step 100: 0.0009146321099251509
# Training loss value at step 200: 0.000543446687515825
# Training loss value at step 300: 0.0003095386200584471
# Training loss value at step 400: 0.0018869704799726605
# Training loss value at step 500: 0.00026651646476238966
# Training loss value at step 600: 5.280832192511298e-05
# Training loss value at step 700: 4.5060096454108134e-05
# Training accuracy over whole file: 0.982300877571106
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 2.0492751598358154
# Training loss value at step 100: 0.003970003686845303
# Training loss value at step 200: 0.0004768426588270813
# Training loss value at step 300: 0.001404966926202178
# Training loss value at step 400: 0.0002985746832564473
# Training loss value at step 500: 0.003560158656910062
# Training loss value at step 600: 0.0008091036579571664
# Training loss value at step 700: 0.000567275274079293
# Training accuracy over whole file: 0.9816687703132629
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.001064806361682713
# Training loss value at step 100: 0.011953979730606079
# Training loss value at step 200: 0.00019572250312194228
# Training loss value at step 300: 0.0009535771678201854
# Training loss value at step 400: 0.003213838441297412
# Training loss value at step 500: 2.109982233378105e-05
# Training loss value at step 600: 1.645074735279195e-05
# Training loss value at step 700: 3.5523738915799186e-05
# Training accuracy over whole file: 0.9840707778930664
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 10.872396469116211
# Training loss value at step 100: 0.024783765897154808
# Training loss value at step 200: 0.30911627411842346
# Training loss value at step 300: 0.0035183453001081944
# Training loss value at step 400: 0.0030209640972316265
# Training loss value at step 500: 0.003569898894056678
# Training loss value at step 600: 0.0023789696861058474
# Training loss value at step 700: 0.00036507140612229705
# Training accuracy over whole file: 0.9787189364433289
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.000892121868673712
# Training loss value at step 100: 0.0008317348547279835
# Training loss value at step 200: 0.004523046314716339
# Training loss value at step 300: 0.0020377126056700945
# Training loss value at step 400: 0.0007819455349817872
# Training loss value at step 500: 0.0005874100024811924
# Training loss value at step 600: 0.00047350639943033457
# Training loss value at step 700: 6.842378934379667e-05
# Training accuracy over whole file: 0.9790500402450562
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.00045170116936787963
# Training loss value at step 100: 0.0003104920033365488
# Training loss value at step 200: 0.0003363520372658968
# Training loss value at step 300: 0.0007830176036804914
# Training loss value at step 400: 0.0003522014303598553
# Training loss value at step 500: 2.7417760065873154e-05
# Training loss value at step 600: 3.862306402879767e-05
# Training loss value at step 700: 4.732496745418757e-05
# Training accuracy over whole file: 0.9811946749687195
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 0.0005461869877763093
# Training loss value at step 100: 0.0003064401389565319
# Training loss value at step 200: 0.000418575422372669
# Training loss value at step 300: 0.00029047083808109164
# Training loss value at step 400: 9.953480184776708e-05
# Training loss value at step 500: 8.511180931236595e-05
# Training loss value at step 600: 2.5629668016335927e-05
# Training loss value at step 700: 4.31528314948082e-05
# Training accuracy over whole file: 0.9832841753959656
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 0.1713075190782547
# Training loss value at step 100: 0.0028820191510021687
# Training loss value at step 200: 0.0006568658282049
# Training loss value at step 300: 0.004459792748093605
# Training loss value at step 400: 0.0018628163961693645
# Training loss value at step 500: 0.0016540905926376581
# Training loss value at step 600: 0.0003280101518612355
# Training loss value at step 700: 0.0004549183649942279
# Training accuracy over whole file: 0.9834386706352234
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 7.888031005859375
# Training loss value at step 100: 0.00182235985994339
# Training loss value at step 200: 0.00014673586701974273
# Training loss value at step 300: 0.00016330339713022113
# Training loss value at step 400: 0.0026106107980012894
# Training loss value at step 500: 0.0011398254428058863
# Training loss value at step 600: 0.001459367573261261
# Training loss value at step 700: 0.0007073761080391705
# Training accuracy over whole file: 0.9817262291908264
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.0009327351581305265
# Training loss value at step 100: 0.0005415403284132481
# Training loss value at step 200: 0.00033718624035827816
# Training loss value at step 300: 0.0005864569102413952
# Training loss value at step 400: 6.69933797325939e-05
# Training loss value at step 500: 0.00032658010604791343
# Training loss value at step 600: 9.202533692587167e-05
# Training loss value at step 700: 0.00013267113536130637
# Training accuracy over whole file: 0.9832490682601929
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.00010847456724150106
# Training loss value at step 100: 0.00012087091454304755
# Training loss value at step 200: 0.000289159914245829
# Training loss value at step 300: 0.00010716341057559475
# Training loss value at step 400: 0.00024351492174901068
# Training loss value at step 500: 8.642300235806033e-05
# Training loss value at step 600: 0.00020668754586949944
# Training loss value at step 700: 0.00029869386344216764
# Training accuracy over whole file: 0.9845376014709473
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 5.173549288883805e-05
# Training loss value at step 100: 0.00020680672605521977
# Training loss value at step 200: 0.0002475670480635017
# Training loss value at step 300: 7.283422019099817e-05
# Training loss value at step 400: 0.0001793938863556832
# Training loss value at step 500: 1.5258672647178173e-05
# Training loss value at step 600: 6.067568756407127e-05
# Training loss value at step 700: 0.00010227633902104571
# Training accuracy over whole file: 0.9856420159339905
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 9.623515129089355
# Training loss value at step 100: 0.0029125672299414873
# Training loss value at step 200: 0.01130308024585247
# Training loss value at step 300: 0.01950874924659729
# Training loss value at step 400: 0.0023267597425729036
# Training loss value at step 500: 0.0008594871615059674
# Training loss value at step 600: 0.0033772119786590338
# Training loss value at step 700: 0.00026306029758416116
# Training accuracy over whole file: 0.9851664304733276
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 9.200324058532715
# Training loss value at step 100: 0.009030098095536232
# Training loss value at step 200: 0.0005927712772972882
# Training loss value at step 300: 0.00027533553657121956
# Training loss value at step 400: 9.619726915843785e-05
# Training loss value at step 500: 0.00011205045302631333
# Training loss value at step 600: 0.003340262221172452
# Training loss value at step 700: 0.00020597243565134704
# Training accuracy over whole file: 0.9841182231903076
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 14.66292953491211
# ...
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.004240924958139658
# Training loss value at step 100: 0.00511693861335516
# Training loss value at step 200: 0.012508275918662548
# Training loss value at step 300: 0.6000441908836365
# Training loss value at step 400: 0.06886332482099533
# Training loss value at step 500: 0.0033362226095050573
# Training loss value at step 600: 0.0033376484643667936
# Training loss value at step 700: 0.00389828416518867
# Training accuracy over whole file: 0.9808560609817505
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 9.703165414975956e-05
# Training loss value at step 100: 0.00011276562872808427
# Training loss value at step 200: 9.345571743324399e-05
# Training loss value at step 300: 6.508615479106084e-05
# Training loss value at step 400: 0.0009534580749459565
# Training loss value at step 500: 0.00013136000779923052
# Training loss value at step 600: 2.4914430468925275e-05
# Training loss value at step 700: 0.00022682955022901297
# Training accuracy over whole file: 0.9830909967422485
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 0.0001726001501083374
# Training loss value at step 100: 6.067568756407127e-05
# Training loss value at step 200: 3.3378044463461265e-05
# Training loss value at step 300: 9.619726915843785e-05
# Training loss value at step 400: 0.0006755692302249372
# Training loss value at step 500: 0.001016695867292583
# Training loss value at step 600: 0.0005353448214009404
# Training loss value at step 700: 0.00017236177518498152
# Training accuracy over whole file: 0.9849697947502136
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 0.918429434299469
# Training loss value at step 100: 0.0037365397438406944
# Training loss value at step 200: 0.0030392666812986135
# Training loss value at step 300: 2.266310214996338
# Training loss value at step 400: 0.0026333199348300695
# Training loss value at step 500: 0.0006815256201662123
# Training loss value at step 600: 0.034041859209537506
# Training loss value at step 700: 0.0014635338447988033
# Training accuracy over whole file: 0.9853349924087524
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 8.82425594329834
# Training loss value at step 100: 0.017426704987883568
# Training loss value at step 200: 0.0006192197324708104
# Training loss value at step 300: 0.0001517419150331989
# Training loss value at step 400: 0.004340157378464937
# Training loss value at step 500: 0.011854675598442554
# Training loss value at step 600: 0.0018277144990861416
# Training loss value at step 700: 0.0006609162664972246
# Training accuracy over whole file: 0.9843696355819702
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.000735608336981386
# Training loss value at step 100: 2.372236667724792e-05
# Training loss value at step 200: 0.0006861716392450035
# Training loss value at step 300: 0.021188216283917427
# Training loss value at step 400: 3.302042750874534e-05
# Training loss value at step 500: 0.00017510310863144696
# Training loss value at step 600: 0.00038580605178140104
# Training loss value at step 700: 0.0004359725280664861
# Training accuracy over whole file: 0.985672116279602
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 7.4741430580616e-05
# Training loss value at step 100: 0.00014029949670657516
# Training loss value at step 200: 0.0004080893413629383
# Training loss value at step 300: 0.0002338612830499187
# Training loss value at step 400: 0.00023803261865396053
# Training loss value at step 500: 0.00028701478731818497
# Training loss value at step 600: 7.271502545336261e-05
# Training loss value at step 700: 7.068861305015162e-05
# Training accuracy over whole file: 0.9867742657661438
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 2.2172682292875834e-05
# Training loss value at step 100: 0.00035482310340739787
# Training loss value at step 200: 0.0003582789213396609
# Training loss value at step 300: 4.136476854910143e-05
# Training loss value at step 400: 4.8636207793606445e-05
# Training loss value at step 500: 1.1920922133867862e-06
# Training loss value at step 600: 2.4437606043647975e-05
# Training loss value at step 700: 2.2053474822314456e-05
# Training accuracy over whole file: 0.9877189993858337
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 10.927696228027344
# Training loss value at step 100: 0.003552081063389778
# Training loss value at step 200: 0.015314020216464996
# Training loss value at step 300: 0.005224504042416811
# Training loss value at step 400: 0.004923244938254356
# Training loss value at step 500: 0.006270614918321371
# Training loss value at step 600: 0.002803921001031995
# Training loss value at step 700: 0.00043644916149787605
# Training accuracy over whole file: 0.9870206713676453
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 12.23084831237793
# Training loss value at step 100: 0.007899117656052113
# Training loss value at step 200: 0.0005983707960695028
# Training loss value at step 300: 0.0016230279579758644
# Training loss value at step 400: 0.0010343207977712154
# Training loss value at step 500: 0.00018904806347563863
# Training loss value at step 600: 0.0022840620949864388
# Training loss value at step 700: 9.035655966727063e-05
# Training accuracy over whole file: 0.9858565330505371
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 11.797449111938477
# Training loss value at step 100: 0.0005334384622983634
# Training loss value at step 200: 5.745722592109814e-05
# Training loss value at step 300: 0.00031001531169749796
# Training loss value at step 400: 0.007375866640359163
# Training loss value at step 500: 0.0010081215295940638
# Training loss value at step 600: 0.06547735631465912
# Training loss value at step 700: 0.0006661579827778041
# Training accuracy over whole file: 0.9846805930137634
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 9.191295623779297
# Training loss value at step 100: 0.015806851908564568
# Training loss value at step 200: 0.0049795894883573055
# Training loss value at step 300: 0.001753103919327259
# Training loss value at step 400: 0.009107830002903938
# Training loss value at step 500: 0.007192551624029875
# Training loss value at step 600: 0.015709923580288887
# Training loss value at step 700: 0.0009471459779888391
# Training accuracy over whole file: 0.9845483899116516
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 7.9837327003479
# Training loss value at step 100: 0.010398495011031628
# Training loss value at step 200: 0.004215521737933159
# Training loss value at step 300: 0.006476958282291889
# Training loss value at step 400: 0.005481214262545109
# Training loss value at step 500: 0.0017998700495809317
# Training loss value at step 600: 0.0027903690934181213
# Training loss value at step 700: 0.0011403016978874803
# Training accuracy over whole file: 0.9837647080421448
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 6.237695217132568
# Training loss value at step 100: 0.0005791893927380443
# Training loss value at step 200: 0.0002517383254598826
# Training loss value at step 300: 0.007626938167959452
# Training loss value at step 400: 0.0001931004080688581
# Training loss value at step 500: 0.002945729298517108
# Training loss value at step 600: 0.0003780603874474764
# Training loss value at step 700: 0.0004650464979931712
# Training accuracy over whole file: 0.9840707778930664
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 7.460996150970459
# Training loss value at step 100: 0.04424097761511803
# Training loss value at step 200: 0.0025264269206672907
# Training loss value at step 300: 0.0012961566681042314
# Training loss value at step 400: 0.0002184867626056075
# Training loss value at step 500: 0.00011991735664196312
# Training loss value at step 600: 0.0007925468380562961
# Training loss value at step 700: 0.0002485204895492643
# Training accuracy over whole file: 0.9842875003814697
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 0.0001113352773245424
# Training loss value at step 100: 5.304672595229931e-05
# Training loss value at step 200: 8.22540732769994e-06
# Training loss value at step 300: 7.068861305015162e-05
# Training loss value at step 400: 5.864924969500862e-05
# Training loss value at step 500: 4.9828242481453344e-05
# Training loss value at step 600: 2.5510462364763953e-05
# Training loss value at step 700: 1.2516897186287679e-05
# Training accuracy over whole file: 0.9850017428398132
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 1.2202191352844238
# Training loss value at step 100: 0.011678542010486126
# Training loss value at step 200: 0.01913083717226982
# Training loss value at step 300: 0.01923363097012043
# Training loss value at step 400: 0.010741393081843853
# Training loss value at step 500: 0.009457075037062168
# Training loss value at step 600: 0.005645995959639549
# Training loss value at step 700: 0.003098807530477643
# Training accuracy over whole file: 0.9849942326545715
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 6.52823543548584
# Training loss value at step 100: 0.0077641610987484455
# Training loss value at step 200: 0.08286380022764206
# Training loss value at step 300: 0.00036590558011084795
# Training loss value at step 400: 3.373566141817719e-05
# Training loss value at step 500: 0.00011443436960689723
# Training loss value at step 600: 9.321732068201527e-05
# Training loss value at step 700: 0.0028937868773937225
# Training accuracy over whole file: 0.984407901763916
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 8.681567192077637
# Training loss value at step 100: 0.0018328310688957572
# Training loss value at step 200: 0.000865561596583575
# Training loss value at step 300: 0.0001908358681248501
# Training loss value at step 400: 0.0008912881603464484
# Training loss value at step 500: 4.541770613286644e-05
# Training loss value at step 600: 0.00012611546844709665
# Training loss value at step 700: 8.260862523457035e-05
# Training accuracy over whole file: 0.9838685393333435
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 8.604129791259766
# Training loss value at step 100: 0.00809235405176878
# Training loss value at step 200: 0.004455994814634323
# Training loss value at step 300: 0.02081630937755108
# Training loss value at step 400: 0.00045122456504032016
# Training loss value at step 500: 0.003640929702669382
# Training loss value at step 600: 0.0051231058314442635
# Training loss value at step 700: 0.00415818439796567
# Training accuracy over whole file: 0.982932984828949
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 2.0774166584014893
# Training loss value at step 100: 0.015480241738259792
# Training loss value at step 200: 0.011039843782782555
# Training loss value at step 300: 0.003432099474593997
# Training loss value at step 400: 0.009718721732497215
# Training loss value at step 500: 0.041803378611803055
# Training loss value at step 600: 0.0007273888913914561
# Training loss value at step 700: 0.0008849757141433656
# Training accuracy over whole file: 0.9829564094543457
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.00044216870446689427
# Training loss value at step 100: 0.000346362212439999
# Training loss value at step 200: 0.0014315128792077303
# Training loss value at step 300: 0.0012144817737862468
# Training loss value at step 400: 0.009164766408503056
# Training loss value at step 500: 0.00019786784832831472
# Training loss value at step 600: 4.160317621426657e-05
# Training loss value at step 700: 2.1457441107486375e-05
# Training accuracy over whole file: 0.983565092086792
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 10.955857276916504
# Training loss value at step 100: 0.0007183355046436191
# Training loss value at step 200: 0.00149555376265198
# Training loss value at step 300: 0.045145560055971146
# Training loss value at step 400: 0.0008038626983761787
# Training loss value at step 500: 0.0007746794726699591
# Training loss value at step 600: 0.0002803409588523209
# Training loss value at step 700: 0.00036816971260122955
# Training accuracy over whole file: 0.9825188517570496
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 3.5625853538513184
# Training loss value at step 100: 0.015069685876369476
# Training loss value at step 200: 0.2883707582950592
# Training loss value at step 300: 0.03597303107380867
# Training loss value at step 400: 0.0057115452364087105
# Training loss value at step 500: 0.0026348656974732876
# Training loss value at step 600: 0.0005651307292282581
# Training loss value at step 700: 0.001157924416474998
# Training accuracy over whole file: 0.9826801419258118
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 3.337111473083496
# Training loss value at step 100: 0.001320681651122868
# Training loss value at step 200: 0.09383069723844528
# Training loss value at step 300: 0.00041392818093299866
# Training loss value at step 400: 0.0062450263649225235
# Training loss value at step 500: 0.0002719986077863723
# Training loss value at step 600: 0.0006217215559445322
# Training loss value at step 700: 0.0005504761938937008
# Training accuracy over whole file: 0.9825047850608826
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 2.2806646823883057
# Training loss value at step 100: 0.0013380631571635604
# Training loss value at step 200: 0.0009357126546092331
# Training loss value at step 300: 0.0012663925299420953
# Training loss value at step 400: 0.0017329927068203688
# Training loss value at step 500: 0.00022146634000819176
# Training loss value at step 600: 9.572047565598041e-05
# Training loss value at step 700: 0.00022015532886143774
# Training accuracy over whole file: 0.9825379252433777
# ---------------------------------------------------
# --------------------------------------------------------------
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.dense.Dense object at 0x2820f22d0>, because it is not built.
# INFO:tensorflow:Assets written to: models/trained_LSTM_e3_5_20_intra/assets
# INFO:tensorflow:Assets written to: models/trained_LSTM_e3_5_20_intra/assets

# %%
new_model = keras.models.load_model("models/trained_LSTM_e3_5_20_intra")
new_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "just_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm1 (LSTM)                multiple                  21520
#
#  lstm2 (LSTM)                multiple                  3280
#
#  dense (Dense)               multiple                  0
#
#  output (Dense)              multiple                  84
#
# =================================================================
# Total params: 24884 (97.20 KB)
# Trainable params: 24884 (97.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_arr = [tensor.numpy() for tensor in losses]

# %%
print(loss_arr)
# Out:
# [0.55024827, 1.0374123, 1.3949203, 1.7491225, 2.0828552]

# %%
acc_arr = [tensor.numpy() for tensor in accuracies]

# %%
print(acc_arr)
# Out:
# [3.931982, 7.847134, 11.773086, 15.712692, 19.648586]
