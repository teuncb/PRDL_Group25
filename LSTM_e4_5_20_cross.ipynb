# %%
import re
import random
import os
import numpy as np
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import LabelBinarizer

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import logging
from sklearn.preprocessing import LabelBinarizer


class JustLSTM(keras.Model):
    def __init__(self, input_shape, timeframe, LSTM_units, dense_units, num_classes=4):
        super().__init__()

        # TODO: kijken of we input shape niet uit elkaar trekken in width, height, batch_size en timesteps (nu num_segments)
        self.in_shape = input_shape
        self.num_classes = num_classes
        self.LSTM_units = LSTM_units

        # The number of images / timesteps that we will look at for each training step
        self.timeframe = timeframe

        self.lstm1 = keras.layers.LSTM(self.LSTM_units, return_sequences=True, name="lstm1")
        self.lstm2 = keras.layers.LSTM(self.LSTM_units, name="lstm2")

        self.fc = keras.layers.Dense(dense_units, activation="relu")

        self.out = keras.layers.Dense(self.num_classes, activation="softmax", name="output")

    def call(self, inputs, training=True, mask=None):
        """
        Specifies how the inputs should be passed through the layers of the model and returns the output

        :param inputs: the inputs to be classified by the model, with the same shape as self.in_shape
        :param training: whether the gradients should be tracked
        :param mask: whether a certain mask should be applied on the inputs (such as masking certain timesteps)
        :return: probabilities for each of the classes
        """

        input_layer = keras.layers.InputLayer(self.in_shape, name="input")(inputs)

        # Pass the timesteps through the RNN to find temporal features The amount of units in the layer are equal to
        # the number of timesteps (i.e. segments) according to Zhang et al. (2018)
        lstm1 = self.lstm1(input_layer)
        lstm2 = self.lstm2(lstm1)

        #fc = self.fc(lstm2)

        # Final fully connected layer with softmax to give class probabilities
        output = self.out(lstm2)

        return output

    def build_graph(self):
        """
        Builds the Tensor Graph in order to generate a summary of the model by running dummy input through the model
        :return: a 'dummy' version of the model of which we can generate a summary
        """
        x = keras.Input(self.in_shape)
        return keras.Model(inputs=[x], outputs=self.call(x))

# %%
def create_windows(dataset, model_type, timeframe):
    # Will contain the slices of the dataset that represent the different windows
    windows = []

    if model_type == "cascade":
        num_windows = int(dataset.shape[2] / timeframe)
    else:
        num_windows = int(dataset.shape[1] / timeframe)

    i = timeframe
    j = 0
    count = 0

    # Loop through the dataset until we have the specified number of windows (might cut off some of the last timesteps)
    while count < num_windows:
        # Save the view of the array in the windows list
        if model_type == "cascade":
            view = dataset[:, :, j:i]
        else:
            view = dataset[:, j:i]
        windows.append(view)

        i += timeframe
        j += timeframe
        count += 1
    # Return the list of array views
    return windows


def read_prepro_file(data_path):
    hfive = h5py.File(data_path, 'r')
    matrix = hfive.get('dir')
    matrix = np.array(matrix)
    return matrix

# %%
import tensorflow as tf
from tensorflow import keras
import re
import os
import random
import numpy as np


# tf function zal niet heel veel uitmaken volgens de documentatie, omdat wij veel convolutional operations hebben (waarbij de speedup dus meevalt)
def train_epoch(model, x_train, y_train, optimizer, train_acc):
    # Instantiate an optimizer and loss function
    loss_function = keras.losses.CategoricalCrossentropy()

    total_loss = 0

    # Doet nu nog wel een update per window, wellicht veel? We kunnen ook nog batches gaan gebruiken om het aantal updates te reduceren
    for step in range(len(x_train)):
        # Used to track the gradients during the forward pass
        with tf.GradientTape() as tape:
            logits = model(tf.expand_dims(x_train[step], axis=0), training=True)
            # Calculate the loss value
            loss_value = loss_function(y_train[step], logits)

        total_loss += loss_value

        # Extract the gradients from the gradienttape
        grads = tape.gradient(loss_value, model.trainable_weights)

        # Perform a weight update step using the extracted gradients
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        # Keep track of the training accuracy which is given at the end of the loop
        train_acc.update_state(y_train[step], logits)

        # Report the training loss for monitoring
        if step % 100 == 0:
            print("Training loss value at step {}: {}".format(step, loss_value))

    print("Training accuracy over whole file: {}".format(train_acc.result()))
    print("---------------------------------------------------")
    average_loss = total_loss / len(x_train)
    return average_loss, train_acc


# TODO: kijken of we de input als tensors willen doen (wat wel netter is I guess) of makkelijker als np arrays --> netwerk vindt allebei goed
def fit_eight(model, model_type, dirlist, parent_path, optimizer, timeframe, label_encoder,
              train_acc_obj):  # Fit a network on 8 datafiles at a time.
    fit_list = []
    average_loss = 0
    i = 0
    j = 0
    while i < 8:  # Load the 8 datafiles
        filename = parent_path + "/" + dirlist[i]

        data = read_prepro_file(filename)
        label = extract_label(filename)

        fit_list.append((data, label))
        i += 1

    for counter, (data, label) in enumerate(fit_list):
        print("Fitting on file {} containing task: {}".format((counter + 1), label))
        # Creates windows of length 'timeframe' to fit the model on
        windows = create_windows(data, model_type, timeframe)
        x_train = []
        # Only needed for CascadeNet, not for the LSTM network
        for window in windows:
            if model_type == "cascade":
                x_train.append(tf.convert_to_tensor(window))
            else:
                x_train.append(tf.convert_to_tensor(np.transpose(window)))

        # Encode the textual label to one-hot-encoding
        encoded_label = label_encoder.transform([label])
        # Create a list of tensors, each corresponding to an encoded label
        y_train = [tf.convert_to_tensor(encoded_label)] * len(x_train)

        # Fit the model on the data from this specific file
        average_loss, train_acc_obj = train_epoch(model, x_train, y_train, optimizer, train_acc_obj)

    return average_loss, train_acc_obj


def train_dir(model, model_type, dirpath, epochs, timeframe, optimizer, label_encoder,
              shuffle=True):  # Train a network on a given directory
    dirnames = os.listdir(dirpath)  # get list of all filenames
    random.shuffle(dirnames)
    batches = len(dirnames) // 8  # int divide by eight to avoid float errors

    train_acc_obj = keras.metrics.CategoricalAccuracy()

    average_epoch_accuracy = 0
    average_epoch_loss = 0
    losses = []
    accuracies = []

    # Check if it is divisible by eight
    if not (len(dirnames) % 8) == 0:
        raise TypeError("Not divisible by eight")

    for epoch in range(epochs):
        print("Starting epoch {}".format(epoch + 1))
        print()
        train_acc_obj.reset_states()
        for i in range(batches):  # Fit on 8 batches at a time                HIER IPV 1 WEER 'BATCHES' NEERZETTEN
            print("Fitting on files {}-{}....".format((i * 8), ((i + 1) * 8)))
            # Fits the model on 8 files for the specified amount of epochs
            average_loss, train_acc_obj = fit_eight(model, model_type, dirnames[i * 8:(i + 1) * 8], dirpath, optimizer,
                                                    timeframe, label_encoder, train_acc_obj)
            average_epoch_loss += average_loss
            average_epoch_accuracy += train_acc_obj.result()

            print("--------------------------------------------------------------")

        losses.append(average_epoch_loss)
        accuracies.append(average_epoch_accuracy)

    # SAVE THE MODEL AFTER TRAINING!!!!
    model.save("models/trained_LSTM_e4_5_20_cross")

    return model, losses, accuracies


def extract_label(filename):  # Extract the label out of a filename
    filename = filename.split("/")
    pattern = r'_\d'
    split = re.split(pattern, filename[-1])
    return split[0]

# %%
from sklearn.preprocessing import LabelBinarizer
import tensorflow
from tensorflow import keras

output_classes = 4

# Hyperparameters
timeframe = 5
LSTM_units = 20
# (1e-2, 1e-3, 1e-4)
learning_rate = 1e-4

epochs = 5



textual_labels = ["rest", "task_motor", "task_story_math", "task_working_memory"]
label_encoder = LabelBinarizer()
label_encoder.fit(textual_labels)

model = JustLSTM((timeframe, 248), timeframe, LSTM_units, 16, output_classes)
model_type = "lstm"

optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

model, losses, accuracies = train_dir(model, model_type, "data/Cross/train_prepro", epochs, timeframe, optimizer, label_encoder)
# Out:
# Starting epoch 1
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 1.096207618713379
# Training loss value at step 100: 0.7583739757537842
# Training loss value at step 200: 0.6789930462837219
# Training loss value at step 300: 0.9530364274978638
# Training loss value at step 400: 0.4363366365432739
# Training loss value at step 500: 0.7834709286689758
# Training loss value at step 600: 0.22252079844474792
# Training loss value at step 700: 0.3619951903820038
# Training accuracy over whole file: 0.9582806825637817
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 0.17986804246902466
# Training loss value at step 100: 0.06199271231889725
# Training loss value at step 200: 0.033503178507089615
# Training loss value at step 300: 0.029871216043829918
# Training loss value at step 400: 0.04249265789985657
# Training loss value at step 500: 0.014129129238426685
# Training loss value at step 600: 0.03177603706717491
# Training loss value at step 700: 0.01736730895936489
# Training accuracy over whole file: 0.9791403412818909
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 7.702289581298828
# Training loss value at step 100: 4.086026191711426
# Training loss value at step 200: 1.522883415222168
# Training loss value at step 300: 0.6038848161697388
# Training loss value at step 400: 1.439849615097046
# Training loss value at step 500: 1.1672488451004028
# Training loss value at step 600: 0.4972181022167206
# Training loss value at step 700: 0.930905282497406
# Training accuracy over whole file: 0.8600926995277405
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 1.790266752243042
# Training loss value at step 100: 0.1174507811665535
# Training loss value at step 200: 0.8015965223312378
# Training loss value at step 300: 0.8135305643081665
# Training loss value at step 400: 0.12174500524997711
# Training loss value at step 500: 0.16025954484939575
# Training loss value at step 600: 0.47229379415512085
# Training loss value at step 700: 0.40611547231674194
# Training accuracy over whole file: 0.8719974756240845
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 7.284839630126953
# Training loss value at step 100: 1.8646326065063477
# Training loss value at step 200: 1.1064759492874146
# Training loss value at step 300: 1.1301881074905396
# Training loss value at step 400: 1.6799817085266113
# Training loss value at step 500: 1.4926954507827759
# Training loss value at step 600: 1.395714282989502
# Training loss value at step 700: 1.0035873651504517
# Training accuracy over whole file: 0.7549936771392822
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.8099324107170105
# Training loss value at step 100: 0.5454188585281372
# Training loss value at step 200: 0.2520236372947693
# Training loss value at step 300: 0.597687840461731
# Training loss value at step 400: 0.6583008170127869
# Training loss value at step 500: 0.1536065936088562
# Training loss value at step 600: 0.20512676239013672
# Training loss value at step 700: 0.18413570523262024
# Training accuracy over whole file: 0.7949852347373962
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 3.2201523780822754
# Training loss value at step 100: 3.2042741775512695
# Training loss value at step 200: 1.1690831184387207
# Training loss value at step 300: 0.8674867153167725
# Training loss value at step 400: 1.1976406574249268
# Training loss value at step 500: 0.7177056670188904
# Training loss value at step 600: 0.36077943444252014
# Training loss value at step 700: 0.24547943472862244
# Training accuracy over whole file: 0.753476619720459
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 0.4786820113658905
# Training loss value at step 100: 0.16004909574985504
# Training loss value at step 200: 0.15162290632724762
# Training loss value at step 300: 0.06987953931093216
# Training loss value at step 400: 0.044436898082494736
# Training loss value at step 500: 0.03691234439611435
# Training loss value at step 600: 0.0356103777885437
# Training loss value at step 700: 0.032797638326883316
# Training accuracy over whole file: 0.7842920422554016
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 5.985622406005859
# Training loss value at step 100: 0.8074654340744019
# Training loss value at step 200: 0.4829212725162506
# Training loss value at step 300: 1.271701693534851
# Training loss value at step 400: 0.5872694253921509
# Training loss value at step 500: 0.3284628391265869
# Training loss value at step 600: 0.6021171808242798
# Training loss value at step 700: 0.14051535725593567
# Training accuracy over whole file: 0.7821323275566101
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 0.20651774108409882
# Training loss value at step 100: 0.22396765649318695
# Training loss value at step 200: 0.08080172538757324
# Training loss value at step 300: 0.08891458809375763
# Training loss value at step 400: 0.12102925777435303
# Training loss value at step 500: 0.06510704010725021
# Training loss value at step 600: 0.15014219284057617
# Training loss value at step 700: 0.02804853767156601
# Training accuracy over whole file: 0.8034133911132812
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 5.064030647277832
# Training loss value at step 100: 3.406120538711548
# Training loss value at step 200: 0.43836870789527893
# Training loss value at step 300: 0.05307755991816521
# Training loss value at step 400: 0.5020759105682373
# Training loss value at step 500: 0.692797839641571
# Training loss value at step 600: 0.3483099341392517
# Training loss value at step 700: 0.1079845055937767
# Training accuracy over whole file: 0.7997931241989136
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 4.730861186981201
# Training loss value at step 100: 0.6534201502799988
# Training loss value at step 200: 3.2077584266662598
# Training loss value at step 300: 0.09691758453845978
# Training loss value at step 400: 0.15540176630020142
# Training loss value at step 500: 0.20858806371688843
# Training loss value at step 600: 0.04419832304120064
# Training loss value at step 700: 0.02974509447813034
# Training accuracy over whole file: 0.8045722842216492
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.09370642155408859
# Training loss value at step 100: 0.07748226821422577
# Training loss value at step 200: 0.04439208284020424
# Training loss value at step 300: 1.1303492784500122
# Training loss value at step 400: 0.36972782015800476
# Training loss value at step 500: 0.23584003746509552
# Training loss value at step 600: 0.011960811913013458
# Training loss value at step 700: 0.01030257623642683
# Training accuracy over whole file: 0.8183409571647644
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 5.759875774383545
# Training loss value at step 100: 0.23381222784519196
# Training loss value at step 200: 0.2398698478937149
# Training loss value at step 300: 1.9868451356887817
# Training loss value at step 400: 0.08120683580636978
# Training loss value at step 500: 0.022036688402295113
# Training loss value at step 600: 0.024883771315217018
# Training loss value at step 700: 0.025428740307688713
# Training accuracy over whole file: 0.8156040906906128
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 4.40221643447876
# Training loss value at step 100: 0.6520630717277527
# Training loss value at step 200: 0.469925194978714
# Training loss value at step 300: 4.420246601104736
# Training loss value at step 400: 0.5079141855239868
# Training loss value at step 500: 0.1290399730205536
# Training loss value at step 600: 0.10993430763483047
# Training loss value at step 700: 0.10458456724882126
# Training accuracy over whole file: 0.8139064311981201
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.28348037600517273
# Training loss value at step 100: 0.16128545999526978
# Training loss value at step 200: 0.16907644271850586
# Training loss value at step 300: 0.07616692036390305
# Training loss value at step 400: 0.023233916610479355
# Training loss value at step 500: 0.016503138467669487
# Training loss value at step 600: 0.019093060865998268
# Training loss value at step 700: 0.08391555398702621
# Training accuracy over whole file: 0.8228508234024048
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 3.6598408222198486
# Training loss value at step 100: 0.47867751121520996
# Training loss value at step 200: 0.17238697409629822
# Training loss value at step 300: 0.8113305568695068
# Training loss value at step 400: 0.06162727251648903
# Training loss value at step 500: 0.27497467398643494
# Training loss value at step 600: 0.1558329463005066
# Training loss value at step 700: 0.03677906468510628
# Training accuracy over whole file: 0.8217446208000183
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 0.06103159114718437
# Training loss value at step 100: 0.02159685082733631
# Training loss value at step 200: 0.015593388117849827
# Training loss value at step 300: 0.045375704765319824
# Training loss value at step 400: 0.03687960281968117
# Training loss value at step 500: 0.007088512182235718
# Training loss value at step 600: 0.012807023711502552
# Training loss value at step 700: 0.028165139257907867
# Training accuracy over whole file: 0.831577479839325
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 5.081243515014648
# Training loss value at step 100: 0.39593377709388733
# Training loss value at step 200: 0.19630035758018494
# Training loss value at step 300: 0.18467023968696594
# Training loss value at step 400: 0.04303222894668579
# Training loss value at step 500: 0.01483656745404005
# Training loss value at step 600: 0.019172588363289833
# Training loss value at step 700: 0.022066423669457436
# Training accuracy over whole file: 0.8332557082176208
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 3.2023768424987793
# Training loss value at step 100: 0.08287093043327332
# Training loss value at step 200: 0.030995775014162064
# Training loss value at step 300: 0.012738289311528206
# Training loss value at step 400: 0.012859748676419258
# Training loss value at step 500: 0.09222181886434555
# Training loss value at step 600: 0.04370513930916786
# Training loss value at step 700: 0.04181172326207161
# Training accuracy over whole file: 0.8398230075836182
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 3.6494991779327393
# Training loss value at step 100: 3.9737210273742676
# Training loss value at step 200: 2.384554862976074
# Training loss value at step 300: 0.01696854457259178
# Training loss value at step 400: 0.017917677760124207
# Training loss value at step 500: 0.011594411917030811
# Training loss value at step 600: 0.0878523662686348
# Training loss value at step 700: 0.0066991266794502735
# Training accuracy over whole file: 0.8431159853935242
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 2.8756942749023438
# Training loss value at step 100: 0.04941015690565109
# Training loss value at step 200: 0.37055662274360657
# Training loss value at step 300: 0.02803833782672882
# Training loss value at step 400: 0.005561948753893375
# Training loss value at step 500: 0.003644136479124427
# Training loss value at step 600: 0.006523503921926022
# Training loss value at step 700: 0.006358630023896694
# Training accuracy over whole file: 0.8484656810760498
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.26389819383621216
# Training loss value at step 100: 0.2080802023410797
# Training loss value at step 200: 0.07252439111471176
# Training loss value at step 300: 0.06707362085580826
# Training loss value at step 400: 2.536261796951294
# Training loss value at step 500: 1.283795714378357
# Training loss value at step 600: 0.13262751698493958
# Training loss value at step 700: 0.02651047706604004
# Training accuracy over whole file: 0.8464794158935547
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.05180395022034645
# Training loss value at step 100: 0.02672533690929413
# Training loss value at step 200: 0.017351726070046425
# Training loss value at step 300: 0.02597678266465664
# Training loss value at step 400: 0.32435324788093567
# Training loss value at step 500: 0.00680521922186017
# Training loss value at step 600: 0.020144984126091003
# Training loss value at step 700: 0.09246866405010223
# Training accuracy over whole file: 0.8525073528289795
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 7.207729339599609
# Training loss value at step 100: 1.1775777339935303
# Training loss value at step 200: 0.420642226934433
# Training loss value at step 300: 0.14827732741832733
# Training loss value at step 400: 3.7953290939331055
# Training loss value at step 500: 0.10115589946508408
# Training loss value at step 600: 0.04934627562761307
# Training loss value at step 700: 0.6946184635162354
# Training accuracy over whole file: 0.8477370142936707
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 0.066837377846241
# Training loss value at step 100: 0.0669611319899559
# Training loss value at step 200: 0.07410138100385666
# Training loss value at step 300: 0.9610563516616821
# Training loss value at step 400: 0.07894372940063477
# Training loss value at step 500: 0.08481442183256149
# Training loss value at step 600: 0.07158699631690979
# Training loss value at step 700: 0.031975798308849335
# Training accuracy over whole file: 0.8492657542228699
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 4.351557731628418
# Training loss value at step 100: 0.20758002996444702
# Training loss value at step 200: 0.10044974088668823
# Training loss value at step 300: 0.908805251121521
# Training loss value at step 400: 0.8879440426826477
# Training loss value at step 500: 0.10696762800216675
# Training loss value at step 600: 0.03486211597919464
# Training loss value at step 700: 0.02681133896112442
# Training accuracy over whole file: 0.8501662015914917
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 0.06792671233415604
# Training loss value at step 100: 0.03709741681814194
# Training loss value at step 200: 0.025798704475164413
# Training loss value at step 300: 0.03121730126440525
# Training loss value at step 400: 0.032309532165527344
# Training loss value at step 500: 0.004935462959110737
# Training loss value at step 600: 0.010416663251817226
# Training loss value at step 700: 0.02102901041507721
# Training accuracy over whole file: 0.8555174469947815
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 5.950160503387451
# Training loss value at step 100: 3.6850152015686035
# Training loss value at step 200: 2.3113369941711426
# Training loss value at step 300: 0.8804534673690796
# Training loss value at step 400: 0.1811106950044632
# Training loss value at step 500: 1.375380516052246
# Training loss value at step 600: 0.6861408352851868
# Training loss value at step 700: 0.03651612997055054
# Training accuracy over whole file: 0.839966893196106
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 1.5497803688049316
# Training loss value at step 100: 0.018166350200772285
# Training loss value at step 200: 0.21439231932163239
# Training loss value at step 300: 0.17177094519138336
# Training loss value at step 400: 0.009054197929799557
# Training loss value at step 500: 0.025242313742637634
# Training loss value at step 600: 0.2943022847175598
# Training loss value at step 700: 0.049893613904714584
# Training accuracy over whole file: 0.8411293625831604
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 0.03884968161582947
# Training loss value at step 100: 0.012792901135981083
# Training loss value at step 200: 0.002754348563030362
# Training loss value at step 300: 0.0036800061352550983
# Training loss value at step 400: 0.01196528784930706
# Training loss value at step 500: 0.007747245486825705
# Training loss value at step 600: 0.005048740655183792
# Training loss value at step 700: 0.004898807965219021
# Training accuracy over whole file: 0.8462542295455933
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 4.779315948486328
# Training loss value at step 100: 0.3979320228099823
# Training loss value at step 200: 1.2679132223129272
# Training loss value at step 300: 0.23639073967933655
# Training loss value at step 400: 0.8273317813873291
# Training loss value at step 500: 1.1955580711364746
# Training loss value at step 600: 0.04071288928389549
# Training loss value at step 700: 0.08895799517631531
# Training accuracy over whole file: 0.8422092199325562
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 32-40....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 1.9689289331436157
# Training loss value at step 100: 0.15811948478221893
# Training loss value at step 200: 0.1334373503923416
# Training loss value at step 300: 0.12902352213859558
# Training loss value at step 400: 0.21017791330814362
# Training loss value at step 500: 0.31126534938812256
# Training loss value at step 600: 0.008050020784139633
# Training loss value at step 700: 0.022702781483530998
# Training accuracy over whole file: 0.843389630317688
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 3.644558906555176
# Training loss value at step 100: 0.07035353779792786
# Training loss value at step 200: 1.9519016742706299
# Training loss value at step 300: 0.44390740990638733
# Training loss value at step 400: 0.46480312943458557
# Training loss value at step 500: 0.06797293573617935
# Training loss value at step 600: 0.009895672090351582
# Training loss value at step 700: 0.01154362317174673
# Training accuracy over whole file: 0.8431620597839355
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.04010220617055893
# Training loss value at step 100: 0.02789737656712532
# Training loss value at step 200: 0.07789389789104462
# Training loss value at step 300: 2.870425224304199
# Training loss value at step 400: 0.12643012404441833
# Training loss value at step 500: 0.6660236120223999
# Training loss value at step 600: 0.14333193004131317
# Training loss value at step 700: 0.010051349177956581
# Training accuracy over whole file: 0.8442477583885193
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 5.926354885101318
# Training loss value at step 100: 1.017303228378296
# Training loss value at step 200: 2.3985700607299805
# Training loss value at step 300: 0.24316538870334625
# Training loss value at step 400: 0.3346557915210724
# Training loss value at step 500: 0.10629910975694656
# Training loss value at step 600: 0.05501421168446541
# Training loss value at step 700: 0.012210970744490623
# Training accuracy over whole file: 0.8415156602859497
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 6.137284278869629
# Training loss value at step 100: 0.02409042976796627
# Training loss value at step 200: 0.013813727535307407
# Training loss value at step 300: 1.4116300344467163
# Training loss value at step 400: 0.01894674077630043
# Training loss value at step 500: 3.547792673110962
# Training loss value at step 600: 0.02996458299458027
# Training loss value at step 700: 0.0200418159365654
# Training accuracy over whole file: 0.8430655598640442
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 3.9730477333068848
# Training loss value at step 100: 0.20728707313537598
# Training loss value at step 200: 0.38157325983047485
# Training loss value at step 300: 2.19598388671875
# Training loss value at step 400: 0.17012421786785126
# Training loss value at step 500: 0.3297840654850006
# Training loss value at step 600: 0.09836671501398087
# Training loss value at step 700: 0.037430934607982635
# Training accuracy over whole file: 0.8431698679924011
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 1.649461030960083
# Training loss value at step 100: 0.05779493972659111
# Training loss value at step 200: 0.8520768284797668
# Training loss value at step 300: 1.2708885669708252
# Training loss value at step 400: 1.3829398155212402
# Training loss value at step 500: 0.09923671185970306
# Training loss value at step 600: 0.0266091488301754
# Training loss value at step 700: 0.04458318650722504
# Training accuracy over whole file: 0.843528151512146
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.02870786003768444
# Training loss value at step 100: 0.0175793394446373
# Training loss value at step 200: 0.016172531992197037
# Training loss value at step 300: 0.047322314232587814
# Training loss value at step 400: 0.04702164605259895
# Training loss value at step 500: 0.07496122270822525
# Training loss value at step 600: 0.04672965034842491
# Training loss value at step 700: 0.002790725789964199
# Training accuracy over whole file: 0.8445954322814941
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 1.5929750204086304
# Training loss value at step 100: 0.5270683169364929
# Training loss value at step 200: 0.077194944024086
# Training loss value at step 300: 2.4263129234313965
# Training loss value at step 400: 0.48939234018325806
# Training loss value at step 500: 0.12441299110651016
# Training loss value at step 600: 0.18187028169631958
# Training loss value at step 700: 0.014067067764699459
# Training accuracy over whole file: 0.8451173305511475
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 5.5406413078308105
# Training loss value at step 100: 2.347306966781616
# Training loss value at step 200: 2.2479021549224854
# Training loss value at step 300: 4.535410404205322
# Training loss value at step 400: 0.8479720950126648
# Training loss value at step 500: 0.3706102967262268
# Training loss value at step 600: 1.9302072525024414
# Training loss value at step 700: 0.10556814819574356
# Training accuracy over whole file: 0.8324905037879944
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 0.21675896644592285
# Training loss value at step 100: 0.25894203782081604
# Training loss value at step 200: 0.15122465789318085
# Training loss value at step 300: 0.27183815836906433
# Training loss value at step 400: 0.08119089901447296
# Training loss value at step 500: 0.06871386617422104
# Training loss value at step 600: 0.05512579157948494
# Training loss value at step 700: 0.1105031669139862
# Training accuracy over whole file: 0.835739254951477
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 5.796753883361816
# Training loss value at step 100: 0.3170829713344574
# Training loss value at step 200: 0.10654754191637039
# Training loss value at step 300: 0.08288048207759857
# Training loss value at step 400: 1.2323261499404907
# Training loss value at step 500: 0.4192346930503845
# Training loss value at step 600: 0.2342679500579834
# Training loss value at step 700: 0.08609897643327713
# Training accuracy over whole file: 0.8352775573730469
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 4.660987854003906
# Training loss value at step 100: 1.1438660621643066
# Training loss value at step 200: 0.7712612748146057
# Training loss value at step 300: 0.20737311244010925
# Training loss value at step 400: 0.09122937172651291
# Training loss value at step 500: 0.12378311157226562
# Training loss value at step 600: 0.1821431666612625
# Training loss value at step 700: 0.11408059298992157
# Training accuracy over whole file: 0.8337968587875366
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 3.9359192848205566
# Training loss value at step 100: 0.6099968552589417
# Training loss value at step 200: 0.34560272097587585
# Training loss value at step 300: 0.10574651509523392
# Training loss value at step 400: 0.0074178739450871944
# Training loss value at step 500: 0.024254152551293373
# Training loss value at step 600: 0.05414855480194092
# Training loss value at step 700: 0.0288200993090868
# Training accuracy over whole file: 0.8323256373405457
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 2.440532922744751
# Training loss value at step 100: 1.7380867004394531
# Training loss value at step 200: 0.18529818952083588
# Training loss value at step 300: 0.19229432940483093
# Training loss value at step 400: 0.5596691966056824
# Training loss value at step 500: 0.055910903960466385
# Training loss value at step 600: 0.18659010529518127
# Training loss value at step 700: 0.05587122589349747
# Training accuracy over whole file: 0.8314549326896667
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 1.9590985774993896
# Training loss value at step 100: 0.19141100347042084
# Training loss value at step 200: 0.11888519674539566
# Training loss value at step 300: 0.3051859736442566
# Training loss value at step 400: 0.06204918026924133
# Training loss value at step 500: 0.16864408552646637
# Training loss value at step 600: 0.048762641847133636
# Training loss value at step 700: 0.2204039990901947
# Training accuracy over whole file: 0.8314369916915894
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 5.4135565757751465
# Training loss value at step 100: 0.35371097922325134
# Training loss value at step 200: 0.07638561725616455
# Training loss value at step 300: 0.2120969146490097
# Training loss value at step 400: 0.0727861225605011
# Training loss value at step 500: 0.25665074586868286
# Training loss value at step 600: 0.06733778119087219
# Training loss value at step 700: 0.03979134187102318
# Training accuracy over whole file: 0.8313940167427063
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 3.4635205268859863
# Training loss value at step 100: 0.05704733729362488
# Training loss value at step 200: 0.027395622804760933
# Training loss value at step 300: 2.9844892024993896
# Training loss value at step 400: 0.5024290084838867
# Training loss value at step 500: 0.040748368948698044
# Training loss value at step 600: 0.006419395096600056
# Training loss value at step 700: 0.0034383959136903286
# Training accuracy over whole file: 0.8323893547058105
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.013951044529676437
# Training loss value at step 100: 0.011832410469651222
# Training loss value at step 200: 0.4379042983055115
# Training loss value at step 300: 0.03481525927782059
# Training loss value at step 400: 0.01720491610467434
# Training loss value at step 500: 0.0031499075703322887
# Training loss value at step 600: 0.0007173825288191438
# Training loss value at step 700: 0.0008437649230472744
# Training accuracy over whole file: 0.834833025932312
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.012809142470359802
# Training loss value at step 100: 0.008733292110264301
# Training loss value at step 200: 0.01772070862352848
# Training loss value at step 300: 0.05219404399394989
# Training loss value at step 400: 0.09314128011465073
# Training loss value at step 500: 0.0021391860209405422
# Training loss value at step 600: 0.0020550815388560295
# Training loss value at step 700: 0.0012305553536862135
# Training accuracy over whole file: 0.8376932740211487
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 0.004281995818018913
# Training loss value at step 100: 0.002586592920124531
# Training loss value at step 200: 0.004488631151616573
# Training loss value at step 300: 0.004177534487098455
# Training loss value at step 400: 0.05261825770139694
# Training loss value at step 500: 0.010033292695879936
# Training loss value at step 600: 0.0008131535141728818
# Training loss value at step 700: 0.0010871936101466417
# Training accuracy over whole file: 0.8406841158866882
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 5.0114874839782715
# Training loss value at step 100: 5.619098663330078
# Training loss value at step 200: 0.029727041721343994
# Training loss value at step 300: 3.441896438598633
# Training loss value at step 400: 0.12558631598949432
# Training loss value at step 500: 0.03112855739891529
# Training loss value at step 600: 0.012217565439641476
# Training loss value at step 700: 0.010077430866658688
# Training accuracy over whole file: 0.8417146801948547
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.005865267012268305
# Training loss value at step 100: 0.008482261560857296
# Training loss value at step 200: 0.004302412271499634
# Training loss value at step 300: 0.005681911949068308
# Training loss value at step 400: 0.08432596921920776
# Training loss value at step 500: 0.001261630211956799
# Training loss value at step 600: 0.003242594189941883
# Training loss value at step 700: 0.0014942444395273924
# Training accuracy over whole file: 0.8437191247940063
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 0.052806321531534195
# Training loss value at step 100: 0.02110850065946579
# Training loss value at step 200: 0.05131246894598007
# Training loss value at step 300: 0.06411771476268768
# Training loss value at step 400: 0.14584946632385254
# Training loss value at step 500: 0.014839738607406616
# Training loss value at step 600: 0.013697205111384392
# Training loss value at step 700: 0.011899086646735668
# Training accuracy over whole file: 0.8461486101150513
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 6.61484956741333
# Training loss value at step 100: 1.4277516603469849
# Training loss value at step 200: 0.4063023328781128
# Training loss value at step 300: 0.05187763646245003
# Training loss value at step 400: 1.013394832611084
# Training loss value at step 500: 0.08793380856513977
# Training loss value at step 600: 0.02599455416202545
# Training loss value at step 700: 0.024244146421551704
# Training accuracy over whole file: 0.8443453907966614
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 1.4850809574127197
# Training loss value at step 100: 0.5227711796760559
# Training loss value at step 200: 1.3570647239685059
# Training loss value at step 300: 0.10139182955026627
# Training loss value at step 400: 1.5430238246917725
# Training loss value at step 500: 0.29671767354011536
# Training loss value at step 600: 0.4088127017021179
# Training loss value at step 700: 2.0318665504455566
# Training accuracy over whole file: 0.8406643867492676
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 5.676054954528809
# Training loss value at step 100: 2.412773370742798
# Training loss value at step 200: 0.3059538006782532
# Training loss value at step 300: 0.7675833702087402
# Training loss value at step 400: 0.1134425699710846
# Training loss value at step 500: 0.3102310001850128
# Training loss value at step 600: 0.3376352787017822
# Training loss value at step 700: 0.03651992231607437
# Training accuracy over whole file: 0.8392937779426575
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.0344337597489357
# Training loss value at step 100: 0.05714236572384834
# Training loss value at step 200: 0.01655062660574913
# Training loss value at step 300: 0.06092279776930809
# Training loss value at step 400: 0.048179011791944504
# Training loss value at step 500: 0.011811322532594204
# Training loss value at step 600: 0.01569361239671707
# Training loss value at step 700: 0.01120972353965044
# Training accuracy over whole file: 0.8419721722602844
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.004122450482100248
# Training loss value at step 100: 0.00944680068641901
# Training loss value at step 200: 0.02235148847103119
# Training loss value at step 300: 0.024440648034214973
# Training loss value at step 400: 0.025952622294425964
# Training loss value at step 500: 0.01026446558535099
# Training loss value at step 600: 0.04017423838376999
# Training loss value at step 700: 0.01161137968301773
# Training accuracy over whole file: 0.844562828540802
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 7.798243999481201
# Training loss value at step 100: 0.17776797711849213
# Training loss value at step 200: 1.7718430757522583
# Training loss value at step 300: 0.09113415330648422
# Training loss value at step 400: 0.0778665542602539
# Training loss value at step 500: 0.11251699179410934
# Training loss value at step 600: 0.08113692700862885
# Training loss value at step 700: 0.07403009384870529
# Training accuracy over whole file: 0.8438073396682739
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 4.8916916847229
# Training loss value at step 100: 0.05392956733703613
# Training loss value at step 200: 0.4349852204322815
# Training loss value at step 300: 0.05970575660467148
# Training loss value at step 400: 0.009309927001595497
# Training loss value at step 500: 0.48375460505485535
# Training loss value at step 600: 0.052166324108839035
# Training loss value at step 700: 0.019566616043448448
# Training accuracy over whole file: 0.8438785672187805
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.04806574434041977
# Training loss value at step 100: 0.02858240157365799
# Training loss value at step 200: 0.02730584517121315
# Training loss value at step 300: 0.05251974239945412
# Training loss value at step 400: 2.832118034362793
# Training loss value at step 500: 0.9654386639595032
# Training loss value at step 600: 0.002072450239211321
# Training loss value at step 700: 0.004158065654337406
# Training accuracy over whole file: 0.8439475297927856
# ---------------------------------------------------
# --------------------------------------------------------------
# Starting epoch 2
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 3.2102737426757812
# Training loss value at step 100: 1.0155714750289917
# Training loss value at step 200: 0.04662327095866203
# Training loss value at step 300: 0.025344712659716606
# Training loss value at step 400: 1.010025143623352
# Training loss value at step 500: 0.07204920798540115
# Training loss value at step 600: 0.5130305290222168
# Training loss value at step 700: 0.11446329951286316
# Training accuracy over whole file: 0.738305926322937
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 2.001384735107422
# Training loss value at step 100: 0.007702176459133625
# Training loss value at step 200: 0.008717693388462067
# Training loss value at step 300: 0.009660282172262669
# Training loss value at step 400: 0.12475651502609253
# Training loss value at step 500: 0.0020204621832817793
# Training loss value at step 600: 0.008446918800473213
# Training loss value at step 700: 0.050389423966407776
# Training accuracy over whole file: 0.8558786511421204
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 8.99986743927002
# Training loss value at step 100: 2.6346428394317627
# Training loss value at step 200: 0.13909734785556793
# Training loss value at step 300: 0.049639664590358734
# Training loss value at step 400: 0.31352540850639343
# Training loss value at step 500: 0.21681012213230133
# Training loss value at step 600: 0.042999111115932465
# Training loss value at step 700: 0.031441088765859604
# Training accuracy over whole file: 0.8305941820144653
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 0.27261993288993835
# Training loss value at step 100: 0.015784673392772675
# Training loss value at step 200: 3.2656219005584717
# Training loss value at step 300: 0.06295380741357803
# Training loss value at step 400: 0.08747833967208862
# Training loss value at step 500: 0.0227955374866724
# Training loss value at step 600: 0.09378652274608612
# Training loss value at step 700: 0.20119157433509827
# Training accuracy over whole file: 0.8536662459373474
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 0.02204718254506588
# Training loss value at step 100: 0.023983478546142578
# Training loss value at step 200: 0.027241116389632225
# Training loss value at step 300: 0.024499859660863876
# Training loss value at step 400: 2.6442668437957764
# Training loss value at step 500: 0.7781691551208496
# Training loss value at step 600: 0.008068113587796688
# Training loss value at step 700: 0.00412838626652956
# Training accuracy over whole file: 0.8543615937232971
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.007012872491031885
# Training loss value at step 100: 0.008484271354973316
# Training loss value at step 200: 0.009418931789696217
# Training loss value at step 300: 0.021103013306856155
# Training loss value at step 400: 0.11613935232162476
# Training loss value at step 500: 0.05720890313386917
# Training loss value at step 600: 0.0017854715697467327
# Training loss value at step 700: 0.0017313265707343817
# Training accuracy over whole file: 0.8775811195373535
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 6.025282382965088
# Training loss value at step 100: 4.2341084480285645
# Training loss value at step 200: 0.7042552828788757
# Training loss value at step 300: 0.8019296526908875
# Training loss value at step 400: 1.0471794605255127
# Training loss value at step 500: 0.39313557744026184
# Training loss value at step 600: 0.1941303014755249
# Training loss value at step 700: 0.11048096418380737
# Training accuracy over whole file: 0.8361929059028625
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 1.650551199913025
# Training loss value at step 100: 0.05459270998835564
# Training loss value at step 200: 0.029420921579003334
# Training loss value at step 300: 0.190049409866333
# Training loss value at step 400: 0.0363289974629879
# Training loss value at step 500: 0.0197951290756464
# Training loss value at step 600: 0.03088262490928173
# Training loss value at step 700: 0.03760707005858421
# Training accuracy over whole file: 0.8546144366264343
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 4.416305065155029
# Training loss value at step 100: 0.26083654165267944
# Training loss value at step 200: 0.021747451275587082
# Training loss value at step 300: 0.3259139060974121
# Training loss value at step 400: 0.09425247460603714
# Training loss value at step 500: 0.020487943664193153
# Training loss value at step 600: 0.23128029704093933
# Training loss value at step 700: 0.029505303129553795
# Training accuracy over whole file: 0.8579856753349304
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 0.039542146027088165
# Training loss value at step 100: 0.04965168610215187
# Training loss value at step 200: 0.00945353228598833
# Training loss value at step 300: 0.02093527279794216
# Training loss value at step 400: 0.015207182615995407
# Training loss value at step 500: 0.007018199656158686
# Training loss value at step 600: 0.00704779289662838
# Training loss value at step 700: 0.0024946779012680054
# Training accuracy over whole file: 0.8720606565475464
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 6.5861616134643555
# Training loss value at step 100: 2.0404582023620605
# Training loss value at step 200: 3.7435150146484375
# Training loss value at step 300: 0.7012916803359985
# Training loss value at step 400: 0.41746631264686584
# Training loss value at step 500: 0.7394737005233765
# Training loss value at step 600: 0.28733524680137634
# Training loss value at step 700: 0.15063203871250153
# Training accuracy over whole file: 0.8496724367141724
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 4.394717693328857
# Training loss value at step 100: 0.7403249740600586
# Training loss value at step 200: 0.967992901802063
# Training loss value at step 300: 0.07473867386579514
# Training loss value at step 400: 0.16147048771381378
# Training loss value at step 500: 0.1744113564491272
# Training loss value at step 600: 0.026411330327391624
# Training loss value at step 700: 0.024221688508987427
# Training accuracy over whole file: 0.8480826020240784
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.3740179240703583
# Training loss value at step 100: 0.18552833795547485
# Training loss value at step 200: 0.13585948944091797
# Training loss value at step 300: 0.12759341299533844
# Training loss value at step 400: 0.24068526923656464
# Training loss value at step 500: 0.329370379447937
# Training loss value at step 600: 0.017604991793632507
# Training loss value at step 700: 0.012324251234531403
# Training accuracy over whole file: 0.8579208254814148
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 6.2933478355407715
# Training loss value at step 100: 0.04520754516124725
# Training loss value at step 200: 0.09682528674602509
# Training loss value at step 300: 1.963395118713379
# Training loss value at step 400: 0.2447444647550583
# Training loss value at step 500: 0.043465934693813324
# Training loss value at step 600: 0.03896159306168556
# Training loss value at step 700: 0.05384925752878189
# Training accuracy over whole file: 0.8537113666534424
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.19160903990268707
# Training loss value at step 100: 0.023316025733947754
# Training loss value at step 200: 0.17737051844596863
# Training loss value at step 300: 0.018200766295194626
# Training loss value at step 400: 0.023420602083206177
# Training loss value at step 500: 0.004496107809245586
# Training loss value at step 600: 0.0014846028061583638
# Training loss value at step 700: 0.0007876630988903344
# Training accuracy over whole file: 0.8601769804954529
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.010333133861422539
# Training loss value at step 100: 0.005714626982808113
# Training loss value at step 200: 0.007349122781306505
# Training loss value at step 300: 0.012177172116935253
# Training loss value at step 400: 0.0015120989410206676
# Training loss value at step 500: 0.0008842610404826701
# Training loss value at step 600: 0.0002134810492862016
# Training loss value at step 700: 0.0008587724878452718
# Training accuracy over whole file: 0.8678097128868103
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 5.546024322509766
# Training loss value at step 100: 0.03338189423084259
# Training loss value at step 200: 0.11098625510931015
# Training loss value at step 300: 0.17811869084835052
# Training loss value at step 400: 1.4508883953094482
# Training loss value at step 500: 0.8326139450073242
# Training loss value at step 600: 0.43639251589775085
# Training loss value at step 700: 0.20078840851783752
# Training accuracy over whole file: 0.8657693266868591
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 0.0181988924741745
# Training loss value at step 100: 0.0024750572629272938
# Training loss value at step 200: 0.009314415045082569
# Training loss value at step 300: 0.8030483722686768
# Training loss value at step 400: 0.303964227437973
# Training loss value at step 500: 0.10330398380756378
# Training loss value at step 600: 0.04531065374612808
# Training loss value at step 700: 0.028040308505296707
# Training accuracy over whole file: 0.8719623684883118
# ...
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 0.015122761018574238
# Training loss value at step 100: 0.006097523961216211
# Training loss value at step 200: 0.00100740697234869
# Training loss value at step 300: 0.500204861164093
# Training loss value at step 400: 0.009324808605015278
# Training loss value at step 500: 0.0009296386269852519
# Training loss value at step 600: 0.0023291383404284716
# Training loss value at step 700: 0.00019834458362311125
# Training accuracy over whole file: 0.9627864956855774
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.0018297373317182064
# Training loss value at step 100: 0.001409014337696135
# Training loss value at step 200: 0.001019792165607214
# Training loss value at step 300: 0.002695262897759676
# Training loss value at step 400: 1.6760419607162476
# Training loss value at step 500: 0.0026856327895075083
# Training loss value at step 600: 0.0010981488740071654
# Training loss value at step 700: 0.00021550717065110803
# Training accuracy over whole file: 0.9625474214553833
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 2.323667287826538
# Training loss value at step 100: 0.022756151854991913
# Training loss value at step 200: 0.001780949649401009
# Training loss value at step 300: 0.0020402108784765005
# Training loss value at step 400: 0.21354852616786957
# Training loss value at step 500: 0.002149297157302499
# Training loss value at step 600: 0.002928732428699732
# Training loss value at step 700: 0.00019774865359067917
# Training accuracy over whole file: 0.9625049829483032
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 6.543879508972168
# Training loss value at step 100: 2.777815103530884
# Training loss value at step 200: 0.7878918647766113
# Training loss value at step 300: 0.10965210199356079
# Training loss value at step 400: 0.00312530854716897
# Training loss value at step 500: 0.010383039712905884
# Training loss value at step 600: 0.7383577823638916
# Training loss value at step 700: 0.18106314539909363
# Training accuracy over whole file: 0.9608091115951538
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 0.05053166672587395
# Training loss value at step 100: 0.017322085797786713
# Training loss value at step 200: 0.001705383649095893
# Training loss value at step 300: 0.0018995827995240688
# Training loss value at step 400: 0.0002466136065777391
# Training loss value at step 500: 0.004351314157247543
# Training loss value at step 600: 0.0028317375108599663
# Training loss value at step 700: 0.0005361788207665086
# Training accuracy over whole file: 0.9616323113441467
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 1.3784476518630981
# Training loss value at step 100: 0.009211186319589615
# Training loss value at step 200: 0.003811596194282174
# Training loss value at step 300: 0.035235513001680374
# Training loss value at step 400: 0.6034311652183533
# Training loss value at step 500: 0.016574544832110405
# Training loss value at step 600: 0.013351202942430973
# Training loss value at step 700: 0.01381643209606409
# Training accuracy over whole file: 0.9612975716590881
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 7.949225902557373
# Training loss value at step 100: 0.01674254983663559
# Training loss value at step 200: 0.10888327658176422
# Training loss value at step 300: 0.0020059479866176844
# Training loss value at step 400: 0.11444161087274551
# Training loss value at step 500: 0.01623399369418621
# Training loss value at step 600: 0.0027718241326510906
# Training loss value at step 700: 0.02343597449362278
# Training accuracy over whole file: 0.9602752923965454
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 0.03785720840096474
# Training loss value at step 100: 0.07430625706911087
# Training loss value at step 200: 0.013971381820738316
# Training loss value at step 300: 0.0047086309641599655
# Training loss value at step 400: 0.019923096522688866
# Training loss value at step 500: 0.07394374161958694
# Training loss value at step 600: 0.001618743408471346
# Training loss value at step 700: 0.0015457835979759693
# Training accuracy over whole file: 0.9602319598197937
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 0.9943102598190308
# Training loss value at step 100: 0.010196263901889324
# Training loss value at step 200: 0.015553130768239498
# Training loss value at step 300: 0.004508212208747864
# Training loss value at step 400: 0.5540866851806641
# Training loss value at step 500: 1.5416736602783203
# Training loss value at step 600: 0.004018328618258238
# Training loss value at step 700: 0.004021890461444855
# Training accuracy over whole file: 0.959679365158081
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 0.03622231259942055
# Training loss value at step 100: 0.00040820849244482815
# Training loss value at step 200: 0.00389519683085382
# Training loss value at step 300: 0.030781369656324387
# Training loss value at step 400: 0.007996213622391224
# Training loss value at step 500: 0.00516200577840209
# Training loss value at step 600: 0.02218535542488098
# Training loss value at step 700: 0.011147480458021164
# Training accuracy over whole file: 0.9585703611373901
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 6.988594055175781
# Training loss value at step 100: 0.056661274284124374
# Training loss value at step 200: 0.002167496830224991
# Training loss value at step 300: 0.006808534264564514
# Training loss value at step 400: 0.0446946807205677
# Training loss value at step 500: 0.0066669173538684845
# Training loss value at step 600: 0.0017203782917931676
# Training loss value at step 700: 0.00944160483777523
# Training accuracy over whole file: 0.9580742716789246
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 0.008812346495687962
# Training loss value at step 100: 0.010630998760461807
# Training loss value at step 200: 0.007789710536599159
# Training loss value at step 300: 0.010903187096118927
# Training loss value at step 400: 0.37241512537002563
# Training loss value at step 500: 0.005506110843271017
# Training loss value at step 600: 0.000706780469045043
# Training loss value at step 700: 0.0008291144040413201
# Training accuracy over whole file: 0.9584071040153503
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.0010700459824874997
# Training loss value at step 100: 0.0010412277188152075
# Training loss value at step 200: 0.0011388728162273765
# Training loss value at step 300: 0.001887565478682518
# Training loss value at step 400: 0.004610621836036444
# Training loss value at step 500: 0.00034290633630007505
# Training loss value at step 600: 0.00017998983094003052
# Training loss value at step 700: 0.00013791563105769455
# Training accuracy over whole file: 0.9585781097412109
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 0.0016349294455721974
# Training loss value at step 100: 0.002752565313130617
# Training loss value at step 200: 0.0023930028546601534
# Training loss value at step 300: 0.0038885469548404217
# Training loss value at step 400: 0.5992429256439209
# Training loss value at step 500: 0.00023469554434996098
# Training loss value at step 600: 0.00038675934774801135
# Training loss value at step 700: 0.00035589560866355896
# Training accuracy over whole file: 0.9591559171676636
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 0.0009089152445085347
# Training loss value at step 100: 0.0008747326792217791
# Training loss value at step 200: 0.0011595914838835597
# Training loss value at step 300: 0.0013105622492730618
# Training loss value at step 400: 1.6070950031280518
# Training loss value at step 500: 0.006139466539025307
# Training loss value at step 600: 0.00029905137489549816
# Training loss value at step 700: 0.00011121608258690685
# Training accuracy over whole file: 0.9597834348678589
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 0.0675404816865921
# Training loss value at step 100: 0.003097381442785263
# Training loss value at step 200: 0.0027184458449482918
# Training loss value at step 300: 1.5544211864471436
# Training loss value at step 400: 0.006445571314543486
# Training loss value at step 500: 0.003909208811819553
# Training loss value at step 600: 0.0007398966699838638
# Training loss value at step 700: 0.024091128259897232
# Training accuracy over whole file: 0.9603174328804016
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.000596107158344239
# Training loss value at step 100: 0.0006478118011727929
# Training loss value at step 200: 0.0011133907828480005
# Training loss value at step 300: 0.03336702287197113
# Training loss value at step 400: 0.2020667940378189
# Training loss value at step 500: 0.051827043294906616
# Training loss value at step 600: 0.00010251473577227443
# Training loss value at step 700: 0.00010430268594063818
# Training accuracy over whole file: 0.9609470367431641
# ---------------------------------------------------
# Fitting on file 8 containing task: task_story_math
# Training loss value at step 0: 0.0028851095121353865
# Training loss value at step 100: 0.0026688692159950733
# Training loss value at step 200: 0.00019167017308063805
# Training loss value at step 300: 0.002685870509594679
# Training loss value at step 400: 0.8763832449913025
# Training loss value at step 500: 0.0005250982358120382
# Training loss value at step 600: 0.0004967409186065197
# Training loss value at step 700: 0.0002004899288294837
# Training accuracy over whole file: 0.9615541100502014
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 6.823451995849609
# Training loss value at step 100: 0.004767004866153002
# Training loss value at step 200: 0.0029377657920122147
# Training loss value at step 300: 0.006355431862175465
# Training loss value at step 400: 0.06331071257591248
# Training loss value at step 500: 0.0004390706308186054
# Training loss value at step 600: 0.0024312958121299744
# Training loss value at step 700: 0.001023007556796074
# Training accuracy over whole file: 0.9614301323890686
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 5.031594276428223
# Training loss value at step 100: 0.0025307077448815107
# Training loss value at step 200: 0.5209345817565918
# Training loss value at step 300: 0.0037017411086708307
# Training loss value at step 400: 0.00032026408007368445
# Training loss value at step 500: 0.6154903173446655
# Training loss value at step 600: 0.006110438611358404
# Training loss value at step 700: 0.00086198840290308
# Training accuracy over whole file: 0.9609834551811218
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 6.356917858123779
# Training loss value at step 100: 3.188063621520996
# Training loss value at step 200: 0.002849211450666189
# Training loss value at step 300: 0.019295841455459595
# Training loss value at step 400: 0.0011980506824329495
# Training loss value at step 500: 0.013073444366455078
# Training loss value at step 600: 0.0013738964917138219
# Training loss value at step 700: 0.0003970073303207755
# Training accuracy over whole file: 0.9608091115951538
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 0.00018726025882642716
# Training loss value at step 100: 0.00017617580306250602
# Training loss value at step 200: 0.00035446559195406735
# Training loss value at step 300: 0.04349127411842346
# Training loss value at step 400: 0.0008939084364101291
# Training loss value at step 500: 0.0004602803383022547
# Training loss value at step 600: 0.0009995469590649009
# Training loss value at step 700: 0.00025233422638848424
# Training accuracy over whole file: 0.9614201188087463
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.00014220656885299832
# Training loss value at step 100: 6.913899414939806e-05
# Training loss value at step 200: 0.0008379285573028028
# Training loss value at step 300: 0.008879461325705051
# Training loss value at step 400: 0.0004325169720686972
# Training loss value at step 500: 0.0017597679980099201
# Training loss value at step 600: 0.0005926521262153983
# Training loss value at step 700: 0.00026901919045485556
# Training accuracy over whole file: 0.962052583694458
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 8.77751636505127
# Training loss value at step 100: 0.10864099115133286
# Training loss value at step 200: 0.04630634933710098
# Training loss value at step 300: 0.0017151420470327139
# Training loss value at step 400: 0.0010063351364806294
# Training loss value at step 500: 0.0003921216703020036
# Training loss value at step 600: 0.006513910833746195
# Training loss value at step 700: 0.0013429442187771201
# Training accuracy over whole file: 0.9615431427955627
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 5.189965724945068
# Training loss value at step 100: 0.0036599335726350546
# Training loss value at step 200: 0.009582829661667347
# Training loss value at step 300: 0.001446987851522863
# Training loss value at step 400: 0.14799772202968597
# Training loss value at step 500: 0.005652989260852337
# Training loss value at step 600: 0.0002033503697020933
# Training loss value at step 700: 0.0005239067832008004
# Training accuracy over whole file: 0.9614713191986084
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.0012054328108206391
# Training loss value at step 100: 0.0014934111386537552
# Training loss value at step 200: 0.014382388442754745
# Training loss value at step 300: 0.001953480765223503
# Training loss value at step 400: 4.692103385925293
# Training loss value at step 500: 0.0009759668610058725
# Training loss value at step 600: 0.00025138078490272164
# Training loss value at step 700: 0.00032634177478030324
# Training accuracy over whole file: 0.9611449241638184
# ---------------------------------------------------
# --------------------------------------------------------------
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.dense.Dense object at 0x38ac66b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.dense.Dense object at 0x38ac66b10>, because it is not built.
# INFO:tensorflow:Assets written to: models/trained_LSTM_e4_5_20_cross/assets
# INFO:tensorflow:Assets written to: models/trained_LSTM_e4_5_20_cross/assets

# %%
new_model = keras.models.load_model("/content/content/MyDrive/trained_LSTM_e4_20_20_cross")
new_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "just_lstm_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm1 (LSTM)                multiple                  21520
#
#  lstm2 (LSTM)                multiple                  3280
#
#  dense_7 (Dense)             multiple                  0
#
#  output (Dense)              multiple                  84
#
# =================================================================
# Total params: 24884 (97.20 KB)
# Trainable params: 24884 (97.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_arr = [tensor.numpy() for tensor in losses]

# %%
print(loss_arr)
# Out:
# [8.416853, 14.597052, 19.167416, 22.369194, 24.751888]

# %%
acc_arr = [tensor.numpy() for tensor in accuracies]

# %%
print(acc_arr)
# Out:
# [4.889338, 10.621641, 16.987432, 23.835, 30.890198]
