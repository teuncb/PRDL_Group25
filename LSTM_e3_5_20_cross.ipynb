# %%
import re
import random
import os
import numpy as np
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import LabelBinarizer

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import logging
from sklearn.preprocessing import LabelBinarizer


class JustLSTM(keras.Model):
    def __init__(self, input_shape, timeframe, LSTM_units, dense_units, num_classes=4):
        super().__init__()

        # TODO: kijken of we input shape niet uit elkaar trekken in width, height, batch_size en timesteps (nu num_segments)
        self.in_shape = input_shape
        self.num_classes = num_classes
        self.LSTM_units = LSTM_units

        # The number of images / timesteps that we will look at for each training step
        self.timeframe = timeframe

        self.lstm1 = keras.layers.LSTM(self.LSTM_units, return_sequences=True, name="lstm1")
        self.lstm2 = keras.layers.LSTM(self.LSTM_units, name="lstm2")

        self.fc = keras.layers.Dense(dense_units, activation="relu")

        self.out = keras.layers.Dense(self.num_classes, activation="softmax", name="output")

    def call(self, inputs, training=True, mask=None):
        """
        Specifies how the inputs should be passed through the layers of the model and returns the output

        :param inputs: the inputs to be classified by the model, with the same shape as self.in_shape
        :param training: whether the gradients should be tracked
        :param mask: whether a certain mask should be applied on the inputs (such as masking certain timesteps)
        :return: probabilities for each of the classes
        """

        input_layer = keras.layers.InputLayer(self.in_shape, name="input")(inputs)

        # Pass the timesteps through the RNN to find temporal features The amount of units in the layer are equal to
        # the number of timesteps (i.e. segments) according to Zhang et al. (2018)
        lstm1 = self.lstm1(input_layer)
        lstm2 = self.lstm2(lstm1)

        #fc = self.fc(lstm2)

        # Final fully connected layer with softmax to give class probabilities
        output = self.out(lstm2)

        return output

    def build_graph(self):
        """
        Builds the Tensor Graph in order to generate a summary of the model by running dummy input through the model
        :return: a 'dummy' version of the model of which we can generate a summary
        """
        x = keras.Input(self.in_shape)
        return keras.Model(inputs=[x], outputs=self.call(x))

# %%
def create_windows(dataset, model_type, timeframe):
    # Will contain the slices of the dataset that represent the different windows
    windows = []

    if model_type == "cascade":
        num_windows = int(dataset.shape[2] / timeframe)
    else:
        num_windows = int(dataset.shape[1] / timeframe)

    i = timeframe
    j = 0
    count = 0

    # Loop through the dataset until we have the specified number of windows (might cut off some of the last timesteps)
    while count < num_windows:
        # Save the view of the array in the windows list
        if model_type == "cascade":
            view = dataset[:, :, j:i]
        else:
            view = dataset[:, j:i]
        windows.append(view)

        i += timeframe
        j += timeframe
        count += 1
    # Return the list of array views
    return windows


def read_prepro_file(data_path):
    hfive = h5py.File(data_path, 'r')
    matrix = hfive.get('dir')
    matrix = np.array(matrix)
    return matrix

# %%
import tensorflow as tf
from tensorflow import keras
import re
import os
import random
import numpy as np


# tf function zal niet heel veel uitmaken volgens de documentatie, omdat wij veel convolutional operations hebben (waarbij de speedup dus meevalt)
def train_epoch(model, x_train, y_train, optimizer, train_acc):
    # Instantiate an optimizer and loss function
    loss_function = keras.losses.CategoricalCrossentropy()

    total_loss = 0

    # Doet nu nog wel een update per window, wellicht veel? We kunnen ook nog batches gaan gebruiken om het aantal updates te reduceren
    for step in range(len(x_train)):
        # Used to track the gradients during the forward pass
        with tf.GradientTape() as tape:
            logits = model(tf.expand_dims(x_train[step], axis=0), training=True)
            # Calculate the loss value
            loss_value = loss_function(y_train[step], logits)

        total_loss += loss_value

        # Extract the gradients from the gradienttape
        grads = tape.gradient(loss_value, model.trainable_weights)

        # Perform a weight update step using the extracted gradients
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        # Keep track of the training accuracy which is given at the end of the loop
        train_acc.update_state(y_train[step], logits)

        # Report the training loss for monitoring
        if step % 100 == 0:
            print("Training loss value at step {}: {}".format(step, loss_value))

    print("Training accuracy over whole file: {}".format(train_acc.result()))
    print("---------------------------------------------------")
    average_loss = total_loss / len(x_train)
    return average_loss, train_acc


# TODO: kijken of we de input als tensors willen doen (wat wel netter is I guess) of makkelijker als np arrays --> netwerk vindt allebei goed
def fit_eight(model, model_type, dirlist, parent_path, optimizer, timeframe, label_encoder,
              train_acc_obj):  # Fit a network on 8 datafiles at a time.
    fit_list = []
    average_loss = 0
    i = 0
    j = 0
    while i < 8:  # Load the 8 datafiles
        filename = parent_path + "/" + dirlist[i]

        data = read_prepro_file(filename)
        label = extract_label(filename)

        fit_list.append((data, label))
        i += 1

    for counter, (data, label) in enumerate(fit_list):
        print("Fitting on file {} containing task: {}".format((counter + 1), label))
        # Creates windows of length 'timeframe' to fit the model on
        windows = create_windows(data, model_type, timeframe)
        x_train = []
        # Only needed for CascadeNet, not for the LSTM network
        for window in windows:
            if model_type == "cascade":
                x_train.append(tf.convert_to_tensor(window))
            else:
                x_train.append(tf.convert_to_tensor(np.transpose(window)))

        # Encode the textual label to one-hot-encoding
        encoded_label = label_encoder.transform([label])
        # Create a list of tensors, each corresponding to an encoded label
        y_train = [tf.convert_to_tensor(encoded_label)] * len(x_train)

        # Fit the model on the data from this specific file
        average_loss, train_acc_obj = train_epoch(model, x_train, y_train, optimizer, train_acc_obj)

    return average_loss, train_acc_obj


def train_dir(model, model_type, dirpath, epochs, timeframe, optimizer, label_encoder,
              shuffle=True):  # Train a network on a given directory
    dirnames = os.listdir(dirpath)  # get list of all filenames
    random.shuffle(dirnames)
    batches = len(dirnames) // 8  # int divide by eight to avoid float errors

    train_acc_obj = keras.metrics.CategoricalAccuracy()

    average_epoch_accuracy = 0
    average_epoch_loss = 0
    losses = []
    accuracies = []

    # Check if it is divisible by eight
    if not (len(dirnames) % 8) == 0:
        raise TypeError("Not divisible by eight")

    for epoch in range(epochs):
        print("Starting epoch {}".format(epoch + 1))
        print()
        train_acc_obj.reset_states()
        for i in range(batches):  # Fit on 8 batches at a time                HIER IPV 1 WEER 'BATCHES' NEERZETTEN
            print("Fitting on files {}-{}....".format((i * 8), ((i + 1) * 8)))
            # Fits the model on 8 files for the specified amount of epochs
            average_loss, train_acc_obj = fit_eight(model, model_type, dirnames[i * 8:(i + 1) * 8], dirpath, optimizer,
                                                    timeframe, label_encoder, train_acc_obj)
            average_epoch_loss += average_loss
            average_epoch_accuracy += train_acc_obj.result()

            print("--------------------------------------------------------------")

        losses.append(average_epoch_loss)
        accuracies.append(average_epoch_accuracy)

    # SAVE THE MODEL AFTER TRAINING!!!!
    model.save("models/trained_LSTM_e3_5_20_cross")

    return model, losses, accuracies


def extract_label(filename):  # Extract the label out of a filename
    filename = filename.split("/")
    pattern = r'_\d'
    split = re.split(pattern, filename[-1])
    return split[0]

# %%
from sklearn.preprocessing import LabelBinarizer
import tensorflow
from tensorflow import keras

output_classes = 4

# Hyperparameters
timeframe = 5
LSTM_units = 20
# (1e-2, 1e-3, 1e-4)
learning_rate = 1e-3

epochs = 5



textual_labels = ["rest", "task_motor", "task_story_math", "task_working_memory"]
label_encoder = LabelBinarizer()
label_encoder.fit(textual_labels)

model = JustLSTM((timeframe, 248), timeframe, LSTM_units, 16, output_classes)
model_type = "lstm"

optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

model, losses, accuracies = train_dir(model, model_type, "data/Cross/train_prepro", epochs, timeframe, optimizer, label_encoder)
# Out:
# Starting epoch 1
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 1.4756965637207031
# Training loss value at step 100: 0.011132626794278622
# Training loss value at step 200: 0.0031871020328253508
# Training loss value at step 300: 0.7768182754516602
# Training loss value at step 400: 0.002540695946663618
# Training loss value at step 500: 0.00036483307485468686
# Training loss value at step 600: 0.00022396916756406426
# Training loss value at step 700: 0.0001433984871255234
# Training accuracy over whole file: 0.9949430823326111
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 10.38430118560791
# Training loss value at step 100: 0.025775006040930748
# Training loss value at step 200: 0.01771649159491062
# Training loss value at step 300: 0.01693267934024334
# Training loss value at step 400: 0.005649670492857695
# Training loss value at step 500: 0.004641236271709204
# Training loss value at step 600: 0.0038682410959154367
# Training loss value at step 700: 0.0010898133041337132
# Training accuracy over whole file: 0.9785082340240479
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 6.296614646911621
# Training loss value at step 100: 0.016188016161322594
# Training loss value at step 200: 0.0085345059633255
# Training loss value at step 300: 0.004380274564027786
# Training loss value at step 400: 0.0027027528267353773
# Training loss value at step 500: 0.0024380742106586695
# Training loss value at step 600: 0.014768090099096298
# Training loss value at step 700: 0.001642546383664012
# Training accuracy over whole file: 0.982722282409668
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 6.292044162750244
# Training loss value at step 100: 0.022359531372785568
# Training loss value at step 200: 0.00905254390090704
# Training loss value at step 300: 0.034799255430698395
# Training loss value at step 400: 0.0026347467210143805
# Training loss value at step 500: 0.0031093843281269073
# Training loss value at step 600: 0.004192017484456301
# Training loss value at step 700: 0.006947526708245277
# Training accuracy over whole file: 0.9766119122505188
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 8.94856071472168
# Training loss value at step 100: 0.040285542607307434
# Training loss value at step 200: 0.02154831774532795
# Training loss value at step 300: 0.012921414338052273
# Training loss value at step 400: 0.013209921307861805
# Training loss value at step 500: 0.01571696624159813
# Training loss value at step 600: 0.003661477705463767
# Training loss value at step 700: 0.0015067425556480885
# Training accuracy over whole file: 0.9724399447441101
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.0007496645557694137
# Training loss value at step 100: 0.000673424918204546
# Training loss value at step 200: 0.0007390628452412784
# Training loss value at step 300: 0.0005438040825538337
# Training loss value at step 400: 0.0007757514831610024
# Training loss value at step 500: 0.0011712603736668825
# Training loss value at step 600: 0.001517931348644197
# Training loss value at step 700: 0.0011892396723851562
# Training accuracy over whole file: 0.9770333170890808
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 0.0004379982128739357
# Training loss value at step 100: 0.00040260792593471706
# Training loss value at step 200: 0.0003948624071199447
# Training loss value at step 300: 0.0003672163875307888
# Training loss value at step 400: 0.0019683525897562504
# Training loss value at step 500: 0.0008431693422608078
# Training loss value at step 600: 0.0008223251206800342
# Training loss value at step 700: 0.00086198840290308
# Training accuracy over whole file: 0.9803142547607422
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 9.000662803649902
# Training loss value at step 100: 0.015243110246956348
# Training loss value at step 200: 0.008277987129986286
# Training loss value at step 300: 0.006065769586712122
# Training loss value at step 400: 0.002659357851371169
# Training loss value at step 500: 0.0013594918418675661
# Training loss value at step 600: 0.0011706650257110596
# Training loss value at step 700: 0.0010802869219332933
# Training accuracy over whole file: 0.9810366630554199
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 0.000730128725990653
# Training loss value at step 100: 0.0017448929138481617
# Training loss value at step 200: 0.0019405120983719826
# Training loss value at step 300: 0.0005154472892172635
# Training loss value at step 400: 0.0006422125734388828
# Training loss value at step 500: 0.0005081792478449643
# Training loss value at step 600: 0.0007251255447044969
# Training loss value at step 700: 0.0005173536483198404
# Training accuracy over whole file: 0.9817389845848083
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 9.061551094055176
# Training loss value at step 100: 0.006092547904700041
# Training loss value at step 200: 0.005355298053473234
# Training loss value at step 300: 0.0029898248612880707
# Training loss value at step 400: 0.00167753582354635
# Training loss value at step 500: 0.0010301527800038457
# Training loss value at step 600: 0.0008673481643199921
# Training loss value at step 700: 0.001057304092682898
# Training accuracy over whole file: 0.9812895059585571
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 11.117602348327637
# Training loss value at step 100: 0.02516896463930607
# Training loss value at step 200: 0.23528063297271729
# Training loss value at step 300: 0.01307815033942461
# Training loss value at step 400: 0.013787860982120037
# Training loss value at step 500: 0.05773497000336647
# Training loss value at step 600: 0.007219536229968071
# Training loss value at step 700: 0.007121535949409008
# Training accuracy over whole file: 0.9795425534248352
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 2.976451873779297
# Training loss value at step 100: 0.004279265645891428
# Training loss value at step 200: 0.0013774678809568286
# Training loss value at step 300: 0.0012276978231966496
# Training loss value at step 400: 0.009979828260838985
# Training loss value at step 500: 0.0010307481279596686
# Training loss value at step 600: 0.0036348719149827957
# Training loss value at step 700: 0.0006236277404241264
# Training accuracy over whole file: 0.97945636510849
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 0.0009482178138568997
# Training loss value at step 100: 0.0012537722941488028
# Training loss value at step 200: 0.018436847254633904
# Training loss value at step 300: 0.0006308949086815119
# Training loss value at step 400: 0.0003843760641757399
# Training loss value at step 500: 0.0003510097449179739
# Training loss value at step 600: 0.33945727348327637
# Training loss value at step 700: 0.00022492263815365732
# Training accuracy over whole file: 0.9810366630554199
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 8.394619941711426
# Training loss value at step 100: 0.016873370856046677
# Training loss value at step 200: 0.46151795983314514
# Training loss value at step 300: 0.005042691715061665
# Training loss value at step 400: 0.011722725816071033
# Training loss value at step 500: 0.03411686420440674
# Training loss value at step 600: 0.010240866802632809
# Training loss value at step 700: 0.004753123503178358
# Training accuracy over whole file: 0.979411244392395
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 9.158622741699219
# Training loss value at step 100: 0.009216147474944592
# Training loss value at step 200: 0.004691308364272118
# Training loss value at step 300: 0.005548196844756603
# Training loss value at step 400: 0.003312697634100914
# Training loss value at step 500: 0.0022361292503774166
# Training loss value at step 600: 0.0027246277313679457
# Training loss value at step 700: 0.022000538185238838
# Training accuracy over whole file: 0.9782553911209106
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 7.091100215911865
# Training loss value at step 100: 0.009912315756082535
# Training loss value at step 200: 0.019264737144112587
# Training loss value at step 300: 0.005338578950613737
# Training loss value at step 400: 0.005321741569787264
# Training loss value at step 500: 0.002903652610257268
# Training loss value at step 600: 0.0018120075110346079
# Training loss value at step 700: 0.0013829439412802458
# Training accuracy over whole file: 0.9777970910072327
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 7.841398239135742
# Training loss value at step 100: 0.049591563642024994
# Training loss value at step 200: 0.0118780005723238
# Training loss value at step 300: 0.010100796818733215
# Training loss value at step 400: 0.2840290665626526
# Training loss value at step 500: 0.008057706989347935
# Training loss value at step 600: 0.0027394883800297976
# Training loss value at step 700: 0.004626878537237644
# Training accuracy over whole file: 0.9761285185813904
# ---------------------------------------------------
# Fitting on file 2 containing task: rest
# Training loss value at step 0: 0.7591461539268494
# Training loss value at step 100: 0.007065430283546448
# Training loss value at step 200: 0.010541354306042194
# Training loss value at step 300: 0.0031983908265829086
# Training loss value at step 400: 0.0031010655220597982
# Training loss value at step 500: 0.004580363165587187
# Training loss value at step 600: 0.009608332999050617
# Training loss value at step 700: 1.6710125207901
# Training accuracy over whole file: 0.976190447807312
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 10.022151947021484
# Training loss value at step 100: 0.1256737858057022
# Training loss value at step 200: 0.018960893154144287
# Training loss value at step 300: 0.005183708854019642
# Training loss value at step 400: 0.013248507864773273
# Training loss value at step 500: 0.009863566607236862
# Training loss value at step 600: 0.006459665950387716
# Training loss value at step 700: 0.005090727470815182
# Training accuracy over whole file: 0.9753809571266174
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 0.002120034070685506
# Training loss value at step 100: 0.004178840201348066
# Training loss value at step 200: 0.0027938163839280605
# Training loss value at step 300: 0.0034833012614399195
# Training loss value at step 400: 0.0029640335123986006
# Training loss value at step 500: 0.0026373625732958317
# Training loss value at step 600: 0.0028293600771576166
# Training loss value at step 700: 0.002186885569244623
# Training accuracy over whole file: 0.9766119122505188
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 8.325235366821289
# Training loss value at step 100: 0.2634252607822418
# Training loss value at step 200: 0.012215680442750454
# Training loss value at step 300: 0.007705725263804197
# Training loss value at step 400: 0.0064188027754426
# Training loss value at step 500: 0.004203176125884056
# Training loss value at step 600: 0.0047214450314641
# Training loss value at step 700: 0.005122038535773754
# Training accuracy over whole file: 0.9746553301811218
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 5.887977123260498
# Training loss value at step 100: 0.021824900060892105
# Training loss value at step 200: 0.006535228807479143
# Training loss value at step 300: 0.015781505033373833
# Training loss value at step 400: 0.003146936884149909
# Training loss value at step 500: 0.004098231438547373
# Training loss value at step 600: 0.0009738231892697513
# Training loss value at step 700: 0.01037808507680893
# Training accuracy over whole file: 0.9742558598518372
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 9.941123962402344
# Training loss value at step 100: 0.025979802012443542
# Training loss value at step 200: 0.004268345423042774
# Training loss value at step 300: 0.0071989428251981735
# Training loss value at step 400: 0.020643731579184532
# Training loss value at step 500: 0.0030061076395213604
# Training loss value at step 600: 0.015355813317000866
# Training loss value at step 700: 0.0006802152493037283
# Training accuracy over whole file: 0.9746605753898621
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 6.324634552001953
# Training loss value at step 100: 0.036436017602682114
# Training loss value at step 200: 0.008077573031187057
# Training loss value at step 300: 0.011915460228919983
# Training loss value at step 400: 0.0033905182499438524
# Training loss value at step 500: 0.0015768486773595214
# Training loss value at step 600: 0.002849211450666189
# Training loss value at step 700: 0.005332294851541519
# Training accuracy over whole file: 0.9738200306892395
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 24-32....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 0.0006744970451109111
# Training loss value at step 100: 0.0006831934442743659
# Training loss value at step 200: 0.0005958688561804593
# Training loss value at step 300: 0.001090765930712223
# Training loss value at step 400: 0.003529155161231756
# Training loss value at step 500: 0.0010657589882612228
# Training loss value at step 600: 0.00195312371943146
# Training loss value at step 700: 0.0005504761938937008
# Training accuracy over whole file: 0.9748672842979431
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 7.065610885620117
# Training loss value at step 100: 0.04358748346567154
# Training loss value at step 200: 4.012993335723877
# Training loss value at step 300: 0.01203160174190998
# Training loss value at step 400: 0.00405976502224803
# Training loss value at step 500: 3.201413154602051
# Training loss value at step 600: 0.025306938216090202
# Training loss value at step 700: 0.00226693507283926
# Training accuracy over whole file: 0.9739375710487366
# ---------------------------------------------------
# Fitting on file 3 containing task: task_working_memory
# Training loss value at step 0: 0.004349771421402693
# Training loss value at step 100: 0.010778659954667091
# Training loss value at step 200: 0.0006038511055521667
# Training loss value at step 300: 0.0011850723531097174
# Training loss value at step 400: 0.0031838936265558004
# Training loss value at step 500: 0.0018587708473205566
# Training loss value at step 600: 0.0019520529313012958
# Training loss value at step 700: 0.0006947487709112465
# Training accuracy over whole file: 0.974902868270874
# ---------------------------------------------------
# Fitting on file 4 containing task: rest
# Training loss value at step 0: 7.147571563720703
# Training loss value at step 100: 0.006510594394057989
# Training loss value at step 200: 0.015161392278969288
# Training loss value at step 300: 0.001303419005125761
# Training loss value at step 400: 0.005223555024713278
# Training loss value at step 500: 0.001168402610346675
# Training loss value at step 600: 0.04619787633419037
# Training loss value at step 700: 0.0007277462864294648
# Training accuracy over whole file: 0.974083423614502
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 8.866878509521484
# Training loss value at step 100: 0.014071298763155937
# Training loss value at step 200: 0.19575712084770203
# Training loss value at step 300: 0.009395549073815346
# Training loss value at step 400: 0.00419166125357151
# Training loss value at step 500: 0.0014292511623352766
# Training loss value at step 600: 0.002086249878630042
# Training loss value at step 700: 0.0035916364286094904
# Training accuracy over whole file: 0.9738000631332397
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 5.593979358673096
# Training loss value at step 100: 0.0022481423802673817
# Training loss value at step 200: 0.0033895678352564573
# Training loss value at step 300: 0.001960857305675745
# Training loss value at step 400: 0.01423831470310688
# Training loss value at step 500: 0.0014786511892452836
# Training loss value at step 600: 0.02937253564596176
# Training loss value at step 700: 0.0009972843108698726
# Training accuracy over whole file: 0.9742098450660706
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 9.0779447555542
# Training loss value at step 100: 0.03894462436437607
# Training loss value at step 200: 1.4938305616378784
# Training loss value at step 300: 0.001142564113251865
# Training loss value at step 400: 0.007075491826981306
# Training loss value at step 500: 0.0012193633010610938
# Training loss value at step 600: 0.0005022218101657927
# Training loss value at step 700: 0.003181279404088855
# Training accuracy over whole file: 0.9733697772026062
# ---------------------------------------------------
# Fitting on file 8 containing task: task_working_memory
# Training loss value at step 0: 7.724467754364014
# Training loss value at step 100: 0.02525475062429905
# Training loss value at step 200: 0.055929504334926605
# Training loss value at step 300: 0.006817532703280449
# Training loss value at step 400: 0.0032130067702382803
# Training loss value at step 500: 0.0032086102291941643
# Training loss value at step 600: 0.0025826692581176758
# Training loss value at step 700: 0.0031986285466700792
# Training accuracy over whole file: 0.9729772210121155
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 32-40....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 6.222229480743408
# Training loss value at step 100: 0.004812681116163731
# Training loss value at step 200: 0.009005997329950333
# Training loss value at step 300: 0.03290088102221489
# Training loss value at step 400: 0.008697839453816414
# Training loss value at step 500: 0.004207924474030733
# Training loss value at step 600: 0.0015290009323507547
# Training loss value at step 700: 0.0013392536202445626
# Training accuracy over whole file: 0.9729533195495605
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 8.782530784606934
# Training loss value at step 100: 0.020510835573077202
# Training loss value at step 200: 0.05122605711221695
# Training loss value at step 300: 0.006002495065331459
# Training loss value at step 400: 0.009027144871652126
# Training loss value at step 500: 0.003677155589684844
# Training loss value at step 600: 0.0027014450170099735
# Training loss value at step 700: 0.002915182150900364
# Training accuracy over whole file: 0.9727448225021362
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 0.0019239740213379264
# Training loss value at step 100: 0.001443654764443636
# Training loss value at step 200: 0.0014335366431623697
# Training loss value at step 300: 0.0011085085570812225
# Training loss value at step 400: 0.0012045992771163583
# Training loss value at step 500: 0.0014252038672566414
# Training loss value at step 600: 0.001057184999808669
# Training loss value at step 700: 0.001759529928676784
# Training accuracy over whole file: 0.9735235571861267
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 0.0011267272057011724
# Training loss value at step 100: 0.0007277462864294648
# Training loss value at step 200: 0.0006976078147999942
# Training loss value at step 300: 0.0012459142599254847
# Training loss value at step 400: 0.0005071069463156164
# Training loss value at step 500: 0.0006180283380672336
# Training loss value at step 600: 0.0006012300727888942
# Training loss value at step 700: 0.0006227937992662191
# Training accuracy over whole file: 0.9742590188980103
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 0.0003856868715956807
# Training loss value at step 100: 0.0006220789509825408
# Training loss value at step 200: 0.00037222131504677236
# Training loss value at step 300: 0.000439428084064275
# Training loss value at step 400: 0.00032050241134129465
# Training loss value at step 500: 0.0007945717661641538
# Training loss value at step 600: 0.00043990471749566495
# Training loss value at step 700: 0.0003147821989841759
# Training accuracy over whole file: 0.9749547243118286
# ---------------------------------------------------
# Fitting on file 6 containing task: task_story_math
# Training loss value at step 0: 0.0003275334893260151
# Training loss value at step 100: 0.00028546550311148167
# Training loss value at step 200: 0.0003165697562508285
# Training loss value at step 300: 0.00034683887497521937
# Training loss value at step 400: 0.00023898606013972312
# Training loss value at step 500: 0.000301673193462193
# Training loss value at step 600: 0.00048423008411191404
# Training loss value at step 700: 0.00019059749320149422
# Training accuracy over whole file: 0.9756138324737549
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 0.08315805345773697
# Training loss value at step 100: 0.0001722425949992612
# Training loss value at step 200: 0.0002026352594839409
# Training loss value at step 300: 0.00016640232934150845
# Training loss value at step 400: 0.000262106885202229
# Training loss value at step 500: 0.00014828535495325923
# Training loss value at step 600: 0.00016282663273159415
# Training loss value at step 700: 0.0001248043408850208
# Training accuracy over whole file: 0.9762390851974487
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 12.008570671081543
# Training loss value at step 100: 0.0006239851354621351
# Training loss value at step 200: 0.0024082250893115997
# Training loss value at step 300: 0.0010808822698891163
# Training loss value at step 400: 0.0008840228547342122
# Training loss value at step 500: 0.00047255316167138517
# Training loss value at step 600: 0.002378018107265234
# Training loss value at step 700: 9.941560711013153e-05
# Training accuracy over whole file: 0.9763274192810059
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 0.0003457663697190583
# Training loss value at step 100: 0.00019965562387369573
# Training loss value at step 200: 0.0002108589978888631
# Training loss value at step 300: 0.00014685506175737828
# Training loss value at step 400: 0.0004140473320148885
# Training loss value at step 500: 0.0003541081096045673
# Training loss value at step 600: 0.00026913834153674543
# Training loss value at step 700: 0.00030286493711173534
# Training accuracy over whole file: 0.9769048094749451
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 0.0001685477327555418
# Training loss value at step 100: 0.0006104036583565176
# Training loss value at step 200: 0.00024387246230617166
# Training loss value at step 300: 0.000346362212439999
# Training loss value at step 400: 0.00010263393050990999
# Training loss value at step 500: 0.00010394509445177391
# Training loss value at step 600: 0.00018499570433050394
# Training loss value at step 700: 6.115249561844394e-05
# Training accuracy over whole file: 0.9774547219276428
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 1.9650949239730835
# Training loss value at step 100: 0.017073553055524826
# Training loss value at step 200: 0.0010517071932554245
# Training loss value at step 300: 0.0008139872807078063
# Training loss value at step 400: 0.0021296695340424776
# Training loss value at step 500: 0.0007902836659923196
# Training loss value at step 600: 0.0012829415500164032
# Training loss value at step 700: 0.00130425242241472
# Training accuracy over whole file: 0.9777731895446777
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 9.025324821472168
# Training loss value at step 100: 0.0031565623357892036
# Training loss value at step 200: 0.0012949660886079073
# Training loss value at step 300: 0.002054486656561494
# Training loss value at step 400: 0.0075024752877652645
# Training loss value at step 500: 0.0003093002596870065
# Training loss value at step 600: 0.00015209948469419032
# Training loss value at step 700: 8.987976616481319e-05
# Training accuracy over whole file: 0.9774738550186157
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 13.86923885345459
# Training loss value at step 100: 0.0011192255187779665
# Training loss value at step 200: 0.002362795639783144
# Training loss value at step 300: 0.0008874768391251564
# Training loss value at step 400: 0.002768852049484849
# Training loss value at step 500: 0.0007439468172378838
# Training loss value at step 600: 0.007613688241690397
# Training loss value at step 700: 0.000285584683297202
# Training accuracy over whole file: 0.9773844480514526
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.0033841028343886137
# Training loss value at step 100: 0.5450606942176819
# Training loss value at step 200: 0.00015805903240107
# Training loss value at step 300: 0.0001541257370263338
# Training loss value at step 400: 0.0005968220066279173
# Training loss value at step 500: 0.00018463814922142774
# Training loss value at step 600: 0.00032634177478030324
# Training loss value at step 700: 0.0001517419150331989
# Training accuracy over whole file: 0.977573812007904
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 1.8636457920074463
# Training loss value at step 100: 0.021445877850055695
# Training loss value at step 200: 0.005823550280183554
# Training loss value at step 300: 5.756783485412598
# Training loss value at step 400: 0.0014293702552095056
# Training loss value at step 500: 0.013605012558400631
# Training loss value at step 600: 0.002164047211408615
# Training loss value at step 700: 0.003186864545568824
# Training accuracy over whole file: 0.9772440195083618
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 5.350242614746094
# Training loss value at step 100: 0.00171538011636585
# Training loss value at step 200: 0.026393335312604904
# Training loss value at step 300: 0.0024717275518924
# Training loss value at step 400: 0.024082284420728683
# Training loss value at step 500: 0.024510908871889114
# Training loss value at step 600: 0.004305854439735413
# Training loss value at step 700: 0.0016756316181272268
# Training accuracy over whole file: 0.9769279360771179
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 9.317943572998047
# Training loss value at step 100: 0.006104514468461275
# Training loss value at step 200: 0.001446987851522863
# Training loss value at step 300: 0.003804589621722698
# Training loss value at step 400: 0.010440965183079243
# Training loss value at step 500: 0.014042617753148079
# Training loss value at step 600: 0.003909327555447817
# Training loss value at step 700: 0.0021422787103801966
# Training accuracy over whole file: 0.9763667583465576
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 3.3054394721984863
# Training loss value at step 100: 0.005577715579420328
# Training loss value at step 200: 0.011848784983158112
# Training loss value at step 300: 0.16217368841171265
# Training loss value at step 400: 0.013323207385838032
# Training loss value at step 500: 0.0030916770920157433
# Training loss value at step 600: 0.002765404526144266
# Training loss value at step 700: 0.003606365295127034
# Training accuracy over whole file: 0.9752970933914185
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 5.725719451904297
# Training loss value at step 100: 0.12428098171949387
# Training loss value at step 200: 0.024767601862549782
# Training loss value at step 300: 0.011691149324178696
# Training loss value at step 400: 0.005717827472835779
# Training loss value at step 500: 0.008430251851677895
# Training loss value at step 600: 0.003312222193926573
# Training loss value at step 700: 0.0024109601508826017
# Training accuracy over whole file: 0.9747899174690247
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 0.00646653538569808
# Training loss value at step 100: 0.0006187431863509119
# Training loss value at step 200: 0.0024917051196098328
# Training loss value at step 300: 0.0028143818490207195
# Training loss value at step 400: 0.0007843278581276536
# Training loss value at step 500: 0.0010826685465872288
# Training loss value at step 600: 0.0013171101454645395
# Training loss value at step 700: 0.0012462714221328497
# Training accuracy over whole file: 0.9752747416496277
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 0.00042906138696707785
# Training loss value at step 100: 0.0018804263090714812
# Training loss value at step 200: 0.0010726656764745712
# Training loss value at step 300: 0.000774917658418417
# Training loss value at step 400: 0.0005756151513196528
# Training loss value at step 500: 0.0012534151319414377
# Training loss value at step 600: 0.00047088501742109656
# Training loss value at step 700: 0.0006521005416288972
# Training accuracy over whole file: 0.9757412672042847
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 1.2741875648498535
# Training loss value at step 100: 0.007284390740096569
# Training loss value at step 200: 0.003017755225300789
# Training loss value at step 300: 0.001257224939763546
# Training loss value at step 400: 0.05778537690639496
# Training loss value at step 500: 0.0018103414913639426
# Training loss value at step 600: 0.0023466211277991533
# Training loss value at step 700: 0.0017916593933477998
# Training accuracy over whole file: 0.9756754040718079
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 13.354045867919922
# Training loss value at step 100: 0.03192337974905968
# Training loss value at step 200: 0.010224111378192902
# Training loss value at step 300: 0.0014390123542398214
# Training loss value at step 400: 0.0035910424776375294
# Training loss value at step 500: 0.14564986526966095
# Training loss value at step 600: 0.001335563138127327
# Training loss value at step 700: 0.0010097887134179473
# Training accuracy over whole file: 0.9753591418266296
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.003323034383356571
# Training loss value at step 100: 0.00248873233795166
# Training loss value at step 200: 0.003853041213005781
# Training loss value at step 300: 0.0013668728061020374
# Training loss value at step 400: 0.000987876090221107
# Training loss value at step 500: 0.01958438567817211
# Training loss value at step 600: 0.00018153927521780133
# Training loss value at step 700: 0.0001567479339428246
# Training accuracy over whole file: 0.975302517414093
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 0.0006082591717131436
# Training loss value at step 100: 0.0012681784573942423
# Training loss value at step 200: 0.00032240914879366755
# Training loss value at step 300: 0.0004451475979294628
# Training loss value at step 400: 0.0010058587649837136
# Training loss value at step 500: 0.00026592056383378804
# Training loss value at step 600: 0.00016282663273159415
# Training loss value at step 700: 0.005960546433925629
# Training accuracy over whole file: 0.9757357835769653
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 7.954740047454834
# Training loss value at step 100: 0.009633835405111313
# Training loss value at step 200: 0.2937609553337097
# Training loss value at step 300: 0.007892967201769352
# Training loss value at step 400: 0.027389708906412125
# Training loss value at step 500: 0.0018047487828880548
# Training loss value at step 600: 0.0007205988513305783
# Training loss value at step 700: 0.0007684853626415133
# Training accuracy over whole file: 0.97547847032547
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 1.6318436861038208
# Training loss value at step 100: 0.0051801507361233234
# Training loss value at step 200: 0.0030280950013548136
# Training loss value at step 300: 0.043423816561698914
# Training loss value at step 400: 0.0021036178804934025
# Training loss value at step 500: 0.0009789442410692573
# Training loss value at step 600: 0.0019814397674053907
# Training loss value at step 700: 0.0017804736271500587
# Training accuracy over whole file: 0.9756369590759277
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 5.701047420501709
# Training loss value at step 100: 0.11663733422756195
# Training loss value at step 200: 1.3178120851516724
# Training loss value at step 300: 0.0054468316957354546
# Training loss value at step 400: 0.0030381970573216677
# Training loss value at step 500: 0.0012469858629629016
# Training loss value at step 600: 0.00462521705776453
# Training loss value at step 700: 0.002248499309644103
# Training accuracy over whole file: 0.9753687381744385
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.0014760324265807867
# Training loss value at step 100: 0.0014056811342015862
# Training loss value at step 200: 0.0033280246425420046
# Training loss value at step 300: 0.0008466235012747347
# Training loss value at step 400: 0.0005990855861455202
# Training loss value at step 500: 0.0011562574654817581
# Training loss value at step 600: 0.0006906984490342438
# Training loss value at step 700: 0.0013449679827317595
# Training accuracy over whole file: 0.975772500038147
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 6.614572048187256
# Training loss value at step 100: 0.0148325739428401
# Training loss value at step 200: 0.005496507976204157
# Training loss value at step 300: 0.0024396199733018875
# Training loss value at step 400: 0.0004010588163509965
# Training loss value at step 500: 0.0005746620590798557
# Training loss value at step 600: 0.00012015574611723423
# Training loss value at step 700: 0.0002012050390476361
# Training accuracy over whole file: 0.9755311608314514
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 0.0008127961773425341
# Training loss value at step 100: 0.0016210046596825123
# Training loss value at step 200: 0.0006811682251282036
# Training loss value at step 300: 0.0004481264913920313
# Training loss value at step 400: 0.0005086558521725237
# Training loss value at step 500: 0.0003987947420682758
# Training loss value at step 600: 0.00019739109848160297
# Training loss value at step 700: 0.0003736513026524335
# Training accuracy over whole file: 0.9759195446968079
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 9.290143966674805
# Training loss value at step 100: 0.003874415997415781
# Training loss value at step 200: 0.002641167026013136
# Training loss value at step 300: 0.0012954423436895013
# Training loss value at step 400: 0.08982717245817184
# Training loss value at step 500: 0.000940714729949832
# Training loss value at step 600: 0.0020888668950647116
# Training loss value at step 700: 0.00038092033355496824
# Training accuracy over whole file: 0.975979745388031
# ---------------------------------------------------
# --------------------------------------------------------------
# Starting epoch 2
#
# Fitting on files 0-8....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 11.597429275512695
# Training loss value at step 100: 0.026607291772961617
# Training loss value at step 200: 0.22998331487178802
# Training loss value at step 300: 1.3787193298339844
# Training loss value at step 400: 0.001776070799678564
# Training loss value at step 500: 7.664863369427621e-05
# Training loss value at step 600: 0.0008507922757416964
# Training loss value at step 700: 0.0006329201860353351
# Training accuracy over whole file: 0.9469026327133179
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 11.806601524353027
# Training loss value at step 100: 0.014706420712172985
# Training loss value at step 200: 0.0046737478114664555
# Training loss value at step 300: 0.008372445590794086
# Training loss value at step 400: 0.003412853693589568
# Training loss value at step 500: 0.012417386285960674
# Training loss value at step 600: 0.0004960260121151805
# Training loss value at step 700: 0.0007240534760057926
# Training accuracy over whole file: 0.9424778819084167
# ---------------------------------------------------
# Fitting on file 3 containing task: task_motor
# Training loss value at step 0: 10.910696983337402
# Training loss value at step 100: 0.006255451589822769
# Training loss value at step 200: 0.07870993763208389
# Training loss value at step 300: 0.0022671727929264307
# Training loss value at step 400: 0.0029229081701487303
# Training loss value at step 500: 0.0015375708462670445
# Training loss value at step 600: 0.006103092804551125
# Training loss value at step 700: 5.94836674281396e-05
# Training accuracy over whole file: 0.9481669068336487
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 6.602268695831299
# Training loss value at step 100: 0.0004210777406115085
# Training loss value at step 200: 0.0008950994815677404
# Training loss value at step 300: 0.004705783445388079
# Training loss value at step 400: 0.001946698990650475
# Training loss value at step 500: 0.0008990298374556005
# Training loss value at step 600: 0.00028546550311148167
# Training loss value at step 700: 0.0012032896047458053
# Training accuracy over whole file: 0.9532237648963928
# ---------------------------------------------------
# Fitting on file 5 containing task: rest
# Training loss value at step 0: 1.469887614250183
# Training loss value at step 100: 0.009811392053961754
# Training loss value at step 200: 0.008692167699337006
# Training loss value at step 300: 0.000690460205078125
# Training loss value at step 400: 0.022036338225007057
# Training loss value at step 500: 0.003821452846750617
# Training loss value at step 600: 0.005753978155553341
# Training loss value at step 700: 0.003911583684384823
# Training accuracy over whole file: 0.9565107226371765
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.00012396997772157192
# Training loss value at step 100: 0.00015710550360381603
# Training loss value at step 200: 0.00037067217635922134
# Training loss value at step 300: 0.000766102981287986
# Training loss value at step 400: 0.000942977552767843
# Training loss value at step 500: 0.0009054613183252513
# Training loss value at step 600: 0.0013684204313904047
# Training loss value at step 700: 0.00034588552080094814
# Training accuracy over whole file: 0.9637589454650879
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 8.67805938469246e-05
# Training loss value at step 100: 0.0003389737685211003
# Training loss value at step 200: 0.0011726891389116645
# Training loss value at step 300: 6.83045873302035e-05
# Training loss value at step 400: 0.0012660353677347302
# Training loss value at step 500: 0.0008908117306418717
# Training loss value at step 600: 0.0004769618099089712
# Training loss value at step 700: 0.0003951007383875549
# Training accuracy over whole file: 0.9689362645149231
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 7.796342372894287
# Training loss value at step 100: 0.01630976051092148
# Training loss value at step 200: 0.012726283632218838
# Training loss value at step 300: 0.008377410471439362
# Training loss value at step 400: 0.0026956195943057537
# Training loss value at step 500: 0.002734376350417733
# Training loss value at step 600: 0.009342641569674015
# Training loss value at step 700: 0.0012384133879095316
# Training accuracy over whole file: 0.9702907800674438
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 8-16....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 0.2083646059036255
# Training loss value at step 100: 0.0029845954850316048
# Training loss value at step 200: 0.0015470929211005569
# Training loss value at step 300: 0.0005430892342701554
# Training loss value at step 400: 0.00027783826226368546
# Training loss value at step 500: 0.0005237876321189106
# Training loss value at step 600: 0.0010931475553661585
# Training loss value at step 700: 0.0009887097403407097
# Training accuracy over whole file: 0.9730299115180969
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 8.070725440979004
# Training loss value at step 100: 0.00013481661153491586
# Training loss value at step 200: 0.00013255194062367082
# Training loss value at step 300: 0.22268682718276978
# Training loss value at step 400: 0.0004655231023207307
# Training loss value at step 500: 0.0006521005416288972
# Training loss value at step 600: 0.001920642564073205
# Training loss value at step 700: 8.201262971851975e-05
# Training accuracy over whole file: 0.9726927876472473
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 3.2275078296661377
# Training loss value at step 100: 0.0005697772721759975
# Training loss value at step 200: 0.005285100545734167
# Training loss value at step 300: 0.0010367024224251509
# Training loss value at step 400: 5.2704854011535645
# Training loss value at step 500: 0.01969040557742119
# Training loss value at step 600: 0.0008488865569233894
# Training loss value at step 700: 0.0002867764269467443
# Training accuracy over whole file: 0.9725319147109985
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 2.2211294174194336
# Training loss value at step 100: 0.023578844964504242
# Training loss value at step 200: 0.0028368488419800997
# Training loss value at step 300: 0.0035059908404946327
# Training loss value at step 400: 0.00034505134681239724
# Training loss value at step 500: 4.458328112377785e-05
# Training loss value at step 600: 0.0012935374397784472
# Training loss value at step 700: 0.001595177804119885
# Training accuracy over whole file: 0.9728192090988159
# ---------------------------------------------------
# Fitting on file 5 containing task: task_working_memory
# Training loss value at step 0: 0.0006084974738769233
# Training loss value at step 100: 0.0004876854654867202
# Training loss value at step 200: 0.012552423402667046
# Training loss value at step 300: 7.4741430580616e-05
# Training loss value at step 400: 0.0008120815036818385
# Training loss value at step 500: 6.341733387671411e-05
# Training loss value at step 600: 0.0010153858456760645
# Training loss value at step 700: 0.00012861855793744326
# Training accuracy over whole file: 0.9744238257408142
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 9.006464958190918
# Training loss value at step 100: 0.008717338554561138
# Training loss value at step 200: 0.02167174592614174
# Training loss value at step 300: 0.0002574589161667973
# Training loss value at step 400: 0.005241462029516697
# Training loss value at step 500: 0.009186264127492905
# Training loss value at step 600: 0.006832806393504143
# Training loss value at step 700: 0.0016315970569849014
# Training accuracy over whole file: 0.9739931225776672
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 9.630546569824219
# Training loss value at step 100: 0.16286899149417877
# Training loss value at step 200: 0.048356443643569946
# Training loss value at step 300: 0.006665851920843124
# Training loss value at step 400: 0.45367786288261414
# Training loss value at step 500: 0.0021384721621870995
# Training loss value at step 600: 0.00587996281683445
# Training loss value at step 700: 0.004669476300477982
# Training accuracy over whole file: 0.9712600111961365
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 1.2139413356781006
# Training loss value at step 100: 0.0014427024871110916
# Training loss value at step 200: 0.00019000156316906214
# Training loss value at step 300: 0.001257344032637775
# Training loss value at step 400: 0.3780550956726074
# Training loss value at step 500: 0.005134017206728458
# Training loss value at step 600: 0.009033996611833572
# Training loss value at step 700: 0.0025009801611304283
# Training accuracy over whole file: 0.9695006608963013
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 16-24....
# Fitting on file 1 containing task: task_working_memory
# Training loss value at step 0: 7.518944263458252
# Training loss value at step 100: 0.051730260252952576
# Training loss value at step 200: 0.008470677770674229
# ...
# ---------------------------------------------------
# Fitting on file 7 containing task: task_story_math
# Training loss value at step 0: 3.8742269680369645e-05
# Training loss value at step 100: 5.960446742392378e-06
# Training loss value at step 200: 5.364403477869928e-06
# Training loss value at step 300: 6.079655122448457e-06
# Training loss value at step 400: 7.986990567587782e-06
# Training loss value at step 500: 2.7656173188006505e-05
# Training loss value at step 600: 1.966933996300213e-05
# Training loss value at step 700: 3.015949550899677e-05
# Training accuracy over whole file: 0.9765308499336243
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 12.090328216552734
# Training loss value at step 100: 0.00026472879108041525
# Training loss value at step 200: 0.00961990375071764
# Training loss value at step 300: 0.0004148814477957785
# Training loss value at step 400: 4.172316494077677e-06
# Training loss value at step 500: 1.823885577323381e-05
# Training loss value at step 600: 2.9802276912960224e-06
# Training loss value at step 700: 8.284702198579907e-05
# Training accuracy over whole file: 0.9761061668395996
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 40-48....
# Fitting on file 1 containing task: task_motor
# Training loss value at step 0: 1.0847986231965479e-05
# Training loss value at step 100: 3.933898824470816e-06
# Training loss value at step 200: 2.610649426060263e-05
# Training loss value at step 300: 1.6689286894688848e-06
# Training loss value at step 400: 1.549708758830093e-05
# Training loss value at step 500: 3.2186455882765586e-06
# Training loss value at step 600: 2.6464111215318553e-05
# Training loss value at step 700: 4.529942543740617e-06
# Training accuracy over whole file: 0.9766889810562134
# ---------------------------------------------------
# Fitting on file 2 containing task: task_motor
# Training loss value at step 0: 3.0397906812140718e-05
# Training loss value at step 100: 9.536738616588991e-07
# Training loss value at step 200: 4.649054244509898e-05
# Training loss value at step 300: 3.2186455882765586e-06
# Training loss value at step 400: 2.861018856492592e-06
# Training loss value at step 500: 2.0265558760002023e-06
# Training loss value at step 600: 5.602820692729438e-06
# Training loss value at step 700: 5.864924969500862e-05
# Training accuracy over whole file: 0.9772440195083618
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 0.0005457103834487498
# Training loss value at step 100: 0.00040844682371243834
# Training loss value at step 200: 0.00026353701832704246
# Training loss value at step 300: 7.760223525110632e-05
# Training loss value at step 400: 0.04059705510735512
# Training loss value at step 500: 0.0036028018221259117
# Training loss value at step 600: 0.0011445883428677917
# Training loss value at step 700: 0.0024318902287632227
# Training accuracy over whole file: 0.9770969748497009
# ---------------------------------------------------
# Fitting on file 4 containing task: task_working_memory
# Training loss value at step 0: 12.073077201843262
# Training loss value at step 100: 0.0003149013500660658
# Training loss value at step 200: 0.0004549183649942279
# Training loss value at step 300: 0.010973463766276836
# Training loss value at step 400: 0.007204268593341112
# Training loss value at step 500: 0.0013569919392466545
# Training loss value at step 600: 0.017677374184131622
# Training loss value at step 700: 0.00020239688456058502
# Training accuracy over whole file: 0.9763532876968384
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 14.201857566833496
# Training loss value at step 100: 0.0031262594275176525
# Training loss value at step 200: 0.003499576123431325
# Training loss value at step 300: 0.00010907054820563644
# Training loss value at step 400: 0.005129747558385134
# Training loss value at step 500: 0.021438295021653175
# Training loss value at step 600: 0.002148464322090149
# Training loss value at step 700: 0.01015437301248312
# Training accuracy over whole file: 0.9762325882911682
# ---------------------------------------------------
# Fitting on file 6 containing task: task_motor
# Training loss value at step 0: 0.0009176096064038575
# Training loss value at step 100: 0.002236367203295231
# Training loss value at step 200: 0.00010549465514486656
# Training loss value at step 300: 0.0011525661684572697
# Training loss value at step 400: 0.005457028280943632
# Training loss value at step 500: 0.0005066303419880569
# Training loss value at step 600: 0.0002746204845607281
# Training loss value at step 700: 7.056941103655845e-05
# Training accuracy over whole file: 0.9765843749046326
# ---------------------------------------------------
# Fitting on file 7 containing task: rest
# Training loss value at step 0: 2.1087613105773926
# Training loss value at step 100: 0.0015395942609757185
# Training loss value at step 200: 1.2560478448867798
# Training loss value at step 300: 0.4243081212043762
# Training loss value at step 400: 0.03726154938340187
# Training loss value at step 500: 0.001209600013680756
# Training loss value at step 600: 0.00014244495832826942
# Training loss value at step 700: 0.0016450457042083144
# Training accuracy over whole file: 0.9765715599060059
# ---------------------------------------------------
# Fitting on file 8 containing task: task_motor
# Training loss value at step 0: 0.051232967525720596
# Training loss value at step 100: 9.536738616588991e-07
# Training loss value at step 200: 0.003330044448375702
# Training loss value at step 300: 0.012129239737987518
# Training loss value at step 400: 0.05496479198336601
# Training loss value at step 500: 0.0021326434798538685
# Training loss value at step 600: 0.00012492353562265635
# Training loss value at step 700: 0.00011097769311163574
# Training accuracy over whole file: 0.9767172336578369
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 48-56....
# Fitting on file 1 containing task: task_story_math
# Training loss value at step 0: 13.82392692565918
# Training loss value at step 100: 0.018756292760372162
# Training loss value at step 200: 0.0005317704635672271
# Training loss value at step 300: 0.0006069486844353378
# Training loss value at step 400: 0.07045342028141022
# Training loss value at step 500: 0.0029850706923753023
# Training loss value at step 600: 0.00010823617776622996
# Training loss value at step 700: 0.006471510045230389
# Training accuracy over whole file: 0.9756959676742554
# ---------------------------------------------------
# Fitting on file 2 containing task: task_working_memory
# Training loss value at step 0: 4.757139682769775
# Training loss value at step 100: 0.00026973424246534705
# Training loss value at step 200: 0.0005041282274760306
# Training loss value at step 300: 0.01525355875492096
# Training loss value at step 400: 0.015033870935440063
# Training loss value at step 500: 0.0012160295154899359
# Training loss value at step 600: 0.00048458753735758364
# Training loss value at step 700: 0.0003457663697190583
# Training accuracy over whole file: 0.9758027791976929
# ---------------------------------------------------
# Fitting on file 3 containing task: task_story_math
# Training loss value at step 0: 6.093091011047363
# Training loss value at step 100: 0.0004782725009135902
# Training loss value at step 200: 0.034528542309999466
# Training loss value at step 300: 0.00041500062798149884
# Training loss value at step 400: 0.0002335037279408425
# Training loss value at step 500: 0.0001941730733960867
# Training loss value at step 600: 0.0012740122620016336
# Training loss value at step 700: 4.410646579344757e-05
# Training accuracy over whole file: 0.9759054183959961
# ---------------------------------------------------
# Fitting on file 4 containing task: task_story_math
# Training loss value at step 0: 0.0752616748213768
# Training loss value at step 100: 9.512448741588742e-05
# Training loss value at step 200: 0.001255677198059857
# Training loss value at step 300: 3.421248038648628e-05
# Training loss value at step 400: 3.576272320060525e-06
# Training loss value at step 500: 7.259582343976945e-05
# Training loss value at step 600: 2.861018856492592e-06
# Training loss value at step 700: 1.3470558769768104e-05
# Training accuracy over whole file: 0.97636878490448
# ---------------------------------------------------
# Fitting on file 5 containing task: task_story_math
# Training loss value at step 0: 0.0007708676857873797
# Training loss value at step 100: 8.868777513271198e-05
# Training loss value at step 200: 7.867782187531702e-06
# Training loss value at step 300: 3.075552376685664e-05
# Training loss value at step 400: 9.07141511561349e-05
# Training loss value at step 500: 7.939023635117337e-05
# Training loss value at step 600: 0.0005164004978723824
# Training loss value at step 700: 4.529942543740617e-06
# Training accuracy over whole file: 0.9768146276473999
# ---------------------------------------------------
# Fitting on file 6 containing task: rest
# Training loss value at step 0: 0.0004267973708920181
# Training loss value at step 100: 0.0015132891712710261
# Training loss value at step 200: 0.0002416080387774855
# Training loss value at step 300: 0.01451199036091566
# Training loss value at step 400: 0.02142324298620224
# Training loss value at step 500: 0.0004180987598374486
# Training loss value at step 600: 0.00014304091746453196
# Training loss value at step 700: 6.16293036728166e-05
# Training accuracy over whole file: 0.9767991900444031
# ---------------------------------------------------
# Fitting on file 7 containing task: task_motor
# Training loss value at step 0: 1.805891990661621
# Training loss value at step 100: 0.0005993238883093
# Training loss value at step 200: 8.380061626667157e-05
# Training loss value at step 300: 0.178847074508667
# Training loss value at step 400: 0.005847016349434853
# Training loss value at step 500: 1.7762025890988298e-05
# Training loss value at step 600: 0.00011216964776394889
# Training loss value at step 700: 0.003035107161849737
# Training accuracy over whole file: 0.977060079574585
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 0.00011622230522334576
# Training loss value at step 100: 0.00011145447206217796
# Training loss value at step 200: 9.285972191719338e-05
# Training loss value at step 300: 0.0003491030656732619
# Training loss value at step 400: 0.24828442931175232
# Training loss value at step 500: 0.0007522851810790598
# Training loss value at step 600: 0.005601305980235338
# Training loss value at step 700: 0.000550357042811811
# Training accuracy over whole file: 0.9770182371139526
# ---------------------------------------------------
# --------------------------------------------------------------
# Fitting on files 56-64....
# Fitting on file 1 containing task: rest
# Training loss value at step 0: 5.471556869451888e-05
# Training loss value at step 100: 2.7656173188006505e-05
# Training loss value at step 200: 1.2040065485052764e-05
# Training loss value at step 300: 2.8013790142722428e-05
# Training loss value at step 400: 0.012824442237615585
# Training loss value at step 500: 5.876845170860179e-05
# Training loss value at step 600: 2.658331868587993e-05
# Training loss value at step 700: 1.9311717551317997e-05
# Training accuracy over whole file: 0.9774214029312134
# ---------------------------------------------------
# Fitting on file 2 containing task: task_story_math
# Training loss value at step 0: 6.795097351074219
# Training loss value at step 100: 6.139089964563027e-05
# Training loss value at step 200: 0.0007332258974201977
# Training loss value at step 300: 0.008833734318614006
# Training loss value at step 400: 0.0004564673872664571
# Training loss value at step 500: 2.5152843591058627e-05
# Training loss value at step 600: 6.341733387671411e-05
# Training loss value at step 700: 9.65590606938349e-06
# Training accuracy over whole file: 0.9775709509849548
# ---------------------------------------------------
# Fitting on file 3 containing task: rest
# Training loss value at step 0: 6.508615479106084e-05
# Training loss value at step 100: 6.246371776796877e-05
# Training loss value at step 200: 0.00020668754586949944
# Training loss value at step 300: 4.7205765440594405e-05
# Training loss value at step 400: 0.0013338964199647307
# Training loss value at step 500: 0.0019470559200271964
# Training loss value at step 600: 0.000592890428379178
# Training loss value at step 700: 0.00030632095877081156
# Training accuracy over whole file: 0.9777582287788391
# ---------------------------------------------------
# Fitting on file 4 containing task: task_motor
# Training loss value at step 0: 17.79829216003418
# Training loss value at step 100: 0.07945099472999573
# Training loss value at step 200: 1.6065986156463623
# Training loss value at step 300: 0.0009079624433070421
# Training loss value at step 400: 0.00015853578224778175
# Training loss value at step 500: 0.0042916107922792435
# Training loss value at step 600: 0.0007960011716932058
# Training loss value at step 700: 0.00024136967840604484
# Training accuracy over whole file: 0.9774757623672485
# ---------------------------------------------------
# Fitting on file 5 containing task: task_motor
# Training loss value at step 0: 0.0008212531101889908
# Training loss value at step 100: 0.0024129818193614483
# Training loss value at step 200: 9.285972191719338e-05
# Training loss value at step 300: 0.00018463814922142774
# Training loss value at step 400: 0.0002485204895492643
# Training loss value at step 500: 3.576272320060525e-06
# Training loss value at step 600: 1.0132738680113107e-05
# Training loss value at step 700: 0.00011467275908216834
# Training accuracy over whole file: 0.9778450131416321
# ---------------------------------------------------
# Fitting on file 6 containing task: task_working_memory
# Training loss value at step 0: 5.975535869598389
# Training loss value at step 100: 0.00039915222441777587
# Training loss value at step 200: 0.0008636558777652681
# Training loss value at step 300: 8.95221673999913e-05
# Training loss value at step 400: 0.0016038662288337946
# Training loss value at step 500: 0.0021445390302687883
# Training loss value at step 600: 0.001686342409811914
# Training loss value at step 700: 0.002656385535374284
# Training accuracy over whole file: 0.9775498509407043
# ---------------------------------------------------
# Fitting on file 7 containing task: task_working_memory
# Training loss value at step 0: 3.790783375734463e-05
# Training loss value at step 100: 9.894321920000948e-06
# Training loss value at step 200: 1.3102977275848389
# Training loss value at step 300: 0.00011169286881340668
# Training loss value at step 400: 0.00013696208770852536
# Training loss value at step 500: 0.0001110968878492713
# Training loss value at step 600: 4.589452510117553e-05
# Training loss value at step 700: 0.0008774721063673496
# Training accuracy over whole file: 0.9778861403465271
# ---------------------------------------------------
# Fitting on file 8 containing task: rest
# Training loss value at step 0: 4.864860534667969
# Training loss value at step 100: 0.00033825874561443925
# Training loss value at step 200: 5.686121585313231e-05
# Training loss value at step 300: 7.199982064776123e-05
# Training loss value at step 400: 0.027028687298297882
# Training loss value at step 500: 0.0018994638230651617
# Training loss value at step 600: 0.0001045410826918669
# Training loss value at step 700: 0.007553587201982737
# Training accuracy over whole file: 0.9778563380241394
# ---------------------------------------------------
# --------------------------------------------------------------
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.dense.Dense object at 0x104a19950>, because it is not built.
# INFO:tensorflow:Assets written to: models/trained_LSTM_e3_5_20_cross/assets
# INFO:tensorflow:Assets written to: models/trained_LSTM_e3_5_20_cross/assets

# %%
new_model = keras.models.load_model("/content/content/MyDrive/trained_LSTM_e4_20_20_cross")
new_model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 new_model = keras.models.load_model("/content/content/MyDrive/trained_LSTM_e4_20_20_cross")
#       2 new_model.summary()
#
# File /opt/homebrew/lib/python3.11/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File /opt/homebrew/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/homebrew/lib/python3.11/site-packages/keras/src/saving/legacy/save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at /content/content/MyDrive/trained_LSTM_e4_20_20_cross

# %%
loss_arr = [tensor.numpy() for tensor in losses]

# %%
print(loss_arr)
# Out:
# [8.416853, 14.597052, 19.167416, 22.369194, 24.751888]

# %%
acc_arr = [tensor.numpy() for tensor in accuracies]

# %%
print(acc_arr)
# Out:
# [4.889338, 10.621641, 16.987432, 23.835, 30.890198]
